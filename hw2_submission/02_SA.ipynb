# %% [markdown]
# # Randomized optimization
#
# Plaigiarism note: I partially took this course in 2020 so some of the analysis and text is repeated.

# %% [markdown]
# mlrose procedure:
#
# 1. Define a fitness function
# - This is the function we want to maximize or minimize, and is used to evaluate the fitness of a state vector.
# 2. Define an optimization problem object
# 3. Select and run a randomized optimization algorithm
#
# mlrose fitness functions: https://mlrose.readthedocs.io/en/stable/source/fitness.html

# %% [markdown]
# ## Load libraries

# %%
import six
import sys
sys.modules['sklearn.externals.six'] = six
import mlrose
import numpy as np
import pandas as pd
import time
from sklearn.preprocessing import normalize
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Set directories

# %%
directory_hw1 = "/Users/mikepecorino/Documents/machine_learning/HW1/"
directory_hw2 = "/Users/mikepecorino/Documents/machine_learning/HW2/"
output_four_peaks = directory_hw2 + "four_peaks/"
output_knapsack = directory_hw2 + "knapsack/"
output_flip_flop = directory_hw2 + "flip_flop/"
output_one_max = directory_hw2 + "one_max/"

# %% [markdown]
# ## Common inputs for each optimization problem

# %%
#Problem specific inputs
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Lengths of the state vector
lengths = [1000]
#Number of unique values for each x (0/1)
max_val = 2
#Keeping the fitness curves
curve = True
#Max attempts to find a better neighbor
max_attempts = [20]
#Max iterations
max_iters = range(100, 2100, 100)

#Algorithm specific inputs
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Random Hill Climbing and Simulated Annealing: setting initial state vectors to None
init_state = None
init_temps = [10, 50, 100, 150, 200, 250]
exp_const = 0.01
min_temp = 0.001

# %% [markdown]
# ## Four Peaks

# %%
#Inputs for four peaks problem
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Initialize the fitness function with default t_pct
fitness_fn = mlrose.FourPeaks(t_pct = 0.1)

#Initialize an empty data frame for recording results
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
four_peaks_results = pd.DataFrame(columns = ["algorithm",
                                             "length",
                                             "init_temp",
                                             "max_attempt",
                                             "max_iter",
                                             "best_fitness",
                                             "time",
                                             "function_evaluations"])


#Loop
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Start the iteration counter
iter = 1
#For each unique number of objects
for length in lengths:
    
    #Set the optimization problem object
    problem = mlrose.DiscreteOpt(length = length,
                                 fitness_fn = fitness_fn,
                                 maximize = True,
                                 max_val = max_val)
    
    #For each combination of max attempt, max iteration, and random restart
    for max_attempt in max_attempts:
        for max_iter in max_iters:
            for init_temp in init_temps:
                
                #Ensuring reproducibility
                random_state = iter
                
                #Simulated Annealing: decay schedule for temperature
                schedule = mlrose.ExpDecay(init_temp = init_temp,
                                           exp_const = exp_const,
                                           min_temp = min_temp)

                #Start a timer for each iteration
                start = time.time()
                    
                #Print message
                print("Working on iter:", iter,
                      "Length:", length,
                      "Init_temp:", init_temp,
                      "Max attempt:", max_attempt,
                      "Max iter:", max_iter)

                #Simulated Annealing
                #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
                #Start the timer for Simulated Annealing
                sa_start = time.time()
                
                #Optimization
                (sa_best_state,
                 sa_best_fitness,
                 sa_fitness_curve) = mlrose.simulated_annealing(problem = problem,
                                                                schedule = schedule,
                                                                max_attempts = max_attempt,
                                                                max_iters = max_iter,
                                                                init_state = init_state,
                                                                curve = curve,
                                                                random_state = random_state)
                #End the timer
                sa_end = time.time()
                #Get the total time
                sa_time = sa_end - sa_start
                
                #Message
                print("    SA best fitness:", sa_best_fitness)
                
                #Add to results list
                four_peaks_results = four_peaks_results.append({"algorithm": "simulated_annealing",
                                                                "length": length,
                                                                "init_temp": init_temp,
                                                                "max_attempt": max_attempt,
                                                                "max_iter": max_iter,
                                                                "best_fitness": sa_best_fitness,
                                                                "time": sa_time,
                                                                "function_evaluations": np.argmax(sa_fitness_curve) + 1},
                                                               ignore_index = True)

                
                #End the timer for all four algorithms
                end = time.time()
                #Total time for all four algorithms
                iter_time = end - start
                
                #Message
                print("Iter time:", iter_time)
                
                #Increment the iteration counter
                iter = iter + 1
                
                print("\n")
                
#Output results
four_peaks_results.to_csv(output_four_peaks + "four_peaks_sa.csv", index = False)
pd.DataFrame(sa_fitness_curve).to_csv(output_four_peaks + "four_peaks_sa_curve.csv", index = False)

#Done
print("Done.")
# Out:
# Working on iter: 1 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 100
#     SA best fitness: 2.0
# Iter time: 0.0064737796783447266
#
#
# Working on iter: 2 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 100
#     SA best fitness: 0.0
# Iter time: 0.004608154296875
#
#
# Working on iter: 3 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 100
#     SA best fitness: 0.0
# Iter time: 0.005009174346923828
#
#
# Working on iter: 4 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 100
#     SA best fitness: 4.0
# Iter time: 0.0048329830169677734
#
#
# Working on iter: 5 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 100
#     SA best fitness: 1.0
# Iter time: 0.004513978958129883
#
#
# Working on iter: 6 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 100
#     SA best fitness: 3.0
# Iter time: 0.004839897155761719
#
#
# Working on iter: 7 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 200
#     SA best fitness: 1.0
# Iter time: 0.00652003288269043
#
#
# Working on iter: 8 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 200
#     SA best fitness: 0.0
# Iter time: 0.00653529167175293
#
#
# Working on iter: 9 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 200
#     SA best fitness: 0.0
# Iter time: 0.007472991943359375
#
#
# Working on iter: 10 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 200
#     SA best fitness: 2.0
# Iter time: 0.006808042526245117
#
#
# Working on iter: 11 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 200
#     SA best fitness: 2.0
# Iter time: 0.007066965103149414
#
#
# Working on iter: 12 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 200
#     SA best fitness: 2.0
# Iter time: 0.007055044174194336
#
#
# Working on iter: 13 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 300
#     SA best fitness: 3.0
# Iter time: 0.00898289680480957
#
#
# Working on iter: 14 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 300
#     SA best fitness: 1.0
# Iter time: 0.008590936660766602
#
#
# Working on iter: 15 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 300
#     SA best fitness: 2.0
# Iter time: 0.009186983108520508
#
#
# Working on iter: 16 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 300
#     SA best fitness: 0.0
# Iter time: 0.008327007293701172
#
#
# Working on iter: 17 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 300
#     SA best fitness: 1.0
# Iter time: 0.00940704345703125
#
#
# Working on iter: 18 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 300
#     SA best fitness: 1.0
# Iter time: 0.008388757705688477
#
#
# Working on iter: 19 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 400
#     SA best fitness: 4.0
# Iter time: 0.012140035629272461
#
#
# Working on iter: 20 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 400
#     SA best fitness: 4.0
# Iter time: 0.011807918548583984
#
#
# Working on iter: 21 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 400
#     SA best fitness: 3.0
# Iter time: 0.011263847351074219
#
#
# Working on iter: 22 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 400
#     SA best fitness: 1.0
# Iter time: 0.010530948638916016
#
#
# Working on iter: 23 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 400
#     SA best fitness: 6.0
# Iter time: 0.01100921630859375
#
#
# Working on iter: 24 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 400
#     SA best fitness: 3.0
# Iter time: 0.0125579833984375
#
#
# Working on iter: 25 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 500
#     SA best fitness: 5.0
# Iter time: 0.014906167984008789
#
#
# Working on iter: 26 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 500
#     SA best fitness: 1.0
# Iter time: 0.013461112976074219
#
#
# Working on iter: 27 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 500
#     SA best fitness: 1.0
# Iter time: 0.013039112091064453
#
#
# Working on iter: 28 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 500
#     SA best fitness: 5.0
# Iter time: 0.015330076217651367
#
#
# Working on iter: 29 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 500
#     SA best fitness: 2.0
# Iter time: 0.014801263809204102
#
#
# Working on iter: 30 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 500
#     SA best fitness: 4.0
# Iter time: 0.014874696731567383
#
#
# Working on iter: 31 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 600
#     SA best fitness: 3.0
# Iter time: 0.015686988830566406
#
#
# Working on iter: 32 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 600
#     SA best fitness: 6.0
# Iter time: 0.01612377166748047
#
#
# Working on iter: 33 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 600
#     SA best fitness: 1.0
# Iter time: 0.015168905258178711
#
#
# Working on iter: 34 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 600
#     SA best fitness: 1.0
# Iter time: 0.01500701904296875
#
#
# Working on iter: 35 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 600
#     SA best fitness: 5.0
# Iter time: 0.017262697219848633
#
#
# Working on iter: 36 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 600
#     SA best fitness: 1.0
# Iter time: 0.015797853469848633
#
#
# Working on iter: 37 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 700
#     SA best fitness: 3.0
# Iter time: 0.017972946166992188
#
#
# Working on iter: 38 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 700
#     SA best fitness: 6.0
# Iter time: 0.020660877227783203
#
#
# Working on iter: 39 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 700
#     SA best fitness: 2.0
# Iter time: 0.018153905868530273
#
#
# Working on iter: 40 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 700
#     SA best fitness: 2.0
# Iter time: 0.01730203628540039
#
#
# Working on iter: 41 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 700
#     SA best fitness: 0.0
# Iter time: 0.016829967498779297
#
#
# Working on iter: 42 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 700
#     SA best fitness: 3.0
# Iter time: 0.01909780502319336
#
#
# Working on iter: 43 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 800
#     SA best fitness: 3.0
# Iter time: 0.020437002182006836
#
#
# Working on iter: 44 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 800
#     SA best fitness: 1.0
# Iter time: 0.025962114334106445
#
#
# Working on iter: 45 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 800
#     SA best fitness: 2.0
# Iter time: 0.019617080688476562
#
#
# Working on iter: 46 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 800
#     SA best fitness: 0.0
# Iter time: 0.01997208595275879
#
#
# Working on iter: 47 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 800
#     SA best fitness: 3.0
# Iter time: 0.021559953689575195
#
#
# Working on iter: 48 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 800
#     SA best fitness: 6.0
# Iter time: 0.023190021514892578
#
#
# Working on iter: 49 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 900
#     SA best fitness: 0.0
# Iter time: 0.020699262619018555
#
#
# Working on iter: 50 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 900
#     SA best fitness: 0.0
# Iter time: 0.021242141723632812
#
#
# Working on iter: 51 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 900
#     SA best fitness: 0.0
# Iter time: 0.020999908447265625
#
#
# Working on iter: 52 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 900
#     SA best fitness: 4.0
# Iter time: 0.023422956466674805
#
#
# Working on iter: 53 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 900
#     SA best fitness: 4.0
# Iter time: 0.023754119873046875
#
#
# Working on iter: 54 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 900
#     SA best fitness: 2.0
# Iter time: 0.02221202850341797
#
#
# Working on iter: 55 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1000
#     SA best fitness: 3.0
# Iter time: 0.0245821475982666
#
#
# Working on iter: 56 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1000
#     SA best fitness: 2.0
# Iter time: 0.02497100830078125
#
#
# Working on iter: 57 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1000
#     SA best fitness: 1.0
# Iter time: 0.023806095123291016
#
#
# Working on iter: 58 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1000
#     SA best fitness: 7.0
# Iter time: 0.024797916412353516
#
#
# Working on iter: 59 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1000
#     SA best fitness: 4.0
# Iter time: 0.024280071258544922
#
#
# Working on iter: 60 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1000
#     SA best fitness: 4.0
# Iter time: 0.026893138885498047
#
#
# Working on iter: 61 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1100
#     SA best fitness: 1.0
# Iter time: 0.028323888778686523
#
#
# Working on iter: 62 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1100
#     SA best fitness: 2.0
# Iter time: 0.027586936950683594
#
#
# Working on iter: 63 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1100
#     SA best fitness: 6.0
# Iter time: 0.026669979095458984
#
#
# Working on iter: 64 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1100
#     SA best fitness: 1.0
# Iter time: 0.025573015213012695
#
#
# Working on iter: 65 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1100
#     SA best fitness: 5.0
# Iter time: 0.04487490653991699
#
#
# Working on iter: 66 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1100
#     SA best fitness: 10.0
# Iter time: 0.029170751571655273
#
#
# Working on iter: 67 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1200
#     SA best fitness:
# /Users/mikepecorino/opt/anaconda3/lib/python3.8/site-packages/mlrose/algorithms.py:311: RuntimeWarning: overflow encountered in exp
#   prob = np.exp(delta_e/temp)
#  6.0
# Iter time: 0.03019404411315918
#
#
# Working on iter: 68 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1200
#     SA best fitness: 5.0
# Iter time: 0.026774883270263672
#
#
# Working on iter: 69 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1200
#     SA best fitness: 15.0
# Iter time: 0.030745744705200195
#
#
# Working on iter: 70 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1200
#     SA best fitness: 5.0
# Iter time: 0.0288698673248291
#
#
# Working on iter: 71 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1200
#     SA best fitness: 5.0
# Iter time: 0.030082225799560547
#
#
# Working on iter: 72 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1200
#     SA best fitness: 1.0
# Iter time: 0.028618812561035156
#
#
# Working on iter: 73 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1300
#     SA best fitness: 2.0
# Iter time: 0.02931380271911621
#
#
# Working on iter: 74 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1300
#     SA best fitness: 2.0
# Iter time: 0.02878713607788086
#
#
# Working on iter: 75 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1300
#     SA best fitness: 1.0
# Iter time: 0.029818058013916016
#
#
# Working on iter: 76 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1300
#     SA best fitness: 5.0
# Iter time: 0.03529667854309082
#
#
# Working on iter: 77 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1300
#     SA best fitness: 4.0
# Iter time: 0.03217196464538574
#
#
# Working on iter: 78 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1300
#     SA best fitness: 7.0
# Iter time: 0.03366398811340332
#
#
# Working on iter: 79 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1400
#     SA best fitness: 5.0
# Iter time: 0.036089181900024414
#
#
# Working on iter: 80 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1400
#     SA best fitness: 4.0
# Iter time: 0.034279823303222656
#
#
# Working on iter: 81 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1400
#     SA best fitness: 10.0
# Iter time: 0.0409550666809082
#
#
# Working on iter: 82 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1400
#     SA best fitness: 11.0
# Iter time: 0.037509918212890625
#
#
# Working on iter: 83 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1400
#     SA best fitness: 8.0
# Iter time: 0.03339886665344238
#
#
# Working on iter: 84 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1400
#     SA best fitness: 3.0
# Iter time: 0.033637046813964844
#
#
# Working on iter: 85 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1500
#     SA best fitness: 1.0
# Iter time: 0.03468489646911621
#
#
# Working on iter: 86 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1500
#     SA best fitness: 3.0
# Iter time: 0.03554391860961914
#
#
# Working on iter: 87 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1500
#     SA best fitness: 6.0
# Iter time: 0.03740191459655762
#
#
# Working on iter: 88 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1500
#     SA best fitness: 6.0
# Iter time: 0.03670692443847656
#
#
# Working on iter: 89 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1500
#     SA best fitness: 10.0
# Iter time: 0.041821956634521484
#
#
# Working on iter: 90 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1500
#     SA best fitness: 4.0
# Iter time: 0.03724384307861328
#
#
# Working on iter: 91 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1600
#     SA best fitness: 1.0
# Iter time: 0.045563697814941406
#
#
# Working on iter: 92 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1600
#     SA best fitness: 3.0
# Iter time: 0.03876090049743652
#
#
# Working on iter: 93 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1600
#     SA best fitness: 14.0
# Iter time: 0.05077981948852539
#
#
# Working on iter: 94 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1600
#     SA best fitness: 3.0
# Iter time: 0.03918004035949707
#
#
# Working on iter: 95 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1600
#     SA best fitness: 4.0
# Iter time: 0.03847813606262207
#
#
# Working on iter: 96 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1600
#     SA best fitness: 2.0
# Iter time: 0.034590959548950195
#
#
# Working on iter: 97 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1700
#     SA best fitness: 8.0
# Iter time: 0.03949570655822754
#
#
# Working on iter: 98 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1700
#     SA best fitness: 1.0
# Iter time: 0.03869485855102539
#
#
# Working on iter: 99 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1700
#     SA best fitness: 5.0
# Iter time: 0.040776968002319336
#
#
# Working on iter: 100 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1700
#     SA best fitness: 6.0
# Iter time: 0.039381980895996094
#
#
# Working on iter: 101 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1700
#     SA best fitness: 6.0
# Iter time: 0.04212689399719238
#
#
# Working on iter: 102 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1700
#     SA best fitness: 5.0
# Iter time: 0.044252872467041016
#
#
# Working on iter: 103 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1800
#     SA best fitness: 4.0
# Iter time: 0.043550968170166016
#
#
# Working on iter: 104 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1800
#     SA best fitness: 6.0
# Iter time: 0.04710507392883301
#
#
# Working on iter: 105 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1800
#     SA best fitness: 1.0
# Iter time: 0.04216790199279785
#
#
# Working on iter: 106 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1800
#     SA best fitness: 6.0
# Iter time: 0.04899096488952637
#
#
# Working on iter: 107 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1800
#     SA best fitness: 3.0
# Iter time: 0.04416370391845703
#
#
# Working on iter: 108 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1800
#     SA best fitness: 4.0
# Iter time: 0.04468894004821777
#
#
# Working on iter: 109 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1900
#     SA best fitness: 10.0
# Iter time: 0.053273916244506836
#
#
# Working on iter: 110 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1900
#     SA best fitness: 12.0
# Iter time: 0.04857015609741211
#
#
# Working on iter: 111 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1900
#     SA best fitness: 2.0
# Iter time: 0.04085707664489746
#
#
# Working on iter: 112 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1900
#     SA best fitness: 15.0
# Iter time: 0.052722930908203125
#
#
# Working on iter: 113 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1900
#     SA best fitness: 3.0
# Iter time: 0.04919028282165527
#
#
# Working on iter: 114 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1900
#     SA best fitness: 3.0
# Iter time: 0.04295516014099121
#
#
# Working on iter: 115 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 2000
#     SA best fitness: 15.0
# Iter time: 0.058438777923583984
#
#
# Working on iter: 116 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 2000
#     SA best fitness: 8.0
# Iter time: 0.0554811954498291
#
#
# Working on iter: 117 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 2000
#     SA best fitness: 5.0
# Iter time: 0.05258584022521973
#
#
# Working on iter: 118 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 2000
#     SA best fitness: 6.0
# Iter time: 0.05196499824523926
#
#
# Working on iter: 119 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 2000
#     SA best fitness: 2.0
# Iter time: 0.0460047721862793
#
#
# Working on iter: 120 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 2000
#     SA best fitness: 5.0
# Iter time: 0.04908108711242676
#
#
# Done.

# %% [markdown]
# ## Knapsack

# %%
#Inputs for knapsack problem
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
weights = np.random.randint(1, 6, lengths)
values = np.random.randint(1, 6, lengths)
max_weight_pct = 0.6
fitness_fn = mlrose.Knapsack(weights = weights, values = values, max_weight_pct = max_weight_pct)

#Initialize an empty data frame for recording results
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
knapsack_results = pd.DataFrame(columns = ["algorithm",
                                           "length",
                                           "init_temp",
                                           "max_attempt",
                                           "max_iter",
                                           "best_fitness",
                                           "time",
                                           "function_evaluations"])

#Loop
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Start an iteration counter
iter = 1
#For each unique number of objects
for length in lengths:
    
    #Set the optimization problem object
    problem = mlrose.DiscreteOpt(length = length,
                                 fitness_fn = fitness_fn,
                                 maximize = True,
                                 max_val = max_val)
    
    #For each combination of max attempt, max iteration, and random restart
    for max_attempt in max_attempts:
        for max_iter in max_iters:
            for init_temp in init_temps:
                
                #Ensuring reproducibility
                random_state = iter
                
                #Simulated Annealing: decay schedule for temperature
                schedule = mlrose.ExpDecay(init_temp = init_temp,
                                           exp_const = exp_const,
                                           min_temp = min_temp)
                
                #Start a timer for each iteration
                start = time.time()
                    
                #Print message
                print("Working on iter:", iter,
                      "Length:", length,
                      "Init_temp:", init_temp,
                      "Max attempt:", max_attempt,
                      "Max iter:", max_iter)

                #Simulated Annealing
                #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
                #Start the timer for Simulated Annealing
                sa_start = time.time()
                
                #Optimization
                (sa_best_state,
                 sa_best_fitness,
                 sa_fitness_curve) = mlrose.simulated_annealing(problem = problem,
                                                                schedule = schedule,
                                                                max_attempts = max_attempt,
                                                                max_iters = max_iter,
                                                                init_state = init_state,
                                                                curve = curve,
                                                                random_state = random_state)
                #End the timer
                sa_end = time.time()
                #Get the total time
                sa_time = sa_end - sa_start
                
                #Message
                print("    SA best fitness:", sa_best_fitness)
                
                #Add to results list
                knapsack_results = knapsack_results.append({"algorithm": "simulated_annealing",
                                                            "length": length,
                                                            "init_temp": init_temp,
                                                            "max_attempt": max_attempt,
                                                            "max_iter": max_iter,
                                                            "best_fitness": sa_best_fitness,
                                                            "time": sa_time,
                                                            "function_evaluations": np.argmax(sa_fitness_curve) + 1},
                                                            ignore_index = True)
                
                #End the timer for all four algorithms
                end = time.time()
                #Total time for all four algorithms
                iter_time = end - start
                
                #Message
                print("Iter time:", iter_time)
                
                print("\n")
                iter = iter + 1

#Output results                
knapsack_results.to_csv(output_knapsack + "knapsack_sa.csv", index = False)
pd.DataFrame(sa_fitness_curve).to_csv(output_knapsack + "knapsack_sa_curve.csv", index = False)

#Done
print("Done.")
# Out:
# Working on iter: 1 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 100
#     SA best fitness: 1487.0
# Iter time: 0.010740041732788086
#
#
# Working on iter: 2 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 100
#     SA best fitness: 1540.0
# Iter time: 0.011059999465942383
#
#
# Working on iter: 3 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 100
#     SA best fitness: 1484.0
# Iter time: 0.01147913932800293
#
#
# Working on iter: 4 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 100
#     SA best fitness: 1519.0
# Iter time: 0.010241985321044922
#
#
# Working on iter: 5 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 100
#     SA best fitness: 1497.0
# Iter time: 0.010213136672973633
#
#
# Working on iter: 6 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 100
#     SA best fitness: 1488.0
# Iter time: 0.010159969329833984
#
#
# Working on iter: 7 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 200
#     SA best fitness: 1633.0
# Iter time: 0.01357412338256836
#
#
# Working on iter: 8 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 200
#     SA best fitness: 1646.0
# Iter time: 0.013891220092773438
#
#
# Working on iter: 9 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 200
#     SA best fitness: 1518.0
# Iter time: 0.015100240707397461
#
#
# Working on iter: 10 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 200
#     SA best fitness: 1481.0
# Iter time: 0.014183998107910156
#
#
# Working on iter: 11 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 200
#     SA best fitness: 1556.0
# Iter time: 0.015357017517089844
#
#
# Working on iter: 12 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 200
#     SA best fitness: 1554.0
# Iter time: 0.014827966690063477
#
#
# Working on iter: 13 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 300
#     SA best fitness: 1735.0
# Iter time: 0.017634153366088867
#
#
# Working on iter: 14 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 300
#     SA best fitness: 1624.0
# Iter time: 0.01793694496154785
#
#
# Working on iter: 15 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 300
#     SA best fitness: 1590.0
# Iter time: 0.02163100242614746
#
#
# Working on iter: 16 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 300
#     SA best fitness: 1600.0
# Iter time: 0.020587921142578125
#
#
# Working on iter: 17 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 300
#     SA best fitness: 1584.0
# Iter time: 0.018947124481201172
#
#
# Working on iter: 18 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 300
#     SA best fitness: 1595.0
# Iter time: 0.01970386505126953
#
#
# Working on iter: 19 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 400
#     SA best fitness: 1838.0
# Iter time: 0.019077777862548828
#
#
# Working on iter: 20 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 400
#     SA best fitness: 1663.0
# Iter time: 0.023777008056640625
#
#
# Working on iter: 21 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 400
#     SA best fitness: 1690.0
# Iter time: 0.02375197410583496
#
#
# Working on iter: 22 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 400
#     SA best fitness: 1586.0
# Iter time: 0.02518486976623535
#
#
# Working on iter: 23 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 400
#     SA best fitness: 1586.0
# Iter time: 0.022320270538330078
#
#
# Working on iter: 24 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 400
#     SA best fitness: 1603.0
# Iter time: 0.02271890640258789
#
#
# Working on iter: 25 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 500
#     SA best fitness: 1822.0
# Iter time: 0.02080512046813965
#
#
# Working on iter: 26 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 500
#     SA best fitness: 1863.0
# Iter time: 0.02605891227722168
#
#
# Working on iter: 27 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 500
#     SA best fitness: 1708.0
# Iter time: 0.025913000106811523
#
#
# Working on iter: 28 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 500
#     SA best fitness: 1750.0
# Iter time: 0.02536606788635254
#
#
# Working on iter: 29 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 500
#     SA best fitness: 1664.0
# Iter time: 0.026031017303466797
#
#
# Working on iter: 30 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 500
#     SA best fitness: 1617.0
# Iter time: 0.025731801986694336
#
#
# Working on iter: 31 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 600
#     SA best fitness: 1870.0
# Iter time: 0.02167820930480957
#
#
# Working on iter: 32 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 600
#     SA best fitness: 1832.0
# Iter time: 0.024986982345581055
#
#
# Working on iter: 33 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 600
#     SA best fitness: 1828.0
# Iter time: 0.029140949249267578
#
#
# Working on iter: 34 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 600
#     SA best fitness: 1803.0
# Iter time: 0.030704021453857422
#
#
# Working on iter: 35 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 600
#     SA best fitness: 1786.0
# Iter time: 0.02939581871032715
#
#
# Working on iter: 36 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 600
#     SA best fitness: 1716.0
# Iter time: 0.02999591827392578
#
#
# Working on iter: 37 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 700
#     SA best fitness: 1825.0
# Iter time: 0.01850128173828125
#
#
# Working on iter: 38 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 700
#     SA best fitness: 1801.0
# Iter time: 0.026168107986450195
#
#
# Working on iter: 39 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 700
#     SA best fitness: 1778.0
# Iter time: 0.030604839324951172
#
#
# Working on iter: 40 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 700
#     SA best fitness: 1827.0
# Iter time: 0.0314028263092041
#
#
# Working on iter: 41 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 700
#     SA best fitness: 1818.0
# Iter time: 0.029616117477416992
#
#
# Working on iter: 42 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 700
#     SA best fitness: 1830.0
# Iter time: 0.0331881046295166
#
#
# Working on iter: 43 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 800
#     SA best fitness: 1824.0
# Iter time: 0.019201993942260742
#
#
# Working on iter: 44 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 800
#     SA best fitness: 1851.0
# Iter time: 0.02287578582763672
#
#
# Working on iter: 45 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 800
#     SA best fitness: 1832.0
# Iter time: 0.027423858642578125
#
#
# Working on iter: 46 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 800
#     SA best fitness: 1888.0
# Iter time: 0.03028082847595215
#
#
# Working on iter: 47 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 800
#     SA best fitness: 1868.0
# Iter time: 0.0318148136138916
#
#
# Working on iter: 48 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 800
#     SA best fitness: 1886.0
# Iter time: 0.03667092323303223
#
#
# Working on iter: 49 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 900
#     SA best fitness: 1842.0
# Iter time: 0.018523216247558594
#
#
# Working on iter: 50 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 900
#     SA best fitness: 1823.0
# Iter time: 0.02408289909362793
#
#
# Working on iter: 51 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 900
#     SA best fitness: 1803.0
# Iter time: 0.03076624870300293
#
#
# Working on iter: 52 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 900
#     SA best fitness: 1818.0
# Iter time: 0.02805924415588379
#
#
# Working on iter: 53 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 900
#     SA best fitness: 1834.0
# Iter time: 0.032759666442871094
#
#
# Working on iter: 54 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 900
#     SA best fitness: 1802.0
# Iter time: 0.03125
#
#
# Working on iter: 55 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1000
#     SA best fitness: 1844.0
# Iter time: 0.02144789695739746
#
#
# Working on iter: 56 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1000
#     SA best fitness: 1875.0
# Iter time: 0.024042129516601562
#
#
# Working on iter: 57 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1000
#     SA best fitness: 1823.0
# Iter time: 0.03113389015197754
#
#
# Working on iter: 58 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1000
#     SA best fitness: 1850.0
# Iter time: 0.030879974365234375
#
#
# Working on iter: 59 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1000
#     SA best fitness: 1829.0
# Iter time: 0.03201103210449219
#
#
# Working on iter: 60 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1000
#     SA best fitness: 1823.0
# Iter time: 0.033773183822631836
#
#
# Working on iter: 61 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1100
#     SA best fitness: 1795.0
# Iter time: 0.018193960189819336
#
#
# Working on iter: 62 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1100
#     SA best fitness: 1838.0
# Iter time: 0.026280879974365234
#
#
# Working on iter: 63 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1100
#     SA best fitness: 1839.0
# Iter time: 0.02898693084716797
#
#
# Working on iter: 64 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1100
#     SA best fitness: 1816.0
# Iter time: 0.03298211097717285
#
#
# Working on iter: 65 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1100
#     SA best fitness: 1836.0
# Iter time: 0.03130197525024414
#
#
# Working on iter: 66 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1100
#     SA best fitness: 1827.0
# Iter time: 0.033720970153808594
#
#
# Working on iter: 67 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1200
#     SA best fitness: 1827.0
# Iter time: 0.018728971481323242
#
#
# Working on iter: 68 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1200
#     SA best fitness: 1825.0
# Iter time: 0.023829936981201172
#
#
# Working on iter: 69 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1200
#     SA best fitness: 1818.0
# Iter time: 0.028508901596069336
#
#
# Working on iter: 70 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1200
#     SA best fitness: 1771.0
# Iter time: 0.02898263931274414
#
#
# Working on iter: 71 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1200
#     SA best fitness: 1882.0
# Iter time: 0.03435707092285156
#
#
# Working on iter: 72 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1200
#     SA best fitness: 1835.0
# Iter time: 0.032267093658447266
#
#
# Working on iter: 73 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1300
#     SA best fitness: 1825.0
# Iter time: 0.01943802833557129
#
#
# Working on iter: 74 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1300
#     SA best fitness: 1833.0
# Iter time: 0.027369976043701172
#
#
# Working on iter: 75 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1300
#     SA best fitness: 1862.0
# Iter time: 0.029202938079833984
#
#
# Working on iter: 76 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1300
#     SA best fitness: 1835.0
# Iter time: 0.02865886688232422
#
#
# Working on iter: 77 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1300
#     SA best fitness: 1829.0
# Iter time: 0.03304910659790039
#
#
# Working on iter: 78 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1300
#     SA best fitness: 1775.0
# Iter time: 0.032937049865722656
#
#
# Working on iter: 79 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1400
#     SA best fitness: 1806.0
# Iter time: 0.019433021545410156
#
#
# Working on iter: 80 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1400
#     SA best fitness: 1809.0
# Iter time: 0.02695775032043457
#
#
# Working on iter: 81 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1400
#     SA best fitness: 1828.0
# Iter time: 0.02826690673828125
#
#
# Working on iter: 82 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1400
#     SA best fitness: 1888.0
# Iter time: 0.0298919677734375
#
#
# Working on iter: 83 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1400
#     SA best fitness: 1856.0
# Iter time: 0.03246712684631348
#
#
# Working on iter: 84 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1400
#     SA best fitness: 1829.0
# Iter time: 0.032195091247558594
#
#
# Working on iter: 85 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1500
#     SA best fitness: 1830.0
# Iter time: 0.017351150512695312
#
#
# Working on iter: 86 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1500
#     SA best fitness: 1817.0
# Iter time: 0.02462482452392578
#
#
# Working on iter: 87 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1500
#     SA best fitness: 1862.0
# Iter time: 0.029389142990112305
#
#
# Working on iter: 88 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1500
#     SA best fitness: 1807.0
# Iter time: 0.030765056610107422
#
#
# Working on iter: 89 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1500
#     SA best fitness: 1815.0
# Iter time: 0.03286600112915039
#
#
# Working on iter: 90 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1500
#     SA best fitness: 1840.0
# Iter time: 0.03160905838012695
#
#
# Working on iter: 91 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1600
#     SA best fitness: 1814.0
# Iter time: 0.019499778747558594
#
#
# Working on iter: 92 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1600
#     SA best fitness: 1830.0
# Iter time: 0.025017976760864258
#
#
# Working on iter: 93 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1600
#     SA best fitness: 1838.0
# Iter time: 0.02871394157409668
#
#
# Working on iter: 94 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1600
#     SA best fitness: 1786.0
# Iter time: 0.02954578399658203
#
#
# Working on iter: 95 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1600
#     SA best fitness: 1836.0
# Iter time: 0.032819271087646484
#
#
# Working on iter: 96 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1600
#     SA best fitness: 1837.0
# Iter time: 0.03186297416687012
#
#
# Working on iter: 97 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1700
#     SA best fitness: 1814.0
# Iter time: 0.021494150161743164
#
#
# Working on iter: 98 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1700
#     SA best fitness: 1835.0
# Iter time: 0.025875091552734375
#
#
# Working on iter: 99 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1700
#     SA best fitness: 1779.0
# Iter time: 0.026536941528320312
#
#
# Working on iter: 100 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1700
#     SA best fitness: 1821.0
# Iter time: 0.030765056610107422
#
#
# Working on iter: 101 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1700
#     SA best fitness: 1871.0
# Iter time: 0.031259775161743164
#
#
# Working on iter: 102 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1700
#     SA best fitness: 1845.0
# Iter time: 0.03270697593688965
#
#
# Working on iter: 103 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1800
#     SA best fitness: 1816.0
# Iter time: 0.018501758575439453
#
#
# Working on iter: 104 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1800
#     SA best fitness: 1820.0
# Iter time: 0.025784730911254883
#
#
# Working on iter: 105 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1800
#     SA best fitness: 1890.0
# Iter time: 0.03007197380065918
#
#
# Working on iter: 106 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1800
#     SA best fitness: 1817.0
# Iter time: 0.03184318542480469
#
#
# Working on iter: 107 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1800
#     SA best fitness: 1803.0
# Iter time: 0.029972076416015625
#
#
# Working on iter: 108 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1800
#     SA best fitness: 1890.0
# Iter time: 0.03501105308532715
#
#
# Working on iter: 109 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1900
#     SA best fitness: 1793.0
# Iter time: 0.022054195404052734
#
#
# Working on iter: 110 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1900
#     SA best fitness: 1868.0
# Iter time: 0.02543497085571289
#
#
# Working on iter: 111 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1900
#     SA best fitness: 1869.0
# Iter time: 0.025931119918823242
#
#
# Working on iter: 112 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1900
#     SA best fitness: 1828.0
# Iter time: 0.028252840042114258
#
#
# Working on iter: 113 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1900
#     SA best fitness: 1911.0
# Iter time: 0.03631782531738281
#
#
# Working on iter: 114 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1900
#     SA best fitness: 1833.0
# Iter time: 0.03244423866271973
#
#
# Working on iter: 115 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 2000
#     SA best fitness: 1872.0
# Iter time: 0.020653963088989258
#
#
# Working on iter: 116 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 2000
#     SA best fitness: 1849.0
# Iter time: 0.02491593360900879
#
#
# Working on iter: 117 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 2000
#     SA best fitness: 1835.0
# Iter time: 0.027459144592285156
#
#
# Working on iter: 118 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 2000
#     SA best fitness: 1824.0
# Iter time: 0.031903982162475586
#
#
# Working on iter: 119 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 2000
#     SA best fitness: 1796.0
# Iter time: 0.031244993209838867
#
#
# Working on iter: 120 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 2000
#     SA best fitness: 1803.0
# Iter time: 0.032972097396850586
#
#
# Done.

# %% [markdown]
# ## FlipFlop

# %%
#Inputs for FlipFlop problem
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
fitness_fn = mlrose.FlipFlop()

#Initialize an empty data frame for recording results
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
flip_flop_results = pd.DataFrame(columns = ["algorithm",
                                            "length",
                                            "init_temp",
                                            "max_attempt",
                                            "max_iter",
                                            "best_fitness",
                                            "time",
                                            "function_evaluations"])

#Loop
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Start an iteration counter
iter = 1
#For each unique number of objects
for length in lengths:
    
    #Set the optimization problem object
    problem = mlrose.DiscreteOpt(length = length,
                                 fitness_fn = fitness_fn,
                                 maximize = True,
                                 max_val = max_val)
    
    #For each combination of max attempt, max iteration, and random restart
    for max_attempt in max_attempts:
        for max_iter in max_iters:
            for init_temp in init_temps:
                
                #Ensuring reproducibility
                random_state = iter
                
                #Simulated Annealing: decay schedule for temperature
                schedule = mlrose.ExpDecay(init_temp = init_temp,
                                           exp_const = exp_const,
                                           min_temp = min_temp)
                    
                #Start a timer for each iteration
                start = time.time()
                    
                #Print message
                print("Working on iter:", iter,
                      "Length:", length,
                      "Init_temp:", init_temp,
                      "Max attempt:", max_attempt,
                      "Max iter:", max_iter)

                
                #Simulated Annealing
                #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
                #Start the timer for Simulated Annealing
                sa_start = time.time()
                
                #Optimization
                (sa_best_state,
                 sa_best_fitness,
                 sa_fitness_curve) = mlrose.simulated_annealing(problem = problem,
                                                                schedule = schedule,
                                                                max_attempts = max_attempt,
                                                                max_iters = max_iter,
                                                                init_state = init_state,
                                                                curve = curve,
                                                                random_state = random_state)
                #End the timer
                sa_end = time.time()
                #Get the total time
                sa_time = sa_end - sa_start
                
                #Message
                print("    SA best fitness:", sa_best_fitness)
                
                #Add to results list
                flip_flop_results = flip_flop_results.append({"algorithm": "simulated_annealing",
                                                              "length": length,
                                                              "init_temp": init_temp,
                                                              "max_attempt": max_attempt,
                                                              "max_iter": max_iter,
                                                              "best_fitness": sa_best_fitness,
                                                              "time": sa_time,
                                                              "function_evaluations": np.argmax(sa_fitness_curve) + 1},
                                                               ignore_index = True)

                
                end = time.time()
                iter_time = end - start
                print("Iter time:", iter_time)
                
                print("\n")
                iter = iter + 1

#Output results
flip_flop_results.to_csv(output_flip_flop + "flip_flop_sa.csv", index = False)
pd.DataFrame(sa_fitness_curve).to_csv(output_flip_flop + "flip_flop_sa_curve.csv", index = False)

#Done
print("Done.")
# Out:
# Working on iter: 1 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 100
#     SA best fitness: 487.0
# Iter time: 0.05822420120239258
#
#
# Working on iter: 2 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 100
#     SA best fitness: 471.0
# Iter time: 0.05867505073547363
#
#
# Working on iter: 3 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 100
#     SA best fitness: 495.0
# Iter time: 0.058275699615478516
#
#
# Working on iter: 4 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 100
#     SA best fitness: 500.0
# Iter time: 0.06171107292175293
#
#
# Working on iter: 5 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 100
#     SA best fitness: 510.0
# Iter time: 0.0606389045715332
#
#
# Working on iter: 6 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 100
#     SA best fitness: 494.0
# Iter time: 0.061972856521606445
#
#
# Working on iter: 7 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 200
#     SA best fitness: 549.0
# Iter time: 0.11116528511047363
#
#
# Working on iter: 8 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 200
#     SA best fitness: 512.0
# Iter time: 0.11628603935241699
#
#
# Working on iter: 9 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 200
#     SA best fitness: 475.0
# Iter time: 0.11506390571594238
#
#
# Working on iter: 10 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 200
#     SA best fitness: 512.0
# Iter time: 0.11703968048095703
#
#
# Working on iter: 11 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 200
#     SA best fitness: 482.0
# Iter time: 0.11774063110351562
#
#
# Working on iter: 12 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 200
#     SA best fitness: 514.0
# Iter time: 0.11646103858947754
#
#
# Working on iter: 13 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 300
#     SA best fitness: 578.0
# Iter time: 0.15840816497802734
#
#
# Working on iter: 14 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 300
#     SA best fitness: 552.0
# Iter time: 0.16863608360290527
#
#
# Working on iter: 15 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 300
#     SA best fitness: 530.0
# Iter time: 0.1720421314239502
#
#
# Working on iter: 16 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 300
#     SA best fitness: 496.0
# Iter time: 0.1716148853302002
#
#
# Working on iter: 17 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 300
#     SA best fitness: 500.0
# Iter time: 0.1742720603942871
#
#
# Working on iter: 18 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 300
#     SA best fitness: 517.0
# Iter time: 0.17173194885253906
#
#
# Working on iter: 19 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 400
#     SA best fitness: 603.0
# Iter time: 0.20385098457336426
#
#
# Working on iter: 20 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 400
#     SA best fitness: 572.0
# Iter time: 0.22397112846374512
#
#
# Working on iter: 21 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 400
#     SA best fitness: 516.0
# Iter time: 0.22051215171813965
#
#
# Working on iter: 22 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 400
#     SA best fitness: 518.0
# Iter time: 0.222900390625
#
#
# Working on iter: 23 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 400
#     SA best fitness: 544.0
# Iter time: 0.22640371322631836
#
#
# Working on iter: 24 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 400
#     SA best fitness: 527.0
# Iter time: 0.22503280639648438
#
#
# Working on iter: 25 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 500
#     SA best fitness: 629.0
# Iter time: 0.25269293785095215
#
#
# Working on iter: 26 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 500
#     SA best fitness: 594.0
# Iter time: 0.26960206031799316
#
#
# Working on iter: 27 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 500
#     SA best fitness: 552.0
# Iter time: 0.2774488925933838
#
#
# Working on iter: 28 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 500
#     SA best fitness: 529.0
# Iter time: 0.2785530090332031
#
#
# Working on iter: 29 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 500
#     SA best fitness: 551.0
# Iter time: 0.27962207794189453
#
#
# Working on iter: 30 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 500
#     SA best fitness: 521.0
# Iter time: 0.2789580821990967
#
#
# Working on iter: 31 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 600
#     SA best fitness: 675.0
# Iter time: 0.29832005500793457
#
#
# Working on iter: 32 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 600
#     SA best fitness: 647.0
# Iter time: 0.3123331069946289
#
#
# Working on iter: 33 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 600
#     SA best fitness: 602.0
# Iter time: 0.3174457550048828
#
#
# Working on iter: 34 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 600
#     SA best fitness: 576.0
# Iter time: 0.33228206634521484
#
#
# Working on iter: 35 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 600
#     SA best fitness: 556.0
# Iter time: 0.3317849636077881
#
#
# Working on iter: 36 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 600
#     SA best fitness: 582.0
# Iter time: 0.3285861015319824
#
#
# Working on iter: 37 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 700
#     SA best fitness: 677.0
# Iter time: 0.3395392894744873
#
#
# Working on iter: 38 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 700
#     SA best fitness: 645.0
# Iter time: 0.3650069236755371
#
#
# Working on iter: 39 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 700
#     SA best fitness: 609.0
# Iter time: 0.36983489990234375
#
#
# Working on iter: 40 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 700
#     SA best fitness: 619.0
# Iter time: 0.3731648921966553
#
#
# Working on iter: 41 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 700
#     SA best fitness: 627.0
# Iter time: 0.37528300285339355
#
#
# Working on iter: 42 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 700
#     SA best fitness: 608.0
# Iter time: 0.3771519660949707
#
#
# Working on iter: 43 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 800
#     SA best fitness: 696.0
# Iter time: 0.39297008514404297
#
#
# Working on iter: 44 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 800
#     SA best fitness: 639.0
# Iter time: 0.4145369529724121
#
#
# Working on iter: 45 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 800
#     SA best fitness: 647.0
# Iter time: 0.4138669967651367
#
#
# Working on iter: 46 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 800
#     SA best fitness: 630.0
# Iter time: 0.41916894912719727
#
#
# Working on iter: 47 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 800
#     SA best fitness: 617.0
# Iter time: 0.4270339012145996
#
#
# Working on iter: 48 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 800
#     SA best fitness: 607.0
# Iter time: 0.42285680770874023
#
#
# Working on iter: 49 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 900
#     SA best fitness: 711.0
# Iter time: 0.4333360195159912
#
#
# Working on iter: 50 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 900
#     SA best fitness: 668.0
# Iter time: 0.45467090606689453
#
#
# Working on iter: 51 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 900
#     SA best fitness: 672.0
# Iter time: 0.4574167728424072
#
#
# Working on iter: 52 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 900
#     SA best fitness: 678.0
# Iter time: 0.46300387382507324
#
#
# Working on iter: 53 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 900
#     SA best fitness: 662.0
# Iter time: 0.4729499816894531
#
#
# Working on iter: 54 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 900
#     SA best fitness: 642.0
# Iter time: 0.47825169563293457
#
#
# Working on iter: 55 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1000
#     SA best fitness: 731.0
# Iter time: 0.49370598793029785
#
#
# Working on iter: 56 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1000
#     SA best fitness: 704.0
# Iter time: 0.5049300193786621
#
#
# Working on iter: 57 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1000
#     SA best fitness: 683.0
# Iter time: 0.5126080513000488
#
#
# Working on iter: 58 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1000
#     SA best fitness: 681.0
# Iter time: 0.5101199150085449
#
#
# Working on iter: 59 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1000
#     SA best fitness: 677.0
# Iter time: 0.520535945892334
#
#
# Working on iter: 60 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1000
#     SA best fitness: 682.0
# Iter time: 0.512897253036499
#
#
# Working on iter: 61 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1100
#     SA best fitness: 738.0
# Iter time: 0.5186140537261963
#
#
# Working on iter: 62 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1100
#     SA best fitness: 709.0
# Iter time: 0.5448601245880127
#
#
# Working on iter: 63 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1100
#     SA best fitness: 718.0
# Iter time: 0.5506739616394043
#
#
# Working on iter: 64 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1100
#     SA best fitness: 688.0
# Iter time: 0.5613069534301758
#
#
# Working on iter: 65 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1100
#     SA best fitness: 700.0
# Iter time: 0.5686049461364746
#
#
# Working on iter: 66 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1100
#     SA best fitness: 692.0
# Iter time: 0.5743908882141113
#
#
# Working on iter: 67 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1200
#     SA best fitness: 753.0
# Iter time: 0.5638000965118408
#
#
# Working on iter: 68 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1200
#     SA best fitness: 717.0
# Iter time: 0.5915608406066895
#
#
# Working on iter: 69 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1200
#     SA best fitness: 717.0
# Iter time: 0.5981659889221191
#
#
# Working on iter: 70 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1200
#     SA best fitness: 721.0
# Iter time: 0.6056859493255615
#
#
# Working on iter: 71 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1200
#     SA best fitness: 703.0
# Iter time: 0.6149859428405762
#
#
# Working on iter: 72 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1200
#     SA best fitness: 694.0
# Iter time: 0.612097978591919
#
#
# Working on iter: 73 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1300
#     SA best fitness: 742.0
# Iter time: 0.6219849586486816
#
#
# Working on iter: 74 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1300
#     SA best fitness: 753.0
# Iter time: 0.6693398952484131
#
#
# Working on iter: 75 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1300
#     SA best fitness: 705.0
# Iter time: 0.6740808486938477
#
#
# Working on iter: 76 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1300
#     SA best fitness: 736.0
# Iter time: 0.7067010402679443
#
#
# Working on iter: 77 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1300
#     SA best fitness: 719.0
# Iter time: 0.8591969013214111
#
#
# Working on iter: 78 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1300
#     SA best fitness: 711.0
# Iter time: 0.886397123336792
#
#
# Working on iter: 79 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1400
#     SA best fitness: 763.0
# Iter time: 0.9878411293029785
#
#
# Working on iter: 80 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1400
#     SA best fitness: 745.0
# Iter time: 0.9399161338806152
#
#
# Working on iter: 81 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1400
#     SA best fitness: 736.0
# Iter time: 1.0088350772857666
#
#
# Working on iter: 82 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1400
#     SA best fitness: 722.0
# Iter time: 0.9908792972564697
#
#
# Working on iter: 83 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1400
#     SA best fitness: 732.0
# Iter time: 0.9823076725006104
#
#
# Working on iter: 84 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1400
#     SA best fitness: 748.0
# Iter time: 1.0123298168182373
#
#
# Working on iter: 85 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1500
#     SA best fitness: 773.0
# Iter time: 1.008753776550293
#
#
# Working on iter: 86 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1500
#     SA best fitness: 763.0
# Iter time: 1.111929178237915
#
#
# Working on iter: 87 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1500
#     SA best fitness: 775.0
# Iter time: 0.9750549793243408
#
#
# Working on iter: 88 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1500
#     SA best fitness: 742.0
# Iter time: 0.9782359600067139
#
#
# Working on iter: 89 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1500
#     SA best fitness: 733.0
# Iter time: 1.129638910293579
#
#
# Working on iter: 90 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1500
#     SA best fitness: 759.0
# Iter time: 0.9896278381347656
#
#
# Working on iter: 91 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1600
#     SA best fitness: 765.0
# Iter time: 1.073084831237793
#
#
# Working on iter: 92 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1600
#     SA best fitness: 786.0
# Iter time: 0.966008186340332
#
#
# Working on iter: 93 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1600
#     SA best fitness: 756.0
# Iter time: 1.0915770530700684
#
#
# Working on iter: 94 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1600
#     SA best fitness: 760.0
# Iter time: 1.0688471794128418
#
#
# Working on iter: 95 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1600
#     SA best fitness: 742.0
# Iter time: 1.1134288311004639
#
#
# Working on iter: 96 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1600
#     SA best fitness: 741.0
# Iter time: 1.1517658233642578
#
#
# Working on iter: 97 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1700
#     SA best fitness: 780.0
# Iter time: 1.1611928939819336
#
#
# Working on iter: 98 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1700
#     SA best fitness: 783.0
# Iter time: 1.174389123916626
#
#
# Working on iter: 99 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1700
#     SA best fitness: 774.0
# Iter time: 1.0643770694732666
#
#
# Working on iter: 100 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1700
#     SA best fitness: 775.0
# Iter time: 1.1978302001953125
#
#
# Working on iter: 101 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1700
#     SA best fitness: 766.0
# Iter time: 1.1734130382537842
#
#
# Working on iter: 102 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1700
#     SA best fitness: 747.0
# Iter time: 1.2117629051208496
#
#
# Working on iter: 103 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1800
#     SA best fitness: 807.0
# Iter time: 1.0695979595184326
#
#
# Working on iter: 104 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1800
#     SA best fitness: 789.0
# Iter time: 1.084550142288208
#
#
# Working on iter: 105 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1800
#     SA best fitness: 773.0
# Iter time: 1.2140681743621826
#
#
# Working on iter: 106 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1800
#     SA best fitness: 768.0
# Iter time: 1.2894656658172607
#
#
# Working on iter: 107 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1800
#     SA best fitness: 768.0
# Iter time: 1.2046101093292236
#
#
# Working on iter: 108 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1800
#     SA best fitness: 792.0
# Iter time: 1.2224769592285156
#
#
# Working on iter: 109 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1900
#     SA best fitness: 785.0
# Iter time: 1.2480530738830566
#
#
# Working on iter: 110 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1900
#     SA best fitness: 790.0
# Iter time: 1.266752004623413
#
#
# Working on iter: 111 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1900
#     SA best fitness: 768.0
# Iter time: 1.2458338737487793
#
#
# Working on iter: 112 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1900
#     SA best fitness: 776.0
# Iter time: 1.2090859413146973
#
#
# Working on iter: 113 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1900
#     SA best fitness: 774.0
# Iter time: 1.2935168743133545
#
#
# Working on iter: 114 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1900
#     SA best fitness: 767.0
# Iter time: 1.257659912109375
#
#
# Working on iter: 115 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 2000
#     SA best fitness: 805.0
# Iter time: 1.3183038234710693
#
#
# Working on iter: 116 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 2000
#     SA best fitness: 784.0
# Iter time: 1.3041999340057373
#
#
# Working on iter: 117 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 2000
#     SA best fitness: 805.0
# Iter time: 1.423064947128296
#
#
# Working on iter: 118 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 2000
#     SA best fitness: 799.0
# Iter time: 1.2744641304016113
#
#
# Working on iter: 119 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 2000
#     SA best fitness: 796.0
# Iter time: 1.303048849105835
#
#
# Working on iter: 120 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 2000
#     SA best fitness: 788.0
# Iter time: 1.3648407459259033
#
#
# Done.

# %% [markdown]
# ### OneMax

# %%
#Inputs for FlipFlop problem
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
fitness_fn = mlrose.OneMax()

#Initialize an empty data frame for recording results
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
one_max_results = pd.DataFrame(columns = ["algorithm",
                                          "length",
                                          "init_temp",
                                          "max_attempt",
                                          "max_iter",
                                          "best_fitness",
                                          "time",
                                          "function_evaluations"])

#Loop
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Start an iteration counter
iter = 1
#For each unique number of objects
for length in lengths:
    
    #Set the optimization problem object
    problem = mlrose.DiscreteOpt(length = length,
                                 fitness_fn = fitness_fn,
                                 maximize = True,
                                 max_val = max_val)
    
    #For each combination of max attempt, max iteration, and random restart
    for max_attempt in max_attempts:
        for max_iter in max_iters:
            for init_temp in init_temps:
                
                #Ensuring reproducibility
                random_state = iter
                
                #Simulated Annealing: decay schedule for temperature
                schedule = mlrose.ExpDecay(init_temp = init_temp,
                                           exp_const = exp_const,
                                           min_temp = min_temp)
                
                #Start a timer for each iteration
                start = time.time()
                    
                #Print message
                print("Working on iter:", iter,
                      "Length:", length,
                      "Init_temp:", init_temp,
                      "Max attempt:", max_attempt,
                      "Max iter:", max_iter)

                #Simulated Annealing
                #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
                #Start the timer for Simulated Annealing
                sa_start = time.time()
                
                #Optimization
                (sa_best_state,
                 sa_best_fitness,
                 sa_fitness_curve) = mlrose.simulated_annealing(problem = problem,
                                                                schedule = schedule,
                                                                max_attempts = max_attempt,
                                                                max_iters = max_iter,
                                                                init_state = init_state,
                                                                curve = curve,
                                                                random_state = random_state)
                #End the timer
                sa_end = time.time()
                #Get the total time
                sa_time = sa_end - sa_start
                
                #Message
                print("    SA best fitness:", sa_best_fitness)
                
                #Add to results list
                one_max_results = one_max_results.append({"algorithm": "simulated_annealing",
                                                          "length": length,
                                                          "init_temp": init_temp,
                                                          "max_attempt": max_attempt,
                                                          "max_iter": max_iter,
                                                          "best_fitness": sa_best_fitness,
                                                          "time": sa_time,
                                                          "function_evaluations": np.argmax(sa_fitness_curve) + 1},
                                                          ignore_index = True)
                
                end = time.time()
                iter_time = end - start
                print("Iter time:", iter_time)
                
                print("\n")
                iter = iter + 1

#Output results
one_max_results.to_csv(output_one_max + "one_max_sa.csv", index = False)
pd.DataFrame(sa_fitness_curve).to_csv(output_one_max + "one_max_sa_curve.csv", index = False)

#Done
print("Done.")
# Out:
# Working on iter: 1 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 100
#     SA best fitness: 483.0
# Iter time: 0.010927200317382812
#
#
# Working on iter: 2 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 100
#     SA best fitness: 506.0
# Iter time: 0.007892847061157227
#
#
# Working on iter: 3 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 100
#     SA best fitness: 490.0
# Iter time: 0.007279872894287109
#
#
# Working on iter: 4 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 100
#     SA best fitness: 505.0
# Iter time: 0.011870861053466797
#
#
# Working on iter: 5 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 100
#     SA best fitness: 501.0
# Iter time: 0.011682748794555664
#
#
# Working on iter: 6 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 100
#     SA best fitness: 502.0
# Iter time: 0.04352903366088867
#
#
# Working on iter: 7 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 200
#     SA best fitness: 526.0
# Iter time: 0.014731884002685547
#
#
# Working on iter: 8 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 200
#     SA best fitness: 521.0
# Iter time: 0.05011105537414551
#
#
# Working on iter: 9 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 200
#     SA best fitness: 498.0
# Iter time: 0.01466822624206543
#
#
# Working on iter: 10 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 200
#     SA best fitness: 500.0
# Iter time: 0.02182912826538086
#
#
# Working on iter: 11 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 200
#     SA best fitness: 508.0
# Iter time: 0.015284061431884766
#
#
# Working on iter: 12 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 200
#     SA best fitness: 518.0
# Iter time: 0.011730194091796875
#
#
# Working on iter: 13 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 300
#     SA best fitness: 538.0
# Iter time: 0.013698101043701172
#
#
# Working on iter: 14 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 300
#     SA best fitness: 514.0
# Iter time: 0.014966011047363281
#
#
# Working on iter: 15 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 300
#     SA best fitness: 519.0
# Iter time: 0.01574087142944336
#
#
# Working on iter: 16 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 300
#     SA best fitness: 513.0
# Iter time: 0.015284061431884766
#
#
# Working on iter: 17 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 300
#     SA best fitness: 509.0
# Iter time: 0.015687942504882812
#
#
# Working on iter: 18 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 300
#     SA best fitness: 524.0
# Iter time: 0.019418954849243164
#
#
# Working on iter: 19 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 400
#     SA best fitness: 605.0
# Iter time: 0.0428929328918457
#
#
# Working on iter: 20 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 400
#     SA best fitness: 530.0
# Iter time: 0.04422497749328613
#
#
# Working on iter: 21 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 400
#     SA best fitness: 527.0
# Iter time: 0.05714988708496094
#
#
# Working on iter: 22 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 400
#     SA best fitness: 510.0
# Iter time: 0.0211031436920166
#
#
# Working on iter: 23 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 400
#     SA best fitness: 518.0
# Iter time: 0.023300886154174805
#
#
# Working on iter: 24 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 400
#     SA best fitness: 501.0
# Iter time: 0.020734786987304688
#
#
# Working on iter: 25 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 500
#     SA best fitness: 606.0
# Iter time: 0.02501392364501953
#
#
# Working on iter: 26 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 500
#     SA best fitness: 582.0
# Iter time: 0.02613091468811035
#
#
# Working on iter: 27 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 500
#     SA best fitness: 547.0
# Iter time: 0.04163217544555664
#
#
# Working on iter: 28 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 500
#     SA best fitness: 524.0
# Iter time: 0.04403805732727051
#
#
# Working on iter: 29 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 500
#     SA best fitness: 527.0
# Iter time: 0.04433894157409668
#
#
# Working on iter: 30 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 500
#     SA best fitness: 519.0
# Iter time: 0.03249526023864746
#
#
# Working on iter: 31 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 600
#     SA best fitness: 640.0
# Iter time: 0.023897886276245117
#
#
# Working on iter: 32 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 600
#     SA best fitness: 632.0
# Iter time: 0.026223182678222656
#
#
# Working on iter: 33 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 600
#     SA best fitness: 575.0
# Iter time: 0.025952816009521484
#
#
# Working on iter: 34 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 600
#     SA best fitness: 572.0
# Iter time: 0.03280186653137207
#
#
# Working on iter: 35 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 600
#     SA best fitness: 546.0
# Iter time: 0.03255295753479004
#
#
# Working on iter: 36 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 600
#     SA best fitness: 533.0
# Iter time: 0.04903602600097656
#
#
# Working on iter: 37 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 700
#     SA best fitness: 718.0
# Iter time: 0.037470102310180664
#
#
# Working on iter: 38 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 700
#     SA best fitness: 620.0
# Iter time: 0.03305387496948242
#
#
# Working on iter: 39 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 700
#     SA best fitness: 614.0
# Iter time: 0.02656102180480957
#
#
# Working on iter: 40 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 700
#     SA best fitness: 588.0
# Iter time: 0.027579784393310547
#
#
# Working on iter: 41 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 700
#     SA best fitness: 608.0
# Iter time: 0.05924868583679199
#
#
# Working on iter: 42 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 700
#     SA best fitness: 581.0
# Iter time: 0.04823780059814453
#
#
# Working on iter: 43 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 800
#     SA best fitness: 718.0
# Iter time: 0.06846380233764648
#
#
# Working on iter: 44 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 800
#     SA best fitness: 698.0
# Iter time: 0.030472755432128906
#
#
# Working on iter: 45 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 800
#     SA best fitness: 672.0
# Iter time: 0.03032088279724121
#
#
# Working on iter: 46 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 800
#     SA best fitness: 657.0
# Iter time: 0.029040813446044922
#
#
# Working on iter: 47 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 800
#     SA best fitness: 632.0
# Iter time: 0.037735939025878906
#
#
# Working on iter: 48 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 800
#     SA best fitness: 602.0
# Iter time: 0.07837295532226562
#
#
# Working on iter: 49 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 900
#     SA best fitness: 702.0
# Iter time: 0.08891963958740234
#
#
# Working on iter: 50 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 900
#     SA best fitness: 728.0
# Iter time: 0.035440921783447266
#
#
# Working on iter: 51 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 900
#     SA best fitness: 669.0
# Iter time: 0.03268790245056152
#
#
# Working on iter: 52 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 900
#     SA best fitness: 712.0
# Iter time: 0.03440999984741211
#
#
# Working on iter: 53 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 900
#     SA best fitness: 652.0
# Iter time: 0.03668832778930664
#
#
# Working on iter: 54 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 900
#     SA best fitness: 665.0
# Iter time: 0.058219194412231445
#
#
# Working on iter: 55 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1000
#     SA best fitness: 774.0
# Iter time: 0.08301901817321777
#
#
# Working on iter: 56 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1000
#     SA best fitness: 758.0
# Iter time: 0.042349815368652344
#
#
# Working on iter: 57 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1000
#     SA best fitness: 723.0
# Iter time: 0.0335240364074707
#
#
# Working on iter: 58 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1000
#     SA best fitness: 705.0
# Iter time: 0.03511810302734375
#
#
# Working on iter: 59 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1000
#     SA best fitness: 705.0
# Iter time: 0.03831315040588379
#
#
# Working on iter: 60 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1000
#     SA best fitness: 687.0
# Iter time: 0.06740999221801758
#
#
# Working on iter: 61 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1100
#     SA best fitness: 781.0
# Iter time: 0.05983901023864746
#
#
# Working on iter: 62 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1100
#     SA best fitness: 771.0
# Iter time: 0.03391218185424805
#
#
# Working on iter: 63 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1100
#     SA best fitness: 753.0
# Iter time: 0.033354997634887695
#
#
# Working on iter: 64 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1100
#     SA best fitness: 718.0
# Iter time: 0.03550004959106445
#
#
# Working on iter: 65 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1100
#     SA best fitness: 727.0
# Iter time: 0.06934809684753418
#
#
# Working on iter: 66 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1100
#     SA best fitness: 713.0
# Iter time: 0.0866539478302002
#
#
# Working on iter: 67 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1200
#     SA best fitness: 666.0
# Iter time: 0.029697895050048828
#
#
# Working on iter: 68 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1200
#     SA best fitness: 794.0
# Iter time: 0.03905510902404785
#
#
# Working on iter: 69 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1200
#     SA best fitness: 779.0
# Iter time: 0.035121917724609375
#
#
# Working on iter: 70 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1200
#     SA best fitness: 788.0
# Iter time: 0.04364585876464844
#
#
# Working on iter: 71 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1200
#     SA best fitness: 753.0
# Iter time: 0.07082891464233398
#
#
# Working on iter: 72 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1200
#     SA best fitness: 744.0
# Iter time: 0.06304001808166504
#
#
# Working on iter: 73 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1300
#     SA best fitness: 842.0
# Iter time: 0.04520678520202637
#
#
# Working on iter: 74 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1300
#     SA best fitness: 813.0
# Iter time: 0.04387998580932617
#
#
# Working on iter: 75 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1300
#     SA best fitness: 793.0
# Iter time: 0.04509091377258301
#
#
# Working on iter: 76 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1300
#     SA best fitness: 791.0
# Iter time: 0.08484482765197754
#
#
# Working on iter: 77 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1300
#     SA best fitness: 780.0
# Iter time: 0.08830595016479492
#
#
# Working on iter: 78 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1300
#     SA best fitness: 758.0
# Iter time: 0.04204893112182617
#
#
# Working on iter: 79 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1400
#     SA best fitness: 791.0
# Iter time: 0.038728952407836914
#
#
# Working on iter: 80 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1400
#     SA best fitness: 808.0
# Iter time: 0.04474067687988281
#
#
# Working on iter: 81 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1400
#     SA best fitness: 750.0
# Iter time: 0.06520295143127441
#
#
# Working on iter: 82 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1400
#     SA best fitness: 797.0
# Iter time: 0.10511183738708496
#
#
# Working on iter: 83 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1400
#     SA best fitness: 719.0
# Iter time: 0.03299117088317871
#
#
# Working on iter: 84 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1400
#     SA best fitness: 811.0
# Iter time: 0.04333901405334473
#
#
# Working on iter: 85 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1500
#     SA best fitness: 807.0
# Iter time: 0.039196014404296875
#
#
# Working on iter: 86 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1500
#     SA best fitness: 810.0
# Iter time: 0.06708216667175293
#
#
# Working on iter: 87 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1500
#     SA best fitness: 836.0
# Iter time: 0.1014869213104248
#
#
# Working on iter: 88 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1500
#     SA best fitness: 822.0
# Iter time: 0.04314899444580078
#
#
# Working on iter: 89 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1500
#     SA best fitness: 803.0
# Iter time: 0.04481983184814453
#
#
# Working on iter: 90 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1500
#     SA best fitness: 819.0
# Iter time: 0.06319904327392578
#
#
# Working on iter: 91 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1600
#     SA best fitness: 771.0
# Iter time: 0.08947372436523438
#
#
# Working on iter: 92 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1600
#     SA best fitness: 853.0
# Iter time: 0.06055092811584473
#
#
# Working on iter: 93 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1600
#     SA best fitness: 848.0
# Iter time: 0.04673314094543457
#
#
# Working on iter: 94 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1600
#     SA best fitness: 738.0
# Iter time: 0.036875009536743164
#
#
# Working on iter: 95 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1600
#     SA best fitness: 753.0
# Iter time: 0.05092597007751465
#
#
# Working on iter: 96 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1600
#     SA best fitness: 843.0
# Iter time: 0.10797691345214844
#
#
# Working on iter: 97 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1700
#     SA best fitness: 840.0
# Iter time: 0.042092084884643555
#
#
# Working on iter: 98 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1700
#     SA best fitness: 833.0
# Iter time: 0.04432487487792969
#
#
# Working on iter: 99 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1700
#     SA best fitness: 805.0
# Iter time: 0.09739112854003906
#
#
# Working on iter: 100 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1700
#     SA best fitness: 780.0
# Iter time: 0.09400701522827148
#
#
# Working on iter: 101 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1700
#     SA best fitness: 827.0
# Iter time: 0.05486321449279785
#
#
# Working on iter: 102 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1700
#     SA best fitness: 791.0
# Iter time: 0.04237008094787598
#
#
# Working on iter: 103 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1800
#     SA best fitness: 712.0
# Iter time: 0.03280901908874512
#
#
# Working on iter: 104 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1800
#     SA best fitness: 821.0
# Iter time: 0.0790090560913086
#
#
# Working on iter: 105 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1800
#     SA best fitness: 807.0
# Iter time: 0.07452178001403809
#
#
# Working on iter: 106 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1800
#     SA best fitness: 668.0
# Iter time: 0.037320852279663086
#
#
# Working on iter: 107 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1800
#     SA best fitness: 831.0
# Iter time: 0.045310020446777344
#
#
# Working on iter: 108 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1800
#     SA best fitness: 799.0
# Iter time: 0.10225224494934082
#
#
# Working on iter: 109 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 1900
#     SA best fitness: 839.0
# Iter time: 0.07852911949157715
#
#
# Working on iter: 110 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 1900
#     SA best fitness: 782.0
# Iter time: 0.05088996887207031
#
#
# Working on iter: 111 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 1900
#     SA best fitness: 872.0
# Iter time: 0.05118894577026367
#
#
# Working on iter: 112 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 1900
#     SA best fitness: 818.0
# Iter time: 0.0550847053527832
#
#
# Working on iter: 113 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 1900
#     SA best fitness: 791.0
# Iter time: 0.06934285163879395
#
#
# Working on iter: 114 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 1900
#     SA best fitness: 852.0
# Iter time: 0.11461901664733887
#
#
# Working on iter: 115 Length: 1000 Init_temp: 10 Max attempt: 20 Max iter: 2000
#     SA best fitness: 838.0
# Iter time: 0.0391538143157959
#
#
# Working on iter: 116 Length: 1000 Init_temp: 50 Max attempt: 20 Max iter: 2000
#     SA best fitness: 799.0
# Iter time: 0.039174795150756836
#
#
# Working on iter: 117 Length: 1000 Init_temp: 100 Max attempt: 20 Max iter: 2000
#     SA best fitness: 829.0
# Iter time: 0.09643387794494629
#
#
# Working on iter: 118 Length: 1000 Init_temp: 150 Max attempt: 20 Max iter: 2000
#     SA best fitness: 757.0
# Iter time: 0.09535622596740723
#
#
# Working on iter: 119 Length: 1000 Init_temp: 200 Max attempt: 20 Max iter: 2000
#     SA best fitness: 821.0
# Iter time: 0.05185198783874512
#
#
# Working on iter: 120 Length: 1000 Init_temp: 250 Max attempt: 20 Max iter: 2000
#     SA best fitness: 712.0
# Iter time: 0.03690171241760254
#
#
# Done.
