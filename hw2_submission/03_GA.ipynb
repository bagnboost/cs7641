# %% [markdown]
# # Randomized optimization
#
# Plaigiarism note: I partially took this course in 2020 so some of the analysis and text is repeated.

# %% [markdown]
# mlrose procedure:
#
# 1. Define a fitness function
# - This is the function we want to maximize or minimize, and is used to evaluate the fitness of a state vector.
# 2. Define an optimization problem object
# 3. Select and run a randomized optimization algorithm
#
# mlrose fitness functions: https://mlrose.readthedocs.io/en/stable/source/fitness.html

# %% [markdown]
# ## Load libraries

# %%
import six
import sys
sys.modules['sklearn.externals.six'] = six
import mlrose
import numpy as np
import pandas as pd
import time
from sklearn.preprocessing import normalize
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Set directories

# %%
directory_hw1 = "/Users/mikepecorino/Documents/machine_learning/HW1/"
directory_hw2 = "/Users/mikepecorino/Documents/machine_learning/HW2/"
output_four_peaks = directory_hw2 + "four_peaks/"
output_knapsack = directory_hw2 + "knapsack/"
output_flip_flop = directory_hw2 + "flip_flop/"
output_one_max = directory_hw2 + "one_max/"

# %% [markdown]
# ## Load inputs

# %% [markdown]
# ## Common inputs for each optimization problem

# %%
#Problem specific inputs
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Lengths of the state vector
lengths = [1000]
#Number of unique values for each x (0/1)
max_val = 2
#Keeping the fitness curves
curve = True
#Max attempts to find a better neighbor
max_attempts = [20]
#Max iterations
max_iters = range(100, 2100, 100)

#Algorithm specific inputs
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Genetic algorithm: population size
pop_sizes = [100, 200, 300]
#Genetic algorithm: mutation rate
mutation_probs = [0.1, 0.2, 0.3]

# %% [markdown]
# ## Four Peaks

# %%
#Inputs for four peaks problem
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Initialize the fitness function with default t_pct
fitness_fn = mlrose.FourPeaks(t_pct = 0.1)

#Initialize an empty data frame for recording results
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
four_peaks_results = pd.DataFrame(columns = ["algorithm",
                                             "pop_size",
                                             "mutation_prob",
                                             "length",
                                             "max_attempt",
                                             "max_iter",
                                             "best_fitness",
                                             "time",
                                             "function_evaluations"])


#Loop
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Start the iteration counter
iter = 1
#For each unique number of objects
for length in lengths:
    
    #Set the optimization problem object
    problem = mlrose.DiscreteOpt(length = length,
                                 fitness_fn = fitness_fn,
                                 maximize = True,
                                 max_val = max_val)
    
    #For each combination of max attempt, max iteration, and random restart
    for max_attempt in max_attempts:
        for max_iter in max_iters:
            for pop_size in pop_sizes:
                for mutation_prob in mutation_probs:

                    #Ensuring reproducibility
                    random_state = iter
                
                    #Start a timer for each iteration
                    start = time.time()

                    #Print message
                    print("Working on iter:", iter,
                          "Length:", length,
                          "Population size:", pop_size,
                          "Mutation proab:", mutation_prob,
                          "Max attempt:", max_attempt,
                          "Max iter:", max_iter)

                    #Genetic Algorithm
                    #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
                    #Start the timer for Genetic Algorithm
                    ga_start = time.time()

                    #Optimization
                    (ga_best_state,
                     ga_best_fitness,
                     ga_fitness_curve) = mlrose.genetic_alg(problem = problem,
                                                            pop_size = pop_size,
                                                            mutation_prob = mutation_prob,
                                                            max_attempts = max_attempt,
                                                            max_iters = max_iter,
                                                            curve = curve,
                                                            random_state = random_state)

                    #End the timer
                    ga_end = time.time()
                    #Get the total time
                    ga_time = ga_end - ga_start

                    #Message
                    print("    GA best fitness:", ga_best_fitness)

                    #Add to results list
                    four_peaks_results = four_peaks_results.append({"algorithm": "genetic_algorithm",
                                                                    "pop_size": pop_size,
                                                                    "mutation_prob": mutation_prob,
                                                                    "length": length,
                                                                    "max_attempt": max_attempt,
                                                                    "max_iter": max_iter,
                                                                    "best_fitness": ga_best_fitness,
                                                                    "time": ga_time,
                                                                    "function_evaluations": np.argmax(ga_fitness_curve) + 1},
                                                                   ignore_index = True)

                    #End the timer for all four algorithms
                    end = time.time()
                    #Total time for all four algorithms
                    iter_time = end - start

                    #Message
                    print("Iter time:", iter_time)

                    #Increment the iteration counter
                    iter = iter + 1

                    print("\n")
                
#Output results
four_peaks_results.to_csv(output_four_peaks + "four_peaks_ga.csv", index = False)
pd.DataFrame(ga_fitness_curve).to_csv(output_four_peaks + "four_peaks_ga_curve.csv", index = False)

#Done
print("Done.")
# Out:
# Working on iter: 1 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 100
#     GA best fitness: 22.0
# Iter time: 2.0027341842651367
#
#
# Working on iter: 2 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 100
#     GA best fitness: 13.0
# Iter time: 0.9307360649108887
#
#
# Working on iter: 3 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 100
#     GA best fitness: 14.0
# Iter time: 1.3273720741271973
#
#
# Working on iter: 4 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 100
#     GA best fitness: 17.0
# Iter time: 1.9927058219909668
#
#
# Working on iter: 5 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 100
#     GA best fitness: 17.0
# Iter time: 2.006538152694702
#
#
# Working on iter: 6 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 100
#     GA best fitness: 16.0
# Iter time: 4.15390682220459
#
#
# Working on iter: 7 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 100
#     GA best fitness: 19.0
# Iter time: 4.3918678760528564
#
#
# Working on iter: 8 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 100
#     GA best fitness: 16.0
# Iter time: 5.912125110626221
#
#
# Working on iter: 9 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 100
#     GA best fitness: 18.0
# Iter time: 5.109400033950806
#
#
# Working on iter: 10 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 200
#     GA best fitness: 17.0
# Iter time: 1.1649689674377441
#
#
# Working on iter: 11 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 200
#     GA best fitness: 13.0
# Iter time: 0.8829171657562256
#
#
# Working on iter: 12 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 200
#     GA best fitness: 12.0
# Iter time: 1.7789740562438965
#
#
# Working on iter: 13 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 200
#     GA best fitness: 19.0
# Iter time: 2.072044849395752
#
#
# Working on iter: 14 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 200
#     GA best fitness: 14.0
# Iter time: 2.7737019062042236
#
#
# Working on iter: 15 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 200
#     GA best fitness: 13.0
# Iter time: 4.65342116355896
#
#
# Working on iter: 16 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 200
#     GA best fitness: 17.0
# Iter time: 2.888111114501953
#
#
# Working on iter: 17 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 200
#     GA best fitness: 18.0
# Iter time: 4.588389158248901
#
#
# Working on iter: 18 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 200
#     GA best fitness: 19.0
# Iter time: 8.529269933700562
#
#
# Working on iter: 19 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 300
#     GA best fitness: 23.0
# Iter time: 2.2777888774871826
#
#
# Working on iter: 20 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 300
#     GA best fitness: 16.0
# Iter time: 2.1008291244506836
#
#
# Working on iter: 21 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 300
#     GA best fitness: 16.0
# Iter time: 2.7140872478485107
#
#
# Working on iter: 22 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 300
#     GA best fitness: 18.0
# Iter time: 2.119774103164673
#
#
# Working on iter: 23 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 300
#     GA best fitness: 16.0
# Iter time: 3.045412063598633
#
#
# Working on iter: 24 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 300
#     GA best fitness: 16.0
# Iter time: 6.517953157424927
#
#
# Working on iter: 25 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 300
#     GA best fitness: 17.0
# Iter time: 5.211236238479614
#
#
# Working on iter: 26 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 300
#     GA best fitness: 15.0
# Iter time: 4.467146873474121
#
#
# Working on iter: 27 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 300
#     GA best fitness: 13.0
# Iter time: 6.7593910694122314
#
#
# Working on iter: 28 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 400
#     GA best fitness: 23.0
# Iter time: 2.801008701324463
#
#
# Working on iter: 29 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 400
#     GA best fitness: 15.0
# Iter time: 2.0570857524871826
#
#
# Working on iter: 30 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 400
#     GA best fitness: 13.0
# Iter time: 4.204175233840942
#
#
# Working on iter: 31 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 400
#     GA best fitness: 22.0
# Iter time: 2.058462142944336
#
#
# Working on iter: 32 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 400
#     GA best fitness: 19.0
# Iter time: 2.8524060249328613
#
#
# Working on iter: 33 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 400
#     GA best fitness: 15.0
# Iter time: 5.368017196655273
#
#
# Working on iter: 34 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 400
#     GA best fitness: 18.0
# Iter time: 3.583678960800171
#
#
# Working on iter: 35 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 400
#     GA best fitness: 15.0
# Iter time: 4.694812297821045
#
#
# Working on iter: 36 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 400
#     GA best fitness: 16.0
# Iter time: 5.514885187149048
#
#
# Working on iter: 37 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 500
#     GA best fitness: 18.0
# Iter time: 1.0960099697113037
#
#
# Working on iter: 38 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 500
#     GA best fitness: 13.0
# Iter time: 2.0227959156036377
#
#
# Working on iter: 39 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 500
#     GA best fitness: 15.0
# Iter time: 2.3322651386260986
#
#
# Working on iter: 40 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 500
#     GA best fitness: 18.0
# Iter time: 2.5729260444641113
#
#
# Working on iter: 41 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 500
#     GA best fitness: 14.0
# Iter time: 2.2958338260650635
#
#
# Working on iter: 42 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 500
#     GA best fitness: 15.0
# Iter time: 7.718989849090576
#
#
# Working on iter: 43 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 500
#     GA best fitness: 21.0
# Iter time: 4.8888938426971436
#
#
# Working on iter: 44 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 500
#     GA best fitness: 16.0
# Iter time: 2.6818618774414062
#
#
# Working on iter: 45 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 500
#     GA best fitness: 12.0
# Iter time: 3.294917106628418
#
#
# Working on iter: 46 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 600
#     GA best fitness: 20.0
# Iter time: 0.7882800102233887
#
#
# Working on iter: 47 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 600
#     GA best fitness: 13.0
# Iter time: 1.22446608543396
#
#
# Working on iter: 48 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 600
#     GA best fitness: 18.0
# Iter time: 1.188675880432129
#
#
# Working on iter: 49 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 600
#     GA best fitness: 15.0
# Iter time: 1.421781063079834
#
#
# Working on iter: 50 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 600
#     GA best fitness: 17.0
# Iter time: 2.233344078063965
#
#
# Working on iter: 51 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 600
#     GA best fitness: 13.0
# Iter time: 2.6490957736968994
#
#
# Working on iter: 52 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 600
#     GA best fitness: 19.0
# Iter time: 2.241816997528076
#
#
# Working on iter: 53 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 600
#     GA best fitness: 14.0
# Iter time: 2.9435460567474365
#
#
# Working on iter: 54 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 600
#     GA best fitness: 16.0
# Iter time: 6.757287979125977
#
#
# Working on iter: 55 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 700
#     GA best fitness: 16.0
# Iter time: 0.960906982421875
#
#
# Working on iter: 56 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 700
#     GA best fitness: 17.0
# Iter time: 1.5061380863189697
#
#
# Working on iter: 57 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 700
#     GA best fitness: 14.0
# Iter time: 1.2348217964172363
#
#
# Working on iter: 58 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 700
#     GA best fitness: 19.0
# Iter time: 2.382816791534424
#
#
# Working on iter: 59 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 700
#     GA best fitness: 20.0
# Iter time: 1.6429228782653809
#
#
# Working on iter: 60 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 700
#     GA best fitness: 12.0
# Iter time: 2.542022943496704
#
#
# Working on iter: 61 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 700
#     GA best fitness: 17.0
# Iter time: 3.1873087882995605
#
#
# Working on iter: 62 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 700
#     GA best fitness: 17.0
# Iter time: 5.1752870082855225
#
#
# Working on iter: 63 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 700
#     GA best fitness: 14.0
# Iter time: 5.770139932632446
#
#
# Working on iter: 64 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 800
#     GA best fitness: 18.0
# Iter time: 1.3443078994750977
#
#
# Working on iter: 65 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 800
#     GA best fitness: 16.0
# Iter time: 1.8629567623138428
#
#
# Working on iter: 66 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 800
#     GA best fitness: 16.0
# Iter time: 1.523205041885376
#
#
# Working on iter: 67 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 800
#     GA best fitness: 19.0
# Iter time: 1.3292312622070312
#
#
# Working on iter: 68 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 800
#     GA best fitness: 20.0
# Iter time: 1.6501610279083252
#
#
# Working on iter: 69 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 800
#     GA best fitness: 14.0
# Iter time: 2.651540994644165
#
#
# Working on iter: 70 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 800
#     GA best fitness: 19.0
# Iter time: 2.3283751010894775
#
#
# Working on iter: 71 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 800
#     GA best fitness: 14.0
# Iter time: 2.463409900665283
#
#
# Working on iter: 72 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 800
#     GA best fitness: 13.0
# Iter time: 4.289488077163696
#
#
# Working on iter: 73 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 900
#     GA best fitness: 17.0
# Iter time: 0.9874148368835449
#
#
# Working on iter: 74 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 900
#     GA best fitness: 13.0
# Iter time: 0.9418880939483643
#
#
# Working on iter: 75 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 900
#     GA best fitness: 16.0
# Iter time: 1.592613697052002
#
#
# Working on iter: 76 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 900
#     GA best fitness: 15.0
# Iter time: 1.5422348976135254
#
#
# Working on iter: 77 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 900
#     GA best fitness: 15.0
# Iter time: 1.635357141494751
#
#
# Working on iter: 78 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 900
#     GA best fitness: 14.0
# Iter time: 3.394339084625244
#
#
# Working on iter: 79 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 900
#     GA best fitness: 20.0
# Iter time: 3.5937607288360596
#
#
# Working on iter: 80 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 900
#     GA best fitness: 19.0
# Iter time: 6.255225896835327
#
#
# Working on iter: 81 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 900
#     GA best fitness: 17.0
# Iter time: 7.4016547203063965
#
#
# Working on iter: 82 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1000
#     GA best fitness: 19.0
# Iter time: 1.3228809833526611
#
#
# Working on iter: 83 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1000
#     GA best fitness: 12.0
# Iter time: 1.0036239624023438
#
#
# Working on iter: 84 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1000
#     GA best fitness: 12.0
# Iter time: 1.4119491577148438
#
#
# Working on iter: 85 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1000
#     GA best fitness: 20.0
# Iter time: 1.5206091403961182
#
#
# Working on iter: 86 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1000
#     GA best fitness: 18.0
# Iter time: 3.231360912322998
#
#
# Working on iter: 87 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1000
#     GA best fitness: 14.0
# Iter time: 2.6242728233337402
#
#
# Working on iter: 88 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1000
#     GA best fitness: 18.0
# Iter time: 1.8530540466308594
#
#
# Working on iter: 89 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1000
#     GA best fitness: 19.0
# Iter time: 3.480675220489502
#
#
# Working on iter: 90 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1000
#     GA best fitness: 15.0
# Iter time: 4.377567291259766
#
#
# Working on iter: 91 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1100
#     GA best fitness: 25.0
# Iter time: 1.0773041248321533
#
#
# Working on iter: 92 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1100
#     GA best fitness: 14.0
# Iter time: 1.2305290699005127
#
#
# Working on iter: 93 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1100
#     GA best fitness: 12.0
# Iter time: 1.6126627922058105
#
#
# Working on iter: 94 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1100
#     GA best fitness: 15.0
# Iter time: 1.3758511543273926
#
#
# Working on iter: 95 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1100
#     GA best fitness: 16.0
# Iter time: 2.914544105529785
#
#
# Working on iter: 96 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1100
#     GA best fitness: 18.0
# Iter time: 2.512648820877075
#
#
# Working on iter: 97 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1100
#     GA best fitness: 18.0
# Iter time: 1.8564627170562744
#
#
# Working on iter: 98 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1100
#     GA best fitness: 16.0
# Iter time: 3.8261990547180176
#
#
# Working on iter: 99 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1100
#     GA best fitness: 19.0
# Iter time: 5.969866037368774
#
#
# Working on iter: 100 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1200
#     GA best fitness: 18.0
# Iter time: 0.7879691123962402
#
#
# Working on iter: 101 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1200
#     GA best fitness: 16.0
# Iter time: 0.9973828792572021
#
#
# Working on iter: 102 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1200
#     GA best fitness: 13.0
# Iter time: 1.3082549571990967
#
#
# Working on iter: 103 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1200
#     GA best fitness: 17.0
# Iter time: 2.1079187393188477
#
#
# Working on iter: 104 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1200
#     GA best fitness: 15.0
# Iter time: 1.8503060340881348
#
#
# Working on iter: 105 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1200
#     GA best fitness: 14.0
# Iter time: 5.640018939971924
#
#
# Working on iter: 106 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1200
#     GA best fitness: 18.0
# Iter time: 2.508882999420166
#
#
# Working on iter: 107 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1200
#     GA best fitness: 16.0
# Iter time: 4.371999979019165
#
#
# Working on iter: 108 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1200
#     GA best fitness: 15.0
# Iter time: 3.4808528423309326
#
#
# Working on iter: 109 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1300
#     GA best fitness: 23.0
# Iter time: 1.254223108291626
#
#
# Working on iter: 110 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1300
#     GA best fitness: 13.0
# Iter time: 1.2245240211486816
#
#
# Working on iter: 111 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1300
#     GA best fitness: 16.0
# Iter time: 2.1456148624420166
#
#
# Working on iter: 112 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1300
#     GA best fitness: 17.0
# Iter time: 1.8714330196380615
#
#
# Working on iter: 113 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1300
#     GA best fitness: 16.0
# Iter time: 2.0791680812835693
#
#
# Working on iter: 114 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1300
#     GA best fitness: 13.0
# Iter time: 2.5099618434906006
#
#
# Working on iter: 115 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1300
#     GA best fitness: 19.0
# Iter time: 4.515271902084351
#
#
# Working on iter: 116 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1300
#     GA best fitness: 20.0
# Iter time: 2.766749858856201
#
#
# Working on iter: 117 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1300
#     GA best fitness: 15.0
# Iter time: 3.2983498573303223
#
#
# Working on iter: 118 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1400
#     GA best fitness: 18.0
# Iter time: 0.8601861000061035
#
#
# Working on iter: 119 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1400
#     GA best fitness: 13.0
# Iter time: 1.00052809715271
#
#
# Working on iter: 120 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1400
#     GA best fitness: 12.0
# Iter time: 1.2018811702728271
#
#
# Working on iter: 121 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1400
#     GA best fitness: 20.0
# Iter time: 2.352997064590454
#
#
# Working on iter: 122 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1400
#     GA best fitness: 16.0
# Iter time: 2.9132869243621826
#
#
# Working on iter: 123 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1400
#     GA best fitness: 16.0
# Iter time: 3.3514299392700195
#
#
# Working on iter: 124 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1400
#     GA best fitness: 20.0
# Iter time: 3.1930606365203857
#
#
# Working on iter: 125 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1400
#     GA best fitness: 15.0
# Iter time: 4.306380033493042
#
#
# Working on iter: 126 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1400
#     GA best fitness: 17.0
# Iter time: 5.626034736633301
#
#
# Working on iter: 127 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1500
#     GA best fitness: 15.0
# Iter time: 0.7565958499908447
#
#
# Working on iter: 128 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1500
#     GA best fitness: 15.0
# Iter time: 1.739995002746582
#
#
# Working on iter: 129 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1500
#     GA best fitness: 15.0
# Iter time: 1.7722301483154297
#
#
# Working on iter: 130 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1500
#     GA best fitness: 24.0
# Iter time: 2.455075979232788
#
#
# Working on iter: 131 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1500
#     GA best fitness: 15.0
# Iter time: 2.3734488487243652
#
#
# Working on iter: 132 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1500
#     GA best fitness: 17.0
# Iter time: 4.20612096786499
#
#
# Working on iter: 133 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1500
#     GA best fitness: 19.0
# Iter time: 3.6202070713043213
#
#
# Working on iter: 134 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1500
#     GA best fitness: 14.0
# Iter time: 2.783720016479492
#
#
# Working on iter: 135 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1500
#     GA best fitness: 12.0
# Iter time: 3.330498218536377
#
#
# Working on iter: 136 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1600
#     GA best fitness: 18.0
# Iter time: 0.9418900012969971
#
#
# Working on iter: 137 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1600
#     GA best fitness: 14.0
# Iter time: 0.854841947555542
#
#
# Working on iter: 138 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1600
#     GA best fitness: 11.0
# Iter time: 2.1496331691741943
#
#
# Working on iter: 139 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1600
#     GA best fitness: 18.0
# Iter time: 2.218470811843872
#
#
# Working on iter: 140 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1600
#     GA best fitness: 18.0
# Iter time: 3.569631814956665
#
#
# Working on iter: 141 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1600
#     GA best fitness: 18.0
# Iter time: 3.8821651935577393
#
#
# Working on iter: 142 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1600
#     GA best fitness: 25.0
# Iter time: 2.6645731925964355
#
#
# Working on iter: 143 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1600
#     GA best fitness: 15.0
# Iter time: 3.359973192214966
#
#
# Working on iter: 144 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1600
#     GA best fitness: 14.0
# Iter time: 4.269357919692993
#
#
# Working on iter: 145 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1700
#     GA best fitness: 20.0
# Iter time: 1.1743700504302979
#
#
# Working on iter: 146 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1700
#     GA best fitness: 16.0
# Iter time: 1.1171700954437256
#
#
# Working on iter: 147 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1700
#     GA best fitness: 12.0
# Iter time: 1.7811520099639893
#
#
# Working on iter: 148 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1700
#     GA best fitness: 18.0
# Iter time: 2.640717029571533
#
#
# Working on iter: 149 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1700
#     GA best fitness: 15.0
# Iter time: 1.77238130569458
#
#
# Working on iter: 150 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1700
#     GA best fitness: 16.0
# Iter time: 3.159245014190674
#
#
# Working on iter: 151 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1700
#     GA best fitness: 21.0
# Iter time: 2.5146138668060303
#
#
# Working on iter: 152 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1700
#     GA best fitness: 17.0
# Iter time: 4.5130531787872314
#
#
# Working on iter: 153 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1700
#     GA best fitness: 17.0
# Iter time: 6.152653932571411
#
#
# Working on iter: 154 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1800
#     GA best fitness: 16.0
# Iter time: 1.1516149044036865
#
#
# Working on iter: 155 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1800
#     GA best fitness: 16.0
# Iter time: 1.3108141422271729
#
#
# Working on iter: 156 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1800
#     GA best fitness: 12.0
# Iter time: 2.9867031574249268
#
#
# Working on iter: 157 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1800
#     GA best fitness: 19.0
# Iter time: 1.965054988861084
#
#
# Working on iter: 158 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1800
#     GA best fitness: 14.0
# Iter time: 2.242316961288452
#
#
# Working on iter: 159 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1800
#     GA best fitness: 16.0
# Iter time: 4.4398369789123535
#
#
# Working on iter: 160 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1800
#     GA best fitness: 21.0
# Iter time: 3.7741410732269287
#
#
# Working on iter: 161 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1800
#     GA best fitness: 19.0
# Iter time: 6.962172031402588
#
#
# Working on iter: 162 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1800
#     GA best fitness: 12.0
# Iter time: 5.081184148788452
#
#
# Working on iter: 163 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1900
#     GA best fitness: 17.0
# Iter time: 0.7884490489959717
#
#
# Working on iter: 164 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1900
#     GA best fitness: 15.0
# Iter time: 1.2385950088500977
#
#
# Working on iter: 165 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1900
#     GA best fitness: 14.0
# Iter time: 1.9477229118347168
#
#
# Working on iter: 166 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1900
#     GA best fitness: 19.0
# Iter time: 1.4830410480499268
#
#
# Working on iter: 167 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1900
#     GA best fitness: 14.0
# Iter time: 3.0212221145629883
#
#
# Working on iter: 168 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1900
#     GA best fitness: 16.0
# Iter time: 4.716041088104248
#
#
# Working on iter: 169 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1900
#     GA best fitness: 21.0
# Iter time: 6.419877767562866
#
#
# Working on iter: 170 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1900
#     GA best fitness: 16.0
# Iter time: 4.6996541023254395
#
#
# Working on iter: 171 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1900
#     GA best fitness: 16.0
# Iter time: 8.141265153884888
#
#
# Working on iter: 172 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 2000
#     GA best fitness: 15.0
# Iter time: 0.8145380020141602
#
#
# Working on iter: 173 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 2000
#     GA best fitness: 13.0
# Iter time: 0.8388528823852539
#
#
# Working on iter: 174 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 2000
#     GA best fitness: 13.0
# Iter time: 1.6490368843078613
#
#
# Working on iter: 175 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 2000
#     GA best fitness: 17.0
# Iter time: 2.4423868656158447
#
#
# Working on iter: 176 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 2000
#     GA best fitness: 18.0
# Iter time: 3.1315457820892334
#
#
# Working on iter: 177 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 2000
#     GA best fitness: 16.0
# Iter time: 6.6070709228515625
#
#
# Working on iter: 178 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 2000
#     GA best fitness: 19.0
# Iter time: 1.6667661666870117
#
#
# Working on iter: 179 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 2000
#     GA best fitness: 15.0
# Iter time: 3.377556085586548
#
#
# Working on iter: 180 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 2000
#     GA best fitness: 14.0
# Iter time: 6.497344017028809
#
#
# Done.

# %% [markdown]
# ## Knapsack

# %%
#Inputs for knapsack problem
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
weights = np.random.randint(1, 6, lengths)
values = np.random.randint(1, 6, lengths)
max_weight_pct = 0.6
fitness_fn = mlrose.Knapsack(weights = weights, values = values, max_weight_pct = max_weight_pct)

#Initialize an empty data frame for recording results
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
knapsack_results = pd.DataFrame(columns = ["algorithm",
                                           "pop_size",
                                           "mutation_prob",
                                           "length",
                                           "max_attempt",
                                           "max_iter",
                                           "best_fitness",
                                           "time",
                                           "function_evaluations"])

#Loop
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Start an iteration counter
iter = 1
#For each unique number of objects
for length in lengths:
    
    #Set the optimization problem object
    problem = mlrose.DiscreteOpt(length = length,
                                 fitness_fn = fitness_fn,
                                 maximize = True,
                                 max_val = max_val)
    
    #For each combination of max attempt, max iteration, and random restart
    for max_attempt in max_attempts:
        for max_iter in max_iters:
            for pop_size in pop_sizes:
                for mutation_prob in mutation_probs:

                    #Ensuring reproducibility
                    random_state = iter
                
                    #Start a timer for each iteration
                    start = time.time()

                    #Print message
                    print("Working on iter:", iter,
                          "Length:", length,
                          "Population size:", pop_size,
                          "Mutation proab:", mutation_prob,
                          "Max attempt:", max_attempt,
                          "Max iter:", max_iter)

                    #Genetic Algorithm
                    #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
                    #Start the timer for Genetic Algorithm
                    ga_start = time.time()

                    #Optimization
                    (ga_best_state,
                     ga_best_fitness,
                     ga_fitness_curve) = mlrose.genetic_alg(problem = problem,
                                                            pop_size = pop_size,
                                                            mutation_prob = mutation_prob,
                                                            max_attempts = max_attempt,
                                                            max_iters = max_iter,
                                                            curve = curve,
                                                            random_state = random_state)
                    #End the timer
                    ga_end = time.time()
                    #Get the total time
                    ga_time = ga_end - ga_start

                    #Message
                    print("    GA best fitness:", ga_best_fitness)

                    #Add to results list
                    knapsack_results = knapsack_results.append({"algorithm": "genetic_algorithm",
                                                                "pop_size": pop_size,
                                                                "mutation_prob": mutation_prob,
                                                                "length": length,
                                                                "max_attempt": max_attempt,
                                                                "max_iter": max_iter,
                                                                "best_fitness": ga_best_fitness,
                                                                "time": ga_time,
                                                                "function_evaluations": np.argmax(ga_fitness_curve) + 1},
                                                                ignore_index = True)


                    #End the timer for all four algorithms
                    end = time.time()
                    #Total time for all four algorithms
                    iter_time = end - start

                    #Message
                    print("Iter time:", iter_time)

                    print("\n")
                    iter = iter + 1

#Output results                
knapsack_results.to_csv(output_knapsack + "knapsack_ga.csv", index = False)
pd.DataFrame(ga_fitness_curve).to_csv(output_knapsack + "knapsack_ga_curve.csv", index = False)

#Done
print("Done.")
# Out:
# Working on iter: 1 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 100
#     GA best fitness: 1701.0
# Iter time: 1.0818798542022705
#
#
# Working on iter: 2 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 100
#     GA best fitness: 1708.0
# Iter time: 2.572923183441162
#
#
# Working on iter: 3 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 100
#     GA best fitness: 1714.0
# Iter time: 1.3030998706817627
#
#
# Working on iter: 4 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 100
#     GA best fitness: 1710.0
# Iter time: 1.695749282836914
#
#
# Working on iter: 5 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 100
#     GA best fitness: 1716.0
# Iter time: 2.460779905319214
#
#
# Working on iter: 6 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 100
#     GA best fitness: 1697.0
# Iter time: 3.3532001972198486
#
#
# Working on iter: 7 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 100
#     GA best fitness: 1704.0
# Iter time: 2.8645880222320557
#
#
# Working on iter: 8 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 100
#     GA best fitness: 1718.0
# Iter time: 2.862929105758667
#
#
# Working on iter: 9 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 100
#     GA best fitness: 1729.0
# Iter time: 3.77091908454895
#
#
# Working on iter: 10 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 200
#     GA best fitness: 1682.0
# Iter time: 0.5417490005493164
#
#
# Working on iter: 11 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 200
#     GA best fitness: 1770.0
# Iter time: 1.4333162307739258
#
#
# Working on iter: 12 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 200
#     GA best fitness: 1691.0
# Iter time: 1.4393506050109863
#
#
# Working on iter: 13 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 200
#     GA best fitness: 1710.0
# Iter time: 1.4891149997711182
#
#
# Working on iter: 14 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 200
#     GA best fitness: 1708.0
# Iter time: 3.797938823699951
#
#
# Working on iter: 15 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 200
#     GA best fitness: 1714.0
# Iter time: 4.516510963439941
#
#
# Working on iter: 16 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 200
#     GA best fitness: 1704.0
# Iter time: 1.777153730392456
#
#
# Working on iter: 17 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 200
#     GA best fitness: 1704.0
# Iter time: 6.216708183288574
#
#
# Working on iter: 18 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 200
#     GA best fitness: 1704.0
# Iter time: 5.0963568687438965
#
#
# Working on iter: 19 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 300
#     GA best fitness: 1746.0
# Iter time: 1.9614367485046387
#
#
# Working on iter: 20 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 300
#     GA best fitness: 1688.0
# Iter time: 0.9571871757507324
#
#
# Working on iter: 21 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 300
#     GA best fitness: 1727.0
# Iter time: 1.447861909866333
#
#
# Working on iter: 22 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 300
#     GA best fitness: 1706.0
# Iter time: 3.3749828338623047
#
#
# Working on iter: 23 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 300
#     GA best fitness: 1745.0
# Iter time: 4.876678943634033
#
#
# Working on iter: 24 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 300
#     GA best fitness: 1708.0
# Iter time: 2.4715850353240967
#
#
# Working on iter: 25 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 300
#     GA best fitness: 1735.0
# Iter time: 2.8880162239074707
#
#
# Working on iter: 26 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 300
#     GA best fitness: 1752.0
# Iter time: 3.369826078414917
#
#
# Working on iter: 27 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 300
#     GA best fitness: 1736.0
# Iter time: 7.76911473274231
#
#
# Working on iter: 28 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 400
#     GA best fitness: 1696.0
# Iter time: 0.644726037979126
#
#
# Working on iter: 29 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 400
#     GA best fitness: 1683.0
# Iter time: 1.9962570667266846
#
#
# Working on iter: 30 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 400
#     GA best fitness: 1756.0
# Iter time: 1.4475998878479004
#
#
# Working on iter: 31 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 400
#     GA best fitness: 1712.0
# Iter time: 2.6496870517730713
#
#
# Working on iter: 32 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 400
#     GA best fitness: 1753.0
# Iter time: 3.8455512523651123
#
#
# Working on iter: 33 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 400
#     GA best fitness: 1709.0
# Iter time: 2.588913917541504
#
#
# Working on iter: 34 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 400
#     GA best fitness: 1708.0
# Iter time: 2.6219053268432617
#
#
# Working on iter: 35 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 400
#     GA best fitness: 1698.0
# Iter time: 3.3525209426879883
#
#
# Working on iter: 36 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 400
#     GA best fitness: 1705.0
# Iter time: 5.1736860275268555
#
#
# Working on iter: 37 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 500
#     GA best fitness: 1700.0
# Iter time: 0.9913709163665771
#
#
# Working on iter: 38 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 500
#     GA best fitness: 1686.0
# Iter time: 1.444249153137207
#
#
# Working on iter: 39 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 500
#     GA best fitness: 1721.0
# Iter time: 1.929844856262207
#
#
# Working on iter: 40 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 500
#     GA best fitness: 1717.0
# Iter time: 1.0971879959106445
#
#
# Working on iter: 41 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 500
#     GA best fitness: 1756.0
# Iter time: 1.926358938217163
#
#
# Working on iter: 42 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 500
#     GA best fitness: 1729.0
# Iter time: 5.033025026321411
#
#
# Working on iter: 43 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 500
#     GA best fitness: 1761.0
# Iter time: 4.67277193069458
#
#
# Working on iter: 44 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 500
#     GA best fitness: 1736.0
# Iter time: 3.6180059909820557
#
#
# Working on iter: 45 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 500
#     GA best fitness: 1691.0
# Iter time: 3.7231550216674805
#
#
# Working on iter: 46 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 600
#     GA best fitness: 1727.0
# Iter time: 0.7457828521728516
#
#
# Working on iter: 47 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 600
#     GA best fitness: 1679.0
# Iter time: 0.8398840427398682
#
#
# Working on iter: 48 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 600
#     GA best fitness: 1674.0
# Iter time: 1.1855931282043457
#
#
# Working on iter: 49 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 600
#     GA best fitness: 1693.0
# Iter time: 1.859004259109497
#
#
# Working on iter: 50 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 600
#     GA best fitness: 1715.0
# Iter time: 3.2827839851379395
#
#
# Working on iter: 51 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 600
#     GA best fitness: 1709.0
# Iter time: 3.439828872680664
#
#
# Working on iter: 52 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 600
#     GA best fitness: 1725.0
# Iter time: 1.7080488204956055
#
#
# Working on iter: 53 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 600
#     GA best fitness: 1727.0
# Iter time: 2.629776954650879
#
#
# Working on iter: 54 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 600
#     GA best fitness: 1755.0
# Iter time: 3.4073469638824463
#
#
# Working on iter: 55 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 700
#     GA best fitness: 1730.0
# Iter time: 1.24080491065979
#
#
# Working on iter: 56 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 700
#     GA best fitness: 1696.0
# Iter time: 1.62664794921875
#
#
# Working on iter: 57 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 700
#     GA best fitness: 1673.0
# Iter time: 1.2373571395874023
#
#
# Working on iter: 58 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 700
#     GA best fitness: 1727.0
# Iter time: 2.223964214324951
#
#
# Working on iter: 59 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 700
#     GA best fitness: 1713.0
# Iter time: 3.1842989921569824
#
#
# Working on iter: 60 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 700
#     GA best fitness: 1735.0
# Iter time: 5.224995136260986
#
#
# Working on iter: 61 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 700
#     GA best fitness: 1716.0
# Iter time: 2.7304351329803467
#
#
# Working on iter: 62 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 700
#     GA best fitness: 1705.0
# Iter time: 3.592313051223755
#
#
# Working on iter: 63 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 700
#     GA best fitness: 1689.0
# Iter time: 3.4102418422698975
#
#
# Working on iter: 64 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 800
#     GA best fitness: 1701.0
# Iter time: 0.8844261169433594
#
#
# Working on iter: 65 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 800
#     GA best fitness: 1685.0
# Iter time: 1.0380229949951172
#
#
# Working on iter: 66 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 800
#     GA best fitness: 1691.0
# Iter time: 1.360124111175537
#
#
# Working on iter: 67 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 800
#     GA best fitness: 1760.0
# Iter time: 1.8276698589324951
#
#
# Working on iter: 68 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 800
#     GA best fitness: 1705.0
# Iter time: 3.5447630882263184
#
#
# Working on iter: 69 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 800
#     GA best fitness: 1712.0
# Iter time: 6.097456216812134
#
#
# Working on iter: 70 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 800
#     GA best fitness: 1678.0
# Iter time: 1.648463249206543
#
#
# Working on iter: 71 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 800
#     GA best fitness: 1766.0
# Iter time: 4.767008066177368
#
#
# Working on iter: 72 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 800
#     GA best fitness: 1732.0
# Iter time: 7.51639199256897
#
#
# Working on iter: 73 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 900
#     GA best fitness: 1713.0
# Iter time: 1.075551986694336
#
#
# Working on iter: 74 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 900
#     GA best fitness: 1710.0
# Iter time: 1.6305320262908936
#
#
# Working on iter: 75 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 900
#     GA best fitness: 1687.0
# Iter time: 1.3462460041046143
#
#
# Working on iter: 76 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 900
#     GA best fitness: 1705.0
# Iter time: 1.5979371070861816
#
#
# Working on iter: 77 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 900
#     GA best fitness: 1688.0
# Iter time: 2.3140830993652344
#
#
# Working on iter: 78 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 900
#     GA best fitness: 1704.0
# Iter time: 5.336734056472778
#
#
# Working on iter: 79 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 900
#     GA best fitness: 1714.0
# Iter time: 2.0568838119506836
#
#
# Working on iter: 80 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 900
#     GA best fitness: 1716.0
# Iter time: 3.1204030513763428
#
#
# Working on iter: 81 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 900
#     GA best fitness: 1704.0
# Iter time: 5.425203800201416
#
#
# Working on iter: 82 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1000
#     GA best fitness: 1711.0
# Iter time: 0.6948831081390381
#
#
# Working on iter: 83 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1000
#     GA best fitness: 1689.0
# Iter time: 2.80662202835083
#
#
# Working on iter: 84 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1000
#     GA best fitness: 1703.0
# Iter time: 2.413818120956421
#
#
# Working on iter: 85 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1000
#     GA best fitness: 1720.0
# Iter time: 1.7495558261871338
#
#
# Working on iter: 86 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1000
#     GA best fitness: 1728.0
# Iter time: 4.3005547523498535
#
#
# Working on iter: 87 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1000
#     GA best fitness: 1697.0
# Iter time: 2.809256076812744
#
#
# Working on iter: 88 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1000
#     GA best fitness: 1704.0
# Iter time: 3.5446481704711914
#
#
# Working on iter: 89 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1000
#     GA best fitness: 1720.0
# Iter time: 4.784265041351318
#
#
# Working on iter: 90 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1000
#     GA best fitness: 1708.0
# Iter time: 6.931321144104004
#
#
# Working on iter: 91 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1100
#     GA best fitness: 1725.0
# Iter time: 1.201448917388916
#
#
# Working on iter: 92 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1100
#     GA best fitness: 1697.0
# Iter time: 1.1982710361480713
#
#
# Working on iter: 93 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1100
#     GA best fitness: 1678.0
# Iter time: 1.2316317558288574
#
#
# Working on iter: 94 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1100
#     GA best fitness: 1710.0
# Iter time: 1.9452300071716309
#
#
# Working on iter: 95 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1100
#     GA best fitness: 1715.0
# Iter time: 3.5164589881896973
#
#
# Working on iter: 96 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1100
#     GA best fitness: 1715.0
# Iter time: 2.6918447017669678
#
#
# Working on iter: 97 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1100
#     GA best fitness: 1705.0
# Iter time: 1.7902779579162598
#
#
# Working on iter: 98 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1100
#     GA best fitness: 1708.0
# Iter time: 3.0139541625976562
#
#
# Working on iter: 99 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1100
#     GA best fitness: 1733.0
# Iter time: 8.949412107467651
#
#
# Working on iter: 100 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1200
#     GA best fitness: 1712.0
# Iter time: 1.0174880027770996
#
#
# Working on iter: 101 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1200
#     GA best fitness: 1743.0
# Iter time: 0.9684748649597168
#
#
# Working on iter: 102 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1200
#     GA best fitness: 1688.0
# Iter time: 1.407249927520752
#
#
# Working on iter: 103 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1200
#     GA best fitness: 1696.0
# Iter time: 1.793210744857788
#
#
# Working on iter: 104 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1200
#     GA best fitness: 1705.0
# Iter time: 3.5149588584899902
#
#
# Working on iter: 105 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1200
#     GA best fitness: 1736.0
# Iter time: 3.9080209732055664
#
#
# Working on iter: 106 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1200
#     GA best fitness: 1719.0
# Iter time: 2.4823639392852783
#
#
# Working on iter: 107 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1200
#     GA best fitness: 1750.0
# Iter time: 4.910747766494751
#
#
# Working on iter: 108 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1200
#     GA best fitness: 1707.0
# Iter time: 7.08515477180481
#
#
# Working on iter: 109 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1300
#     GA best fitness: 1705.0
# Iter time: 1.1419379711151123
#
#
# Working on iter: 110 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1300
#     GA best fitness: 1684.0
# Iter time: 1.164693832397461
#
#
# Working on iter: 111 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1300
#     GA best fitness: 1714.0
# Iter time: 1.3521721363067627
#
#
# Working on iter: 112 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1300
#     GA best fitness: 1700.0
# Iter time: 2.670640707015991
#
#
# Working on iter: 113 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1300
#     GA best fitness: 1726.0
# Iter time: 2.183663845062256
#
#
# Working on iter: 114 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1300
#     GA best fitness: 1731.0
# Iter time: 2.6962711811065674
#
#
# Working on iter: 115 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1300
#     GA best fitness: 1724.0
# Iter time: 3.237339973449707
#
#
# Working on iter: 116 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1300
#     GA best fitness: 1727.0
# Iter time: 4.922514915466309
#
#
# Working on iter: 117 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1300
#     GA best fitness: 1690.0
# Iter time: 5.152903318405151
#
#
# Working on iter: 118 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1400
#     GA best fitness: 1742.0
# Iter time: 1.328432321548462
#
#
# Working on iter: 119 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1400
#     GA best fitness: 1699.0
# Iter time: 1.0347981452941895
#
#
# Working on iter: 120 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1400
#     GA best fitness: 1678.0
# Iter time: 1.9977130889892578
#
#
# Working on iter: 121 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1400
#     GA best fitness: 1716.0
# Iter time: 1.7927770614624023
#
#
# Working on iter: 122 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1400
#     GA best fitness: 1700.0
# Iter time: 1.751619815826416
#
#
# Working on iter: 123 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1400
#     GA best fitness: 1702.0
# Iter time: 7.034203767776489
#
#
# Working on iter: 124 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1400
#     GA best fitness: 1717.0
# Iter time: 1.7950823307037354
#
#
# Working on iter: 125 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1400
#     GA best fitness: 1720.0
# Iter time: 5.012672185897827
#
#
# Working on iter: 126 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1400
#     GA best fitness: 1707.0
# Iter time: 5.0464372634887695
#
#
# Working on iter: 127 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1500
#     GA best fitness: 1691.0
# Iter time: 1.0473222732543945
#
#
# Working on iter: 128 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1500
#     GA best fitness: 1685.0
# Iter time: 1.2035839557647705
#
#
# Working on iter: 129 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1500
#     GA best fitness: 1698.0
# Iter time: 2.1465909481048584
#
#
# Working on iter: 130 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1500
#     GA best fitness: 1714.0
# Iter time: 1.3916101455688477
#
#
# Working on iter: 131 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1500
#     GA best fitness: 1709.0
# Iter time: 3.360074043273926
#
#
# Working on iter: 132 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1500
#     GA best fitness: 1711.0
# Iter time: 3.9004409313201904
#
#
# Working on iter: 133 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1500
#     GA best fitness: 1715.0
# Iter time: 3.011063814163208
#
#
# Working on iter: 134 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1500
#     GA best fitness: 1705.0
# Iter time: 3.0363101959228516
#
#
# Working on iter: 135 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1500
#     GA best fitness: 1757.0
# Iter time: 7.6296210289001465
#
#
# Working on iter: 136 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1600
#     GA best fitness: 1687.0
# Iter time: 0.6029298305511475
#
#
# Working on iter: 137 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1600
#     GA best fitness: 1691.0
# Iter time: 0.9281010627746582
#
#
# Working on iter: 138 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1600
#     GA best fitness: 1704.0
# Iter time: 1.5702497959136963
#
#
# Working on iter: 139 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1600
#     GA best fitness: 1693.0
# Iter time: 2.134486198425293
#
#
# Working on iter: 140 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1600
#     GA best fitness: 1735.0
# Iter time: 2.181697130203247
#
#
# Working on iter: 141 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1600
#     GA best fitness: 1716.0
# Iter time: 3.482226848602295
#
#
# Working on iter: 142 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1600
#     GA best fitness: 1718.0
# Iter time: 2.0971052646636963
#
#
# Working on iter: 143 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1600
#     GA best fitness: 1702.0
# Iter time: 5.780923128128052
#
#
# Working on iter: 144 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1600
#     GA best fitness: 1747.0
# Iter time: 6.645132064819336
#
#
# Working on iter: 145 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1700
#     GA best fitness: 1697.0
# Iter time: 0.6987841129302979
#
#
# Working on iter: 146 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1700
#     GA best fitness: 1715.0
# Iter time: 1.1353347301483154
#
#
# Working on iter: 147 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1700
#     GA best fitness: 1682.0
# Iter time: 2.1754097938537598
#
#
# Working on iter: 148 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1700
#     GA best fitness: 1725.0
# Iter time: 1.3424839973449707
#
#
# Working on iter: 149 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1700
#     GA best fitness: 1700.0
# Iter time: 1.917923927307129
#
#
# Working on iter: 150 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1700
#     GA best fitness: 1695.0
# Iter time: 6.0087339878082275
#
#
# Working on iter: 151 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1700
#     GA best fitness: 1725.0
# Iter time: 4.427657127380371
#
#
# Working on iter: 152 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1700
#     GA best fitness: 1706.0
# Iter time: 9.288260221481323
#
#
# Working on iter: 153 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1700
#     GA best fitness: 1699.0
# Iter time: 4.237853288650513
#
#
# Working on iter: 154 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1800
#     GA best fitness: 1704.0
# Iter time: 0.5427200794219971
#
#
# Working on iter: 155 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1800
#     GA best fitness: 1709.0
# Iter time: 1.7739241123199463
#
#
# Working on iter: 156 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1800
#     GA best fitness: 1704.0
# Iter time: 2.0390803813934326
#
#
# Working on iter: 157 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1800
#     GA best fitness: 1719.0
# Iter time: 1.1341519355773926
#
#
# Working on iter: 158 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1800
#     GA best fitness: 1720.0
# Iter time: 3.2555031776428223
#
#
# Working on iter: 159 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1800
#     GA best fitness: 1723.0
# Iter time: 2.964158773422241
#
#
# Working on iter: 160 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1800
#     GA best fitness: 1702.0
# Iter time: 1.6500420570373535
#
#
# Working on iter: 161 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1800
#     GA best fitness: 1731.0
# Iter time: 4.876877069473267
#
#
# Working on iter: 162 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1800
#     GA best fitness: 1723.0
# Iter time: 8.435168981552124
#
#
# Working on iter: 163 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1900
#     GA best fitness: 1694.0
# Iter time: 0.5437920093536377
#
#
# Working on iter: 164 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1900
#     GA best fitness: 1743.0
# Iter time: 1.0390448570251465
#
#
# Working on iter: 165 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1900
#     GA best fitness: 1682.0
# Iter time: 2.143754720687866
#
#
# Working on iter: 166 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1900
#     GA best fitness: 1710.0
# Iter time: 4.501899003982544
#
#
# Working on iter: 167 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1900
#     GA best fitness: 1697.0
# Iter time: 3.3465538024902344
#
#
# Working on iter: 168 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1900
#     GA best fitness: 1691.0
# Iter time: 2.382580280303955
#
#
# Working on iter: 169 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1900
#     GA best fitness: 1728.0
# Iter time: 2.6019859313964844
#
#
# Working on iter: 170 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1900
#     GA best fitness: 1723.0
# Iter time: 4.658705949783325
#
#
# Working on iter: 171 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1900
#     GA best fitness: 1721.0
# Iter time: 6.866864204406738
#
#
# Working on iter: 172 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 2000
#     GA best fitness: 1702.0
# Iter time: 1.0189788341522217
#
#
# Working on iter: 173 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 2000
#     GA best fitness: 1698.0
# Iter time: 2.6086950302124023
#
#
# Working on iter: 174 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 2000
#     GA best fitness: 1695.0
# Iter time: 2.1416971683502197
#
#
# Working on iter: 175 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 2000
#     GA best fitness: 1760.0
# Iter time: 2.8803551197052
#
#
# Working on iter: 176 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 2000
#     GA best fitness: 1764.0
# Iter time: 4.692039251327515
#
#
# Working on iter: 177 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 2000
#     GA best fitness: 1733.0
# Iter time: 5.425633192062378
#
#
# Working on iter: 178 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 2000
#     GA best fitness: 1709.0
# Iter time: 2.022913932800293
#
#
# Working on iter: 179 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 2000
#     GA best fitness: 1692.0
# Iter time: 3.27827787399292
#
#
# Working on iter: 180 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 2000
#     GA best fitness: 1696.0
# Iter time: 3.4165728092193604
#
#
# Done.

# %% [markdown]
# ## FlipFlop

# %%
#Inputs for FlipFlop problem
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
fitness_fn = mlrose.FlipFlop()

#Initialize an empty data frame for recording results
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
flip_flop_results = pd.DataFrame(columns = ["algorithm",
                                            "pop_size",
                                            "mutation_prob",
                                            "length",
                                            "max_attempt",
                                            "max_iter",
                                            "best_fitness",
                                            "time",
                                            "function_evaluations"])

#Loop
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Start an iteration counter
iter = 1
#For each unique number of objects
for length in lengths:
    
    #Set the optimization problem object
    problem = mlrose.DiscreteOpt(length = length,
                                 fitness_fn = fitness_fn,
                                 maximize = True,
                                 max_val = max_val)
    
    #For each combination of max attempt, max iteration, and random restart
    for max_attempt in max_attempts:
        for max_iter in max_iters:
            for pop_size in pop_sizes:
                for mutation_prob in mutation_probs:
                
                    #Ensuring reproducibility
                    random_state = iter
                
                    #Start a timer for each iteration
                    start = time.time()

                    #Print message
                    print("Working on iter:", iter,
                          "Length:", length,
                          "Population size:", pop_size,
                          "Mutation proab:", mutation_prob,
                          "Max attempt:", max_attempt,
                          "Max iter:", max_iter)

                    #Genetic Algorithm
                    #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
                    #Start the timer for Genetic Algorithm
                    ga_start = time.time()

                    #Optimization
                    (ga_best_state,
                     ga_best_fitness,
                     ga_fitness_curve) = mlrose.genetic_alg(problem = problem,
                                                            pop_size = pop_size,
                                                            mutation_prob = mutation_prob,
                                                            max_attempts = max_attempt,
                                                            max_iters = max_iter,
                                                            curve = curve,
                                                            random_state = random_state)
                    #End the timer
                    ga_end = time.time()
                    #Get the total time
                    ga_time = ga_end - ga_start

                    #Message
                    print("    GA best fitness:", ga_best_fitness)

                    #Add to results list
                    flip_flop_results = flip_flop_results.append({"algorithm": "genetic_algorithm",
                                                                  "pop_size": pop_size,
                                                                  "mutation_prob": mutation_prob,
                                                                  "length": length,
                                                                  "max_attempt": max_attempt,
                                                                  "max_iter": max_iter,
                                                                  "best_fitness": ga_best_fitness,
                                                                  "time": ga_time,
                                                                  "function_evaluations": np.argmax(ga_fitness_curve) + 1},
                                                                   ignore_index = True)

                    end = time.time()
                    iter_time = end - start
                    print("Iter time:", iter_time)

                    print("\n")
                    iter = iter + 1

#Output results
flip_flop_results.to_csv(output_flip_flop + "flip_flop_ga.csv", index = False)
pd.DataFrame(ga_fitness_curve).to_csv(output_flip_flop + "flip_flop_ga_curve.csv", index = False)

#Done
print("Done.")
# Out:
# Working on iter: 1 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 100
#     GA best fitness: 565.0
# Iter time: 1.6891980171203613
#
#
# Working on iter: 2 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 100
#     GA best fitness: 561.0
# Iter time: 3.4230990409851074
#
#
# Working on iter: 3 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 100
#     GA best fitness: 553.0
# Iter time: 3.0398120880126953
#
#
# Working on iter: 4 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 100
#     GA best fitness: 558.0
# Iter time: 4.855298042297363
#
#
# Working on iter: 5 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 100
#     GA best fitness: 560.0
# Iter time: 5.0186638832092285
#
#
# Working on iter: 6 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 100
#     GA best fitness: 556.0
# Iter time: 6.800121784210205
#
#
# Working on iter: 7 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 100
#     GA best fitness: 561.0
# Iter time: 6.846495151519775
#
#
# Working on iter: 8 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 100
#     GA best fitness: 559.0
# Iter time: 5.763671875
#
#
# Working on iter: 9 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 100
#     GA best fitness: 573.0
# Iter time: 6.622277021408081
#
#
# Working on iter: 10 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 200
#     GA best fitness: 550.0
# Iter time: 1.7617318630218506
#
#
# Working on iter: 11 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 200
#     GA best fitness: 558.0
# Iter time: 3.1779189109802246
#
#
# Working on iter: 12 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 200
#     GA best fitness: 557.0
# Iter time: 1.7315900325775146
#
#
# Working on iter: 13 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 200
#     GA best fitness: 558.0
# Iter time: 3.9741108417510986
#
#
# Working on iter: 14 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 200
#     GA best fitness: 557.0
# Iter time: 3.21706223487854
#
#
# Working on iter: 15 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 200
#     GA best fitness: 557.0
# Iter time: 6.034696102142334
#
#
# Working on iter: 16 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 200
#     GA best fitness: 556.0
# Iter time: 3.484766960144043
#
#
# Working on iter: 17 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 200
#     GA best fitness: 556.0
# Iter time: 7.847544193267822
#
#
# Working on iter: 18 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 200
#     GA best fitness: 561.0
# Iter time: 13.07232403755188
#
#
# Working on iter: 19 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 300
#     GA best fitness: 557.0
# Iter time: 1.5615870952606201
#
#
# Working on iter: 20 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 300
#     GA best fitness: 556.0
# Iter time: 1.8948500156402588
#
#
# Working on iter: 21 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 300
#     GA best fitness: 562.0
# Iter time: 3.686936140060425
#
#
# Working on iter: 22 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 300
#     GA best fitness: 552.0
# Iter time: 3.664185047149658
#
#
# Working on iter: 23 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 300
#     GA best fitness: 561.0
# Iter time: 3.113295316696167
#
#
# Working on iter: 24 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 300
#     GA best fitness: 558.0
# Iter time: 4.143787860870361
#
#
# Working on iter: 25 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 300
#     GA best fitness: 555.0
# Iter time: 5.458983898162842
#
#
# Working on iter: 26 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 300
#     GA best fitness: 552.0
# Iter time: 8.751580953598022
#
#
# Working on iter: 27 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 300
#     GA best fitness: 560.0
# Iter time: 7.3067028522491455
#
#
# Working on iter: 28 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 400
#     GA best fitness: 557.0
# Iter time: 2.3121531009674072
#
#
# Working on iter: 29 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 400
#     GA best fitness: 553.0
# Iter time: 2.280050754547119
#
#
# Working on iter: 30 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 400
#     GA best fitness: 557.0
# Iter time: 2.3518779277801514
#
#
# Working on iter: 31 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 400
#     GA best fitness: 553.0
# Iter time: 3.4453420639038086
#
#
# Working on iter: 32 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 400
#     GA best fitness: 558.0
# Iter time: 4.411653995513916
#
#
# Working on iter: 33 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 400
#     GA best fitness: 567.0
# Iter time: 6.870378017425537
#
#
# Working on iter: 34 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 400
#     GA best fitness: 567.0
# Iter time: 9.52864384651184
#
#
# Working on iter: 35 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 400
#     GA best fitness: 559.0
# Iter time: 6.612168073654175
#
#
# Working on iter: 36 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 400
#     GA best fitness: 561.0
# Iter time: 5.15522313117981
#
#
# Working on iter: 37 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 500
#     GA best fitness: 555.0
# Iter time: 1.9808440208435059
#
#
# Working on iter: 38 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 500
#     GA best fitness: 558.0
# Iter time: 1.6267821788787842
#
#
# Working on iter: 39 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 500
#     GA best fitness: 555.0
# Iter time: 2.161600112915039
#
#
# Working on iter: 40 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 500
#     GA best fitness: 564.0
# Iter time: 4.4620161056518555
#
#
# Working on iter: 41 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 500
#     GA best fitness: 559.0
# Iter time: 3.4713478088378906
#
#
# Working on iter: 42 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 500
#     GA best fitness: 564.0
# Iter time: 10.81321382522583
#
#
# Working on iter: 43 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 500
#     GA best fitness: 561.0
# Iter time: 5.928187131881714
#
#
# Working on iter: 44 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 500
#     GA best fitness: 559.0
# Iter time: 6.780577182769775
#
#
# Working on iter: 45 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 500
#     GA best fitness: 561.0
# Iter time: 5.82680869102478
#
#
# Working on iter: 46 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 600
#     GA best fitness: 560.0
# Iter time: 1.7985138893127441
#
#
# Working on iter: 47 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 600
#     GA best fitness: 550.0
# Iter time: 2.25173020362854
#
#
# Working on iter: 48 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 600
#     GA best fitness: 559.0
# Iter time: 1.9999291896820068
#
#
# Working on iter: 49 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 600
#     GA best fitness: 555.0
# Iter time: 2.891528844833374
#
#
# Working on iter: 50 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 600
#     GA best fitness: 573.0
# Iter time: 2.8201041221618652
#
#
# Working on iter: 51 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 600
#     GA best fitness: 551.0
# Iter time: 7.408852815628052
#
#
# Working on iter: 52 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 600
#     GA best fitness: 569.0
# Iter time: 6.388197898864746
#
#
# Working on iter: 53 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 600
#     GA best fitness: 552.0
# Iter time: 4.739617109298706
#
#
# Working on iter: 54 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 600
#     GA best fitness: 559.0
# Iter time: 9.907193183898926
#
#
# Working on iter: 55 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 700
#     GA best fitness: 552.0
# Iter time: 1.3725156784057617
#
#
# Working on iter: 56 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 700
#     GA best fitness: 555.0
# Iter time: 1.6237869262695312
#
#
# Working on iter: 57 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 700
#     GA best fitness: 554.0
# Iter time: 2.0829529762268066
#
#
# Working on iter: 58 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 700
#     GA best fitness: 561.0
# Iter time: 6.995392084121704
#
#
# Working on iter: 59 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 700
#     GA best fitness: 552.0
# Iter time: 5.329102039337158
#
#
# Working on iter: 60 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 700
#     GA best fitness: 562.0
# Iter time: 5.527159929275513
#
#
# Working on iter: 61 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 700
#     GA best fitness: 560.0
# Iter time: 3.4210071563720703
#
#
# Working on iter: 62 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 700
#     GA best fitness: 562.0
# Iter time: 4.6382670402526855
#
#
# Working on iter: 63 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 700
#     GA best fitness: 560.0
# Iter time: 6.625431060791016
#
#
# Working on iter: 64 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 800
#     GA best fitness: 544.0
# Iter time: 1.1191706657409668
#
#
# Working on iter: 65 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 800
#     GA best fitness: 554.0
# Iter time: 2.278045892715454
#
#
# Working on iter: 66 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 800
#     GA best fitness: 557.0
# Iter time: 4.502560138702393
#
#
# Working on iter: 67 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 800
#     GA best fitness: 568.0
# Iter time: 2.532926082611084
#
#
# Working on iter: 68 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 800
#     GA best fitness: 563.0
# Iter time: 2.9465389251708984
#
#
# Working on iter: 69 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 800
#     GA best fitness: 559.0
# Iter time: 6.62078070640564
#
#
# Working on iter: 70 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 800
#     GA best fitness: 558.0
# Iter time: 5.770174980163574
#
#
# Working on iter: 71 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 800
#     GA best fitness: 559.0
# Iter time: 7.638152122497559
#
#
# Working on iter: 72 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 800
#     GA best fitness: 557.0
# Iter time: 7.07198429107666
#
#
# Working on iter: 73 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 900
#     GA best fitness: 555.0
# Iter time: 1.5313830375671387
#
#
# Working on iter: 74 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 900
#     GA best fitness: 553.0
# Iter time: 4.508244037628174
#
#
# Working on iter: 75 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 900
#     GA best fitness: 550.0
# Iter time: 1.752971887588501
#
#
# Working on iter: 76 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 900
#     GA best fitness: 557.0
# Iter time: 2.3267698287963867
#
#
# Working on iter: 77 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 900
#     GA best fitness: 553.0
# Iter time: 2.8005361557006836
#
#
# Working on iter: 78 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 900
#     GA best fitness: 559.0
# Iter time: 4.582167148590088
#
#
# Working on iter: 79 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 900
#     GA best fitness: 561.0
# Iter time: 12.901687622070312
#
#
# Working on iter: 80 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 900
#     GA best fitness: 556.0
# Iter time: 5.960933685302734
#
#
# Working on iter: 81 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 900
#     GA best fitness: 561.0
# Iter time: 10.900736093521118
#
#
# Working on iter: 82 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1000
#     GA best fitness: 561.0
# Iter time: 1.8924798965454102
#
#
# Working on iter: 83 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1000
#     GA best fitness: 556.0
# Iter time: 1.8971028327941895
#
#
# Working on iter: 84 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1000
#     GA best fitness: 552.0
# Iter time: 2.368462085723877
#
#
# Working on iter: 85 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1000
#     GA best fitness: 556.0
# Iter time: 4.32093620300293
#
#
# Working on iter: 86 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1000
#     GA best fitness: 560.0
# Iter time: 3.8384389877319336
#
#
# Working on iter: 87 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1000
#     GA best fitness: 555.0
# Iter time: 5.951080083847046
#
#
# Working on iter: 88 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1000
#     GA best fitness: 562.0
# Iter time: 3.7518813610076904
#
#
# Working on iter: 89 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1000
#     GA best fitness: 564.0
# Iter time: 6.843791961669922
#
#
# Working on iter: 90 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1000
#     GA best fitness: 565.0
# Iter time: 10.950543880462646
#
#
# Working on iter: 91 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1100
#     GA best fitness: 549.0
# Iter time: 1.2557659149169922
#
#
# Working on iter: 92 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1100
#     GA best fitness: 561.0
# Iter time: 3.570834159851074
#
#
# Working on iter: 93 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1100
#     GA best fitness: 555.0
# Iter time: 2.7906830310821533
#
#
# Working on iter: 94 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1100
#     GA best fitness: 561.0
# Iter time: 2.636866807937622
#
#
# Working on iter: 95 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1100
#     GA best fitness: 550.0
# Iter time: 3.0986361503601074
#
#
# Working on iter: 96 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1100
#     GA best fitness: 563.0
# Iter time: 7.9477808475494385
#
#
# Working on iter: 97 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1100
#     GA best fitness: 559.0
# Iter time: 3.312250852584839
#
#
# Working on iter: 98 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1100
#     GA best fitness: 561.0
# Iter time: 6.801027059555054
#
#
# Working on iter: 99 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1100
#     GA best fitness: 566.0
# Iter time: 7.036272764205933
#
#
# Working on iter: 100 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1200
#     GA best fitness: 558.0
# Iter time: 1.7156097888946533
#
#
# Working on iter: 101 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1200
#     GA best fitness: 548.0
# Iter time: 1.9443650245666504
#
#
# Working on iter: 102 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1200
#     GA best fitness: 553.0
# Iter time: 2.1647799015045166
#
#
# Working on iter: 103 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1200
#     GA best fitness: 554.0
# Iter time: 2.2121589183807373
#
#
# Working on iter: 104 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1200
#     GA best fitness: 558.0
# Iter time: 3.1766412258148193
#
#
# Working on iter: 105 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1200
#     GA best fitness: 568.0
# Iter time: 8.707053899765015
#
#
# Working on iter: 106 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1200
#     GA best fitness: 563.0
# Iter time: 6.271376848220825
#
#
# Working on iter: 107 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1200
#     GA best fitness: 561.0
# Iter time: 10.726808071136475
#
#
# Working on iter: 108 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1200
#     GA best fitness: 555.0
# Iter time: 11.111274242401123
#
#
# Working on iter: 109 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1300
#     GA best fitness: 555.0
# Iter time: 1.3185832500457764
#
#
# Working on iter: 110 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1300
#     GA best fitness: 553.0
# Iter time: 2.298286199569702
#
#
# Working on iter: 111 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1300
#     GA best fitness: 554.0
# Iter time: 4.421850919723511
#
#
# Working on iter: 112 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1300
#     GA best fitness: 552.0
# Iter time: 2.200944185256958
#
#
# Working on iter: 113 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1300
#     GA best fitness: 569.0
# Iter time: 7.2573771476745605
#
#
# Working on iter: 114 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1300
#     GA best fitness: 560.0
# Iter time: 3.4214260578155518
#
#
# Working on iter: 115 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1300
#     GA best fitness: 553.0
# Iter time: 4.4476399421691895
#
#
# Working on iter: 116 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1300
#     GA best fitness: 560.0
# Iter time: 8.743243932723999
#
#
# Working on iter: 117 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1300
#     GA best fitness: 557.0
# Iter time: 9.429434061050415
#
#
# Working on iter: 118 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1400
#     GA best fitness: 554.0
# Iter time: 1.7983238697052002
#
#
# Working on iter: 119 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1400
#     GA best fitness: 550.0
# Iter time: 1.878509283065796
#
#
# Working on iter: 120 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1400
#     GA best fitness: 556.0
# Iter time: 2.642688035964966
#
#
# Working on iter: 121 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1400
#     GA best fitness: 560.0
# Iter time: 3.208519220352173
#
#
# Working on iter: 122 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1400
#     GA best fitness: 556.0
# Iter time: 5.0958569049835205
#
#
# Working on iter: 123 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1400
#     GA best fitness: 561.0
# Iter time: 7.095963954925537
#
#
# Working on iter: 124 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1400
#     GA best fitness: 564.0
# Iter time: 6.692446231842041
#
#
# Working on iter: 125 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1400
#     GA best fitness: 558.0
# Iter time: 5.01731014251709
#
#
# Working on iter: 126 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1400
#     GA best fitness: 564.0
# Iter time: 11.576894044876099
#
#
# Working on iter: 127 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1500
#     GA best fitness: 549.0
# Iter time: 1.7271990776062012
#
#
# Working on iter: 128 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1500
#     GA best fitness: 561.0
# Iter time: 3.373462200164795
#
#
# Working on iter: 129 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1500
#     GA best fitness: 554.0
# Iter time: 3.4872419834136963
#
#
# Working on iter: 130 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1500
#     GA best fitness: 564.0
# Iter time: 3.4608469009399414
#
#
# Working on iter: 131 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1500
#     GA best fitness: 561.0
# Iter time: 4.112903118133545
#
#
# Working on iter: 132 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1500
#     GA best fitness: 553.0
# Iter time: 3.409076452255249
#
#
# Working on iter: 133 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1500
#     GA best fitness: 565.0
# Iter time: 3.461728096008301
#
#
# Working on iter: 134 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1500
#     GA best fitness: 559.0
# Iter time: 6.6273767948150635
#
#
# Working on iter: 135 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1500
#     GA best fitness: 557.0
# Iter time: 5.631947994232178
#
#
# Working on iter: 136 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1600
#     GA best fitness: 548.0
# Iter time: 1.7522222995758057
#
#
# Working on iter: 137 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1600
#     GA best fitness: 552.0
# Iter time: 1.8422000408172607
#
#
# Working on iter: 138 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1600
#     GA best fitness: 553.0
# Iter time: 2.268240213394165
#
#
# Working on iter: 139 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1600
#     GA best fitness: 559.0
# Iter time: 3.524914264678955
#
#
# Working on iter: 140 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1600
#     GA best fitness: 564.0
# Iter time: 3.8097269535064697
#
#
# Working on iter: 141 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1600
#     GA best fitness: 566.0
# Iter time: 7.658843755722046
#
#
# Working on iter: 142 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1600
#     GA best fitness: 562.0
# Iter time: 9.752381324768066
#
#
# Working on iter: 143 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1600
#     GA best fitness: 560.0
# Iter time: 6.158644914627075
#
#
# Working on iter: 144 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1600
#     GA best fitness: 561.0
# Iter time: 5.127266883850098
#
#
# Working on iter: 145 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1700
#     GA best fitness: 559.0
# Iter time: 1.7328321933746338
#
#
# Working on iter: 146 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1700
#     GA best fitness: 556.0
# Iter time: 2.66965913772583
#
#
# Working on iter: 147 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1700
#     GA best fitness: 557.0
# Iter time: 5.376420736312866
#
#
# Working on iter: 148 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1700
#     GA best fitness: 560.0
# Iter time: 4.996025800704956
#
#
# Working on iter: 149 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1700
#     GA best fitness: 555.0
# Iter time: 8.098968982696533
#
#
# Working on iter: 150 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1700
#     GA best fitness: 551.0
# Iter time: 4.063277006149292
#
#
# Working on iter: 151 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1700
#     GA best fitness: 565.0
# Iter time: 6.225243091583252
#
#
# Working on iter: 152 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1700
#     GA best fitness: 558.0
# Iter time: 5.5844810009002686
#
#
# Working on iter: 153 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1700
#     GA best fitness: 568.0
# Iter time: 5.092437028884888
#
#
# Working on iter: 154 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1800
#     GA best fitness: 552.0
# Iter time: 2.07236385345459
#
#
# Working on iter: 155 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1800
#     GA best fitness: 559.0
# Iter time: 2.5758352279663086
#
#
# Working on iter: 156 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1800
#     GA best fitness: 560.0
# Iter time: 3.608736038208008
#
#
# Working on iter: 157 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1800
#     GA best fitness: 556.0
# Iter time: 2.426002025604248
#
#
# Working on iter: 158 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1800
#     GA best fitness: 559.0
# Iter time: 6.327232122421265
#
#
# Working on iter: 159 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1800
#     GA best fitness: 557.0
# Iter time: 4.005353927612305
#
#
# Working on iter: 160 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1800
#     GA best fitness: 568.0
# Iter time: 3.903388023376465
#
#
# Working on iter: 161 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1800
#     GA best fitness: 560.0
# Iter time: 5.745322942733765
#
#
# Working on iter: 162 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1800
#     GA best fitness: 561.0
# Iter time: 6.529288053512573
#
#
# Working on iter: 163 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1900
#     GA best fitness: 552.0
# Iter time: 3.6530699729919434
#
#
# Working on iter: 164 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1900
#     GA best fitness: 553.0
# Iter time: 1.6615898609161377
#
#
# Working on iter: 165 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1900
#     GA best fitness: 553.0
# Iter time: 3.997199058532715
#
#
# Working on iter: 166 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1900
#     GA best fitness: 556.0
# Iter time: 3.8081629276275635
#
#
# Working on iter: 167 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1900
#     GA best fitness: 556.0
# Iter time: 4.608904838562012
#
#
# Working on iter: 168 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1900
#     GA best fitness: 560.0
# Iter time: 4.042553901672363
#
#
# Working on iter: 169 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1900
#     GA best fitness: 561.0
# Iter time: 5.288258075714111
#
#
# Working on iter: 170 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1900
#     GA best fitness: 564.0
# Iter time: 6.555827856063843
#
#
# Working on iter: 171 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1900
#     GA best fitness: 568.0
# Iter time: 19.1025710105896
#
#
# Working on iter: 172 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 2000
#     GA best fitness: 563.0
# Iter time: 1.2531700134277344
#
#
# Working on iter: 173 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 2000
#     GA best fitness: 557.0
# Iter time: 3.143526077270508
#
#
# Working on iter: 174 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 2000
#     GA best fitness: 550.0
# Iter time: 3.4737038612365723
#
#
# Working on iter: 175 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 2000
#     GA best fitness: 569.0
# Iter time: 2.509842872619629
#
#
# Working on iter: 176 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 2000
#     GA best fitness: 562.0
# Iter time: 3.9751806259155273
#
#
# Working on iter: 177 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 2000
#     GA best fitness: 558.0
# Iter time: 9.709761142730713
#
#
# Working on iter: 178 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 2000
#     GA best fitness: 563.0
# Iter time: 4.342284202575684
#
#
# Working on iter: 179 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 2000
#     GA best fitness: 558.0
# Iter time: 9.848720788955688
#
#
# Working on iter: 180 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 2000
#     GA best fitness: 557.0
# Iter time: 6.519930124282837
#
#
# Done.

# %% [markdown]
# ### OneMax

# %%
#Inputs for FlipFlop problem
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
fitness_fn = mlrose.OneMax()

#Initialize an empty data frame for recording results
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
one_max_results = pd.DataFrame(columns = ["algorithm",
                                          "pop_size",
                                          "mutation_prob",
                                          "length",
                                          "max_attempt",
                                          "max_iter",
                                          "best_fitness",
                                          "time",
                                          "function_evaluations"])

#Loop
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Start an iteration counter
iter = 1
#For each unique number of objects
for length in lengths:
    
    #Set the optimization problem object
    problem = mlrose.DiscreteOpt(length = length,
                                 fitness_fn = fitness_fn,
                                 maximize = True,
                                 max_val = max_val)
    
    #For each combination of max attempt, max iteration, and random restart
    for max_attempt in max_attempts:
        for max_iter in max_iters:
            for pop_size in pop_sizes:
                for mutation_prob in mutation_probs:
                
                    #Ensuring reproducibility
                    random_state = iter
                
                    #Start a timer for each iteration
                    start = time.time()

                    #Print message
                    print("Working on iter:", iter,
                          "Length:", length,
                          "Population size:", pop_size,
                          "Mutation proab:", mutation_prob,
                          "Max attempt:", max_attempt,
                          "Max iter:", max_iter)

                    #Genetic Algorithm
                    #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
                    #Start the timer for Genetic Algorithm
                    ga_start = time.time()

                    #Optimization
                    (ga_best_state,
                     ga_best_fitness,
                     ga_fitness_curve) = mlrose.genetic_alg(problem = problem,
                                                            pop_size = pop_size,
                                                            mutation_prob = mutation_prob,
                                                            max_attempts = max_attempt,
                                                            max_iters = max_iter,
                                                            curve = curve,
                                                            random_state = random_state)
                    #End the timer
                    ga_end = time.time()
                    #Get the total time
                    ga_time = ga_end - ga_start

                    #Message
                    print("    GA best fitness:", ga_best_fitness)

                    #Add to results list
                    one_max_results = one_max_results.append({"algorithm": "genetic_algorithm",
                                                              "pop_size": pop_size,
                                                              "mutation_prob": mutation_prob,
                                                              "length": length,
                                                              "max_attempt": max_attempt,
                                                              "max_iter": max_iter,
                                                              "best_fitness": ga_best_fitness,
                                                              "time": ga_time,
                                                              "function_evaluations": np.argmax(ga_fitness_curve) + 1},
                                                              ignore_index = True)

                    end = time.time()
                    iter_time = end - start
                    print("Iter time:", iter_time)

                    print("\n")
                    iter = iter + 1

#Output results
one_max_results.to_csv(output_one_max + "one_max_ga.csv", index = False)
pd.DataFrame(ga_fitness_curve).to_csv(output_one_max + "one_max_ga_curve.csv", index = False)

#Done
print("Done.")
# Out:
# Working on iter: 1 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 100
#     GA best fitness: 555.0
# Iter time: 0.534700870513916
#
#
# Working on iter: 2 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 100
#     GA best fitness: 554.0
# Iter time: 1.17342209815979
#
#
# Working on iter: 3 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 100
#     GA best fitness: 554.0
# Iter time: 2.1630210876464844
#
#
# Working on iter: 4 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 100
#     GA best fitness: 550.0
# Iter time: 1.2985117435455322
#
#
# Working on iter: 5 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 100
#     GA best fitness: 551.0
# Iter time: 1.957118034362793
#
#
# Working on iter: 6 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 100
#     GA best fitness: 565.0
# Iter time: 2.753019094467163
#
#
# Working on iter: 7 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 100
#     GA best fitness: 562.0
# Iter time: 2.1813230514526367
#
#
# Working on iter: 8 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 100
#     GA best fitness: 559.0
# Iter time: 4.568049907684326
#
#
# Working on iter: 9 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 100
#     GA best fitness: 571.0
# Iter time: 6.534404754638672
#
#
# Working on iter: 10 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 200
#     GA best fitness: 567.0
# Iter time: 1.5106267929077148
#
#
# Working on iter: 11 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 200
#     GA best fitness: 559.0
# Iter time: 1.1624789237976074
#
#
# Working on iter: 12 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 200
#     GA best fitness: 562.0
# Iter time: 3.1080777645111084
#
#
# Working on iter: 13 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 200
#     GA best fitness: 561.0
# Iter time: 3.050076961517334
#
#
# Working on iter: 14 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 200
#     GA best fitness: 564.0
# Iter time: 1.8702630996704102
#
#
# Working on iter: 15 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 200
#     GA best fitness: 552.0
# Iter time: 3.4011030197143555
#
#
# Working on iter: 16 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 200
#     GA best fitness: 559.0
# Iter time: 2.839423179626465
#
#
# Working on iter: 17 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 200
#     GA best fitness: 557.0
# Iter time: 3.636237144470215
#
#
# Working on iter: 18 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 200
#     GA best fitness: 559.0
# Iter time: 7.3851988315582275
#
#
# Working on iter: 19 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 300
#     GA best fitness: 556.0
# Iter time: 0.6977429389953613
#
#
# Working on iter: 20 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 300
#     GA best fitness: 553.0
# Iter time: 0.9345242977142334
#
#
# Working on iter: 21 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 300
#     GA best fitness: 559.0
# Iter time: 1.7395730018615723
#
#
# Working on iter: 22 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 300
#     GA best fitness: 561.0
# Iter time: 2.3049638271331787
#
#
# Working on iter: 23 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 300
#     GA best fitness: 556.0
# Iter time: 3.82096004486084
#
#
# Working on iter: 24 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 300
#     GA best fitness: 553.0
# Iter time: 2.315899133682251
#
#
# Working on iter: 25 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 300
#     GA best fitness: 557.0
# Iter time: 1.8822400569915771
#
#
# Working on iter: 26 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 300
#     GA best fitness: 557.0
# Iter time: 2.928023099899292
#
#
# Working on iter: 27 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 300
#     GA best fitness: 567.0
# Iter time: 6.241862773895264
#
#
# Working on iter: 28 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 400
#     GA best fitness: 557.0
# Iter time: 0.7274198532104492
#
#
# Working on iter: 29 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 400
#     GA best fitness: 556.0
# Iter time: 1.143263816833496
#
#
# Working on iter: 30 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 400
#     GA best fitness: 555.0
# Iter time: 1.7937021255493164
#
#
# Working on iter: 31 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 400
#     GA best fitness: 557.0
# Iter time: 1.1437709331512451
#
#
# Working on iter: 32 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 400
#     GA best fitness: 554.0
# Iter time: 2.333158254623413
#
#
# Working on iter: 33 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 400
#     GA best fitness: 552.0
# Iter time: 2.343686103820801
#
#
# Working on iter: 34 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 400
#     GA best fitness: 569.0
# Iter time: 3.1097612380981445
#
#
# Working on iter: 35 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 400
#     GA best fitness: 557.0
# Iter time: 2.824887990951538
#
#
# Working on iter: 36 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 400
#     GA best fitness: 564.0
# Iter time: 5.2930450439453125
#
#
# Working on iter: 37 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 500
#     GA best fitness: 557.0
# Iter time: 0.9954690933227539
#
#
# Working on iter: 38 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 500
#     GA best fitness: 560.0
# Iter time: 1.0134940147399902
#
#
# Working on iter: 39 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 500
#     GA best fitness: 562.0
# Iter time: 2.643282890319824
#
#
# Working on iter: 40 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 500
#     GA best fitness: 566.0
# Iter time: 2.4769201278686523
#
#
# Working on iter: 41 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 500
#     GA best fitness: 559.0
# Iter time: 1.797184944152832
#
#
# Working on iter: 42 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 500
#     GA best fitness: 557.0
# Iter time: 2.3507049083709717
#
#
# Working on iter: 43 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 500
#     GA best fitness: 562.0
# Iter time: 2.036048173904419
#
#
# Working on iter: 44 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 500
#     GA best fitness: 556.0
# Iter time: 3.4338619709014893
#
#
# Working on iter: 45 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 500
#     GA best fitness: 569.0
# Iter time: 6.539408206939697
#
#
# Working on iter: 46 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 600
#     GA best fitness: 549.0
# Iter time: 0.5260839462280273
#
#
# Working on iter: 47 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 600
#     GA best fitness: 557.0
# Iter time: 1.3671197891235352
#
#
# Working on iter: 48 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 600
#     GA best fitness: 557.0
# Iter time: 3.253814935684204
#
#
# Working on iter: 49 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 600
#     GA best fitness: 562.0
# Iter time: 2.4862818717956543
#
#
# Working on iter: 50 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 600
#     GA best fitness: 556.0
# Iter time: 2.4825222492218018
#
#
# Working on iter: 51 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 600
#     GA best fitness: 561.0
# Iter time: 2.6665940284729004
#
#
# Working on iter: 52 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 600
#     GA best fitness: 563.0
# Iter time: 2.3856959342956543
#
#
# Working on iter: 53 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 600
#     GA best fitness: 568.0
# Iter time: 2.6190569400787354
#
#
# Working on iter: 54 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 600
#     GA best fitness: 561.0
# Iter time: 4.302196979522705
#
#
# Working on iter: 55 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 700
#     GA best fitness: 556.0
# Iter time: 0.5262138843536377
#
#
# Working on iter: 56 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 700
#     GA best fitness: 557.0
# Iter time: 1.9936769008636475
#
#
# Working on iter: 57 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 700
#     GA best fitness: 558.0
# Iter time: 2.5519421100616455
#
#
# Working on iter: 58 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 700
#     GA best fitness: 554.0
# Iter time: 1.452497959136963
#
#
# Working on iter: 59 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 700
#     GA best fitness: 563.0
# Iter time: 1.7276029586791992
#
#
# Working on iter: 60 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 700
#     GA best fitness: 561.0
# Iter time: 4.3508522510528564
#
#
# Working on iter: 61 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 700
#     GA best fitness: 567.0
# Iter time: 4.010403156280518
#
#
# Working on iter: 62 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 700
#     GA best fitness: 559.0
# Iter time: 3.426017999649048
#
#
# Working on iter: 63 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 700
#     GA best fitness: 552.0
# Iter time: 3.3811020851135254
#
#
# Working on iter: 64 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 800
#     GA best fitness: 553.0
# Iter time: 1.485541820526123
#
#
# Working on iter: 65 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 800
#     GA best fitness: 562.0
# Iter time: 1.2214698791503906
#
#
# Working on iter: 66 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 800
#     GA best fitness: 552.0
# Iter time: 1.390787124633789
#
#
# Working on iter: 67 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 800
#     GA best fitness: 557.0
# Iter time: 2.5962748527526855
#
#
# Working on iter: 68 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 800
#     GA best fitness: 557.0
# Iter time: 2.030787944793701
#
#
# Working on iter: 69 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 800
#     GA best fitness: 558.0
# Iter time: 3.4259629249572754
#
#
# Working on iter: 70 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 800
#     GA best fitness: 566.0
# Iter time: 2.852231979370117
#
#
# Working on iter: 71 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 800
#     GA best fitness: 562.0
# Iter time: 4.118788003921509
#
#
# Working on iter: 72 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 800
#     GA best fitness: 566.0
# Iter time: 5.591223955154419
#
#
# Working on iter: 73 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 900
#     GA best fitness: 553.0
# Iter time: 0.8245279788970947
#
#
# Working on iter: 74 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 900
#     GA best fitness: 559.0
# Iter time: 1.3277990818023682
#
#
# Working on iter: 75 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 900
#     GA best fitness: 551.0
# Iter time: 1.5390560626983643
#
#
# Working on iter: 76 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 900
#     GA best fitness: 557.0
# Iter time: 1.1501939296722412
#
#
# Working on iter: 77 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 900
#     GA best fitness: 554.0
# Iter time: 1.7964351177215576
#
#
# Working on iter: 78 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 900
#     GA best fitness: 557.0
# Iter time: 3.198476791381836
#
#
# Working on iter: 79 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 900
#     GA best fitness: 560.0
# Iter time: 3.7430012226104736
#
#
# Working on iter: 80 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 900
#     GA best fitness: 563.0
# Iter time: 6.016473054885864
#
#
# Working on iter: 81 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 900
#     GA best fitness: 558.0
# Iter time: 5.132028102874756
#
#
# Working on iter: 82 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1000
#     GA best fitness: 545.0
# Iter time: 0.5266051292419434
#
#
# Working on iter: 83 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1000
#     GA best fitness: 550.0
# Iter time: 1.3272318840026855
#
#
# Working on iter: 84 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1000
#     GA best fitness: 554.0
# Iter time: 1.6467969417572021
#
#
# Working on iter: 85 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1000
#     GA best fitness: 558.0
# Iter time: 2.3970019817352295
#
#
# Working on iter: 86 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1000
#     GA best fitness: 549.0
# Iter time: 2.334658145904541
#
#
# Working on iter: 87 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1000
#     GA best fitness: 559.0
# Iter time: 3.2988059520721436
#
#
# Working on iter: 88 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1000
#     GA best fitness: 566.0
# Iter time: 1.88173508644104
#
#
# Working on iter: 89 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1000
#     GA best fitness: 553.0
# Iter time: 2.588139057159424
#
#
# Working on iter: 90 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1000
#     GA best fitness: 560.0
# Iter time: 4.674530982971191
#
#
# Working on iter: 91 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1100
#     GA best fitness: 551.0
# Iter time: 1.066084861755371
#
#
# Working on iter: 92 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1100
#     GA best fitness: 560.0
# Iter time: 1.82698392868042
#
#
# Working on iter: 93 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1100
#     GA best fitness: 563.0
# Iter time: 3.341292142868042
#
#
# Working on iter: 94 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1100
#     GA best fitness: 559.0
# Iter time: 2.162424087524414
#
#
# Working on iter: 95 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1100
#     GA best fitness: 567.0
# Iter time: 2.581176996231079
#
#
# Working on iter: 96 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1100
#     GA best fitness: 563.0
# Iter time: 3.27585506439209
#
#
# Working on iter: 97 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1100
#     GA best fitness: 556.0
# Iter time: 2.5660040378570557
#
#
# Working on iter: 98 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1100
#     GA best fitness: 555.0
# Iter time: 2.8158071041107178
#
#
# Working on iter: 99 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1100
#     GA best fitness: 570.0
# Iter time: 5.457293272018433
#
#
# Working on iter: 100 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1200
#     GA best fitness: 549.0
# Iter time: 0.6956260204315186
#
#
# Working on iter: 101 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1200
#     GA best fitness: 560.0
# Iter time: 0.9339766502380371
#
#
# Working on iter: 102 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1200
#     GA best fitness: 554.0
# Iter time: 2.061417818069458
#
#
# Working on iter: 103 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1200
#     GA best fitness: 558.0
# Iter time: 2.686810255050659
#
#
# Working on iter: 104 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1200
#     GA best fitness: 564.0
# Iter time: 3.38830304145813
#
#
# Working on iter: 105 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1200
#     GA best fitness: 550.0
# Iter time: 2.6772282123565674
#
#
# Working on iter: 106 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1200
#     GA best fitness: 573.0
# Iter time: 4.057982921600342
#
#
# Working on iter: 107 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1200
#     GA best fitness: 554.0
# Iter time: 3.416670083999634
#
#
# Working on iter: 108 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1200
#     GA best fitness: 557.0
# Iter time: 6.069599866867065
#
#
# Working on iter: 109 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1300
#     GA best fitness: 561.0
# Iter time: 0.6474747657775879
#
#
# Working on iter: 110 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1300
#     GA best fitness: 555.0
# Iter time: 1.2121949195861816
#
#
# Working on iter: 111 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1300
#     GA best fitness: 560.0
# Iter time: 1.685642957687378
#
#
# Working on iter: 112 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1300
#     GA best fitness: 556.0
# Iter time: 1.990109920501709
#
#
# Working on iter: 113 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1300
#     GA best fitness: 555.0
# Iter time: 2.8844988346099854
#
#
# Working on iter: 114 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1300
#     GA best fitness: 556.0
# Iter time: 3.189638137817383
#
#
# Working on iter: 115 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1300
#     GA best fitness: 559.0
# Iter time: 2.471514940261841
#
#
# Working on iter: 116 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1300
#     GA best fitness: 564.0
# Iter time: 4.8289618492126465
#
#
# Working on iter: 117 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1300
#     GA best fitness: 556.0
# Iter time: 4.961809158325195
#
#
# Working on iter: 118 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1400
#     GA best fitness: 555.0
# Iter time: 0.5241329669952393
#
#
# Working on iter: 119 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1400
#     GA best fitness: 567.0
# Iter time: 0.9748489856719971
#
#
# Working on iter: 120 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1400
#     GA best fitness: 558.0
# Iter time: 2.555349826812744
#
#
# Working on iter: 121 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1400
#     GA best fitness: 567.0
# Iter time: 2.638225793838501
#
#
# Working on iter: 122 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1400
#     GA best fitness: 555.0
# Iter time: 1.7278361320495605
#
#
# Working on iter: 123 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1400
#     GA best fitness: 555.0
# Iter time: 3.855827808380127
#
#
# Working on iter: 124 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1400
#     GA best fitness: 561.0
# Iter time: 1.7318389415740967
#
#
# Working on iter: 125 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1400
#     GA best fitness: 574.0
# Iter time: 4.44861102104187
#
#
# Working on iter: 126 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1400
#     GA best fitness: 565.0
# Iter time: 3.8486669063568115
#
#
# Working on iter: 127 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1500
#     GA best fitness: 545.0
# Iter time: 0.5868968963623047
#
#
# Working on iter: 128 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1500
#     GA best fitness: 555.0
# Iter time: 1.1725940704345703
#
#
# Working on iter: 129 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1500
#     GA best fitness: 553.0
# Iter time: 1.9159369468688965
#
#
# Working on iter: 130 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1500
#     GA best fitness: 562.0
# Iter time: 1.1987278461456299
#
#
# Working on iter: 131 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1500
#     GA best fitness: 562.0
# Iter time: 1.7131907939910889
#
#
# Working on iter: 132 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1500
#     GA best fitness: 556.0
# Iter time: 3.088479995727539
#
#
# Working on iter: 133 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1500
#     GA best fitness: 558.0
# Iter time: 1.9565479755401611
#
#
# Working on iter: 134 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1500
#     GA best fitness: 574.0
# Iter time: 3.764431953430176
#
#
# Working on iter: 135 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1500
#     GA best fitness: 554.0
# Iter time: 3.9957010746002197
#
#
# Working on iter: 136 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1600
#     GA best fitness: 572.0
# Iter time: 0.5764360427856445
#
#
# Working on iter: 137 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1600
#     GA best fitness: 567.0
# Iter time: 1.294240951538086
#
#
# Working on iter: 138 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1600
#     GA best fitness: 555.0
# Iter time: 1.159182071685791
#
#
# Working on iter: 139 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1600
#     GA best fitness: 552.0
# Iter time: 1.7493619918823242
#
#
# Working on iter: 140 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1600
#     GA best fitness: 558.0
# Iter time: 4.123283386230469
#
#
# Working on iter: 141 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1600
#     GA best fitness: 566.0
# Iter time: 5.844609022140503
#
#
# Working on iter: 142 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1600
#     GA best fitness: 569.0
# Iter time: 4.185916900634766
#
#
# Working on iter: 143 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1600
#     GA best fitness: 556.0
# Iter time: 3.1666901111602783
#
#
# Working on iter: 144 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1600
#     GA best fitness: 557.0
# Iter time: 4.031575679779053
#
#
# Working on iter: 145 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1700
#     GA best fitness: 566.0
# Iter time: 0.6854982376098633
#
#
# Working on iter: 146 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1700
#     GA best fitness: 553.0
# Iter time: 0.8599531650543213
#
#
# Working on iter: 147 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1700
#     GA best fitness: 560.0
# Iter time: 1.3417589664459229
#
#
# Working on iter: 148 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1700
#     GA best fitness: 560.0
# Iter time: 1.6587297916412354
#
#
# Working on iter: 149 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1700
#     GA best fitness: 553.0
# Iter time: 2.3413610458374023
#
#
# Working on iter: 150 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1700
#     GA best fitness: 557.0
# Iter time: 3.5216028690338135
#
#
# Working on iter: 151 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1700
#     GA best fitness: 559.0
# Iter time: 3.5987820625305176
#
#
# Working on iter: 152 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1700
#     GA best fitness: 560.0
# Iter time: 4.722064971923828
#
#
# Working on iter: 153 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1700
#     GA best fitness: 557.0
# Iter time: 6.248627185821533
#
#
# Working on iter: 154 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1800
#     GA best fitness: 557.0
# Iter time: 0.6754710674285889
#
#
# Working on iter: 155 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1800
#     GA best fitness: 564.0
# Iter time: 2.60863995552063
#
#
# Working on iter: 156 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1800
#     GA best fitness: 553.0
# Iter time: 1.374863862991333
#
#
# Working on iter: 157 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1800
#     GA best fitness: 566.0
# Iter time: 1.7360739707946777
#
#
# Working on iter: 158 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1800
#     GA best fitness: 556.0
# Iter time: 2.565032958984375
#
#
# Working on iter: 159 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1800
#     GA best fitness: 562.0
# Iter time: 2.2330198287963867
#
#
# Working on iter: 160 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1800
#     GA best fitness: 558.0
# Iter time: 2.918339252471924
#
#
# Working on iter: 161 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1800
#     GA best fitness: 563.0
# Iter time: 4.925631046295166
#
#
# Working on iter: 162 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1800
#     GA best fitness: 556.0
# Iter time: 4.820439100265503
#
#
# Working on iter: 163 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 1900
#     GA best fitness: 556.0
# Iter time: 0.6232361793518066
#
#
# Working on iter: 164 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 1900
#     GA best fitness: 552.0
# Iter time: 1.0518341064453125
#
#
# Working on iter: 165 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 1900
#     GA best fitness: 559.0
# Iter time: 2.9724841117858887
#
#
# Working on iter: 166 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 1900
#     GA best fitness: 574.0
# Iter time: 2.2465598583221436
#
#
# Working on iter: 167 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 1900
#     GA best fitness: 559.0
# Iter time: 1.7971479892730713
#
#
# Working on iter: 168 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 1900
#     GA best fitness: 561.0
# Iter time: 3.1091599464416504
#
#
# Working on iter: 169 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 1900
#     GA best fitness: 561.0
# Iter time: 1.9729321002960205
#
#
# Working on iter: 170 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 1900
#     GA best fitness: 559.0
# Iter time: 2.606027841567993
#
#
# Working on iter: 171 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 1900
#     GA best fitness: 558.0
# Iter time: 6.766853094100952
#
#
# Working on iter: 172 Length: 1000 Population size: 100 Mutation proab: 0.1 Max attempt: 20 Max iter: 2000
#     GA best fitness: 556.0
# Iter time: 1.1088800430297852
#
#
# Working on iter: 173 Length: 1000 Population size: 100 Mutation proab: 0.2 Max attempt: 20 Max iter: 2000
#     GA best fitness: 549.0
# Iter time: 1.1338748931884766
#
#
# Working on iter: 174 Length: 1000 Population size: 100 Mutation proab: 0.3 Max attempt: 20 Max iter: 2000
#     GA best fitness: 554.0
# Iter time: 1.8546550273895264
#
#
# Working on iter: 175 Length: 1000 Population size: 200 Mutation proab: 0.1 Max attempt: 20 Max iter: 2000
#     GA best fitness: 561.0
# Iter time: 1.494290828704834
#
#
# Working on iter: 176 Length: 1000 Population size: 200 Mutation proab: 0.2 Max attempt: 20 Max iter: 2000
#     GA best fitness: 558.0
# Iter time: 4.537815093994141
#
#
# Working on iter: 177 Length: 1000 Population size: 200 Mutation proab: 0.3 Max attempt: 20 Max iter: 2000
#     GA best fitness: 550.0
# Iter time: 2.460184097290039
#
#
# Working on iter: 178 Length: 1000 Population size: 300 Mutation proab: 0.1 Max attempt: 20 Max iter: 2000
#     GA best fitness: 562.0
# Iter time: 3.7581071853637695
#
#
# Working on iter: 179 Length: 1000 Population size: 300 Mutation proab: 0.2 Max attempt: 20 Max iter: 2000
#     GA best fitness: 562.0
# Iter time: 3.6347157955169678
#
#
# Working on iter: 180 Length: 1000 Population size: 300 Mutation proab: 0.3 Max attempt: 20 Max iter: 2000
#     GA best fitness: 556.0
# Iter time: 4.806464910507202
#
#
# Done.
