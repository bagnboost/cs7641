# %% [markdown]
# # Randomized optimization
#
# Plaigiarism note: I partially took this course in 2020 so some of the analysis and text is repeated.

# %% [markdown]
# mlrose procedure:
#
# 1. Define a fitness function
# - This is the function we want to maximize or minimize, and is used to evaluate the fitness of a state vector.
# 2. Define an optimization problem object
# 3. Select and run a randomized optimization algorithm
#
# mlrose fitness functions: https://mlrose.readthedocs.io/en/stable/source/fitness.html

# %% [markdown]
# ## Load libraries

# %%
import six
import sys
sys.modules['sklearn.externals.six'] = six
import mlrose
import numpy as np
import pandas as pd
import time
from sklearn.preprocessing import normalize
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Set directories

# %%
directory_hw1 = "/Users/mikepecorino/Documents/machine_learning/HW1/"
directory_hw2 = "/Users/mikepecorino/Documents/machine_learning/HW2/"
output_four_peaks = directory_hw2 + "four_peaks/"
output_knapsack = directory_hw2 + "knapsack/"
output_flip_flop = directory_hw2 + "flip_flop/"
output_one_max = directory_hw2 + "one_max/"

# %% [markdown]
# ## Common inputs for each optimization problem

# %%
#Problem specific inputs
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Lengths of the state vector
lengths = [1000]
#Number of unique values for each x (0/1)
max_val = 2
#Keeping the fitness curves
curve = True
#Max attempts to find a better neighbor
max_attempts = [20]
#Max iterations
max_iters = range(100, 2100, 100)

#Algorithm specific inputs
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Mimic: population and proportion of samples to keep in each iteration
pop_sizes = [100]
keep_pcts = [0.1, 0.2, 0.3]

# %% [markdown]
# ## Four Peaks

# %%
#Inputs for four peaks problem
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Initialize the fitness function with default t_pct
fitness_fn = mlrose.FourPeaks(t_pct = 0.1)

#Initialize an empty data frame for recording results
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
four_peaks_results = pd.DataFrame(columns = ["algorithm",
                                             "pop_size",
                                             "keep_pct",
                                             "length",
                                             "max_attempt",
                                             "max_iter",
                                             "best_fitness",
                                             "time",
                                             "function_evaluations"])


#Loop
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Start the iteration counter
iter = 1
#For each unique number of objects
for length in lengths:
    
    #Set the optimization problem object
    problem = mlrose.DiscreteOpt(length = length,
                                 fitness_fn = fitness_fn,
                                 maximize = True,
                                 max_val = max_val)
    
    #For each combination of max attempt, max iteration, and random restart
    for max_attempt in max_attempts:
        for max_iter in max_iters:
            for pop_size in pop_sizes:
                for keep_pct in keep_pcts:
                
                    #Ensuring reproducibility
                    random_state = iter
                
                    #Start a timer for each iteration
                    start = time.time()

                    #Print message
                    print("Working on iter:", iter,
                          "Length:", length,
                          "Population size:", pop_size,
                          "Keep pct:", keep_pct,
                          "Max attempt:", max_attempt,
                          "Max iter:", max_iter)

                    #Mimic
                    #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
                    #Start the tmer for MIMIC
                    mim_start = time.time()

                    #Optimization
                    (mim_best_state,
                     mim_best_fitness,
                     mim_fitness_curve) = mlrose.mimic(problem = problem,
                                                       pop_size = pop_size,
                                                       keep_pct = keep_pct,
                                                       max_attempts = max_attempt,
                                                       max_iters = max_iter,
                                                       curve = curve,
                                                       random_state = random_state,
                                                       fast_mimic = True)

                    #End the timer
                    mim_end = time.time()
                    #Get the total time
                    mim_time = mim_end - mim_start

                    #Message
                    print("    MIMIC best fitness:", mim_best_fitness)

                    #Add to results list
                    four_peaks_results = four_peaks_results.append({"algorithm": "mimic",
                                                                    "pop_size": pop_size,
                                                                    "keep_pct": keep_pct,
                                                                    "length": length,
                                                                    "max_attempt": max_attempt,
                                                                    "max_iter": max_iter,
                                                                    "best_fitness": mim_best_fitness,
                                                                    "time": mim_time,
                                                                    "function_evaluations": np.argmax(mim_fitness_curve) + 1},
                                                                   ignore_index = True)


                    #End the timer for all four algorithms
                    end = time.time()
                    #Total time for all four algorithms
                    iter_time = end - start

                    #Message
                    print("Iter time:", iter_time)

                    #Increment the iteration counter
                    iter = iter + 1

                    print("\n")

#Output results
four_peaks_results.to_csv(output_four_peaks + "four_peaks_mim.csv", index = False)
pd.DataFrame(mim_fitness_curve).to_csv(output_four_peaks + "four_peaks_mim_curve.csv", index = False)

#Done
print("Done.")
# Out:
# Working on iter: 1 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 100
#     MIMIC best fitness: 16.0
# Iter time: 38.9676079750061
#
#
# Working on iter: 2 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 100
#     MIMIC best fitness: 27.0
# Iter time: 48.251452922821045
#
#
# Working on iter: 3 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 100
#     MIMIC best fitness: 20.0
# Iter time: 45.78596091270447
#
#
# Working on iter: 4 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 200
#     MIMIC best fitness: 13.0
# Iter time: 35.8398220539093
#
#
# Working on iter: 5 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 200
#     MIMIC best fitness: 15.0
# Iter time: 37.943105697631836
#
#
# Working on iter: 6 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 200
#     MIMIC best fitness: 18.0
# Iter time: 95.26564502716064
#
#
# Working on iter: 7 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 300
#     MIMIC best fitness: 9.0
# Iter time: 49.396950006484985
#
#
# Working on iter: 8 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 300
#     MIMIC best fitness: 29.0
# Iter time: 57.29542589187622
#
#
# Working on iter: 9 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 300
#     MIMIC best fitness: 15.0
# Iter time: 73.5210690498352
#
#
# Working on iter: 10 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 400
#     MIMIC best fitness: 17.0
# Iter time: 58.012773752212524
#
#
# Working on iter: 11 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 400
#     MIMIC best fitness: 10.0
# Iter time: 39.166417837142944
#
#
# Working on iter: 12 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 400
#     MIMIC best fitness: 14.0
# Iter time: 40.25845408439636
#
#
# Working on iter: 13 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 500
#     MIMIC best fitness: 31.0
# Iter time: 55.48273682594299
#
#
# Working on iter: 14 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 500
#     MIMIC best fitness: 20.0
# Iter time: 37.428539991378784
#
#
# Working on iter: 15 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 500
#     MIMIC best fitness: 24.0
# Iter time: 59.9812548160553
#
#
# Working on iter: 16 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 600
#     MIMIC best fitness: 24.0
# Iter time: 46.584881067276
#
#
# Working on iter: 17 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 600
#     MIMIC best fitness: 24.0
# Iter time: 43.20676016807556
#
#
# Working on iter: 18 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 600
#     MIMIC best fitness: 17.0
# Iter time: 41.00211310386658
#
#
# Working on iter: 19 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 700
#     MIMIC best fitness: 19.0
# Iter time: 40.369094133377075
#
#
# Working on iter: 20 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 700
#     MIMIC best fitness: 22.0
# Iter time: 35.39968204498291
#
#
# Working on iter: 21 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 700
#     MIMIC best fitness: 19.0
# Iter time: 37.80092000961304
#
#
# Working on iter: 22 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 800
#     MIMIC best fitness: 16.0
# Iter time: 41.66681694984436
#
#
# Working on iter: 23 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 800
#     MIMIC best fitness: 32.0
# Iter time: 63.53350305557251
#
#
# Working on iter: 24 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 800
#     MIMIC best fitness: 18.0
# Iter time: 40.34296894073486
#
#
# Working on iter: 25 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 900
#     MIMIC best fitness: 11.0
# Iter time: 38.27368998527527
#
#
# Working on iter: 26 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 900
#     MIMIC best fitness: 19.0
# Iter time: 45.63693070411682
#
#
# Working on iter: 27 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 900
#     MIMIC best fitness: 12.0
# Iter time: 37.995288133621216
#
#
# Working on iter: 28 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1000
#     MIMIC best fitness: 21.0
# Iter time: 41.11011791229248
#
#
# Working on iter: 29 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1000
#     MIMIC best fitness: 33.0
# Iter time: 90.55233669281006
#
#
# Working on iter: 30 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1000
#     MIMIC best fitness: 13.0
# Iter time: 63.06070017814636
#
#
# Working on iter: 31 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1100
#     MIMIC best fitness: 16.0
# Iter time: 37.07906413078308
#
#
# Working on iter: 32 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1100
#     MIMIC best fitness: 14.0
# Iter time: 33.012879848480225
#
#
# Working on iter: 33 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1100
#     MIMIC best fitness: 29.0
# Iter time: 103.9027349948883
#
#
# Working on iter: 34 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1200
#     MIMIC best fitness: 17.0
# Iter time: 40.171765089035034
#
#
# Working on iter: 35 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1200
#     MIMIC best fitness: 16.0
# Iter time: 48.14877915382385
#
#
# Working on iter: 36 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1200
#     MIMIC best fitness: 18.0
# Iter time: 50.67831873893738
#
#
# Working on iter: 37 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1300
#     MIMIC best fitness: 12.0
# Iter time: 35.98308777809143
#
#
# Working on iter: 38 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1300
#     MIMIC best fitness: 14.0
# Iter time: 42.62507486343384
#
#
# Working on iter: 39 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1300
#     MIMIC best fitness: 16.0
# Iter time: 50.11249399185181
#
#
# Working on iter: 40 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1400
#     MIMIC best fitness: 21.0
# Iter time: 37.9695770740509
#
#
# Working on iter: 41 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1400
#     MIMIC best fitness: 11.0
# Iter time: 34.33605670928955
#
#
# Working on iter: 42 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1400
#     MIMIC best fitness: 16.0
# Iter time: 54.27856397628784
#
#
# Working on iter: 43 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1500
#     MIMIC best fitness: 14.0
# Iter time: 43.31810688972473
#
#
# Working on iter: 44 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1500
#     MIMIC best fitness: 24.0
# Iter time: 37.25656008720398
#
#
# Working on iter: 45 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1500
#     MIMIC best fitness: 20.0
# Iter time: 46.93665099143982
#
#
# Working on iter: 46 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1600
#     MIMIC best fitness: 30.0
# Iter time: 40.28178524971008
#
#
# Working on iter: 47 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1600
#     MIMIC best fitness: 25.0
# Iter time: 51.023277759552
#
#
# Working on iter: 48 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1600
#     MIMIC best fitness: 16.0
# Iter time: 42.5007860660553
#
#
# Working on iter: 49 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1700
#     MIMIC best fitness: 18.0
# Iter time: 52.96030116081238
#
#
# Working on iter: 50 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1700
#     MIMIC best fitness: 13.0
# Iter time: 43.45815896987915
#
#
# Working on iter: 51 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1700
#     MIMIC best fitness: 16.0
# Iter time: 49.36252188682556
#
#
# Working on iter: 52 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1800
#     MIMIC best fitness: 15.0
# Iter time: 34.231521129608154
#
#
# Working on iter: 53 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1800
#     MIMIC best fitness: 17.0
# Iter time: 36.96222805976868
#
#
# Working on iter: 54 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1800
#     MIMIC best fitness: 14.0
# Iter time: 47.17141509056091
#
#
# Working on iter: 55 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1900
#     MIMIC best fitness: 14.0
# Iter time: 36.48485803604126
#
#
# Working on iter: 56 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1900
#     MIMIC best fitness: 22.0
# Iter time: 1049.9663310050964
#
#
# Working on iter: 57 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1900
#     MIMIC best fitness: 27.0
# Iter time: 1960.151242017746
#
#
# Working on iter: 58 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 2000
#     MIMIC best fitness: 19.0
# Iter time: 1844.9819581508636
#
#
# Working on iter: 59 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 2000
#     MIMIC best fitness: 15.0
# Iter time: 48.716498136520386
#
#
# Working on iter: 60 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 2000
#     MIMIC best fitness: 18.0
# Iter time: 1022.4186089038849
#
#
# Done.

# %% [markdown]
# ## Knapsack

# %%
#Inputs for knapsack problem
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
weights = np.random.randint(1, 6, lengths)
values = np.random.randint(1, 6, lengths)
max_weight_pct = 0.6
fitness_fn = mlrose.Knapsack(weights = weights, values = values, max_weight_pct = max_weight_pct)

#Initialize an empty data frame for recording results
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
knapsack_results = pd.DataFrame(columns = ["algorithm",
                                           "pop_size",
                                           "keep_pct",
                                           "length",
                                           "max_attempt",
                                           "max_iter",
                                           "best_fitness",
                                           "time",
                                           "function_evaluations"])

#Loop
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Start an iteration counter
iter = 1
#For each unique number of objects
for length in lengths:
    
    #Set the optimization problem object
    problem = mlrose.DiscreteOpt(length = length,
                                 fitness_fn = fitness_fn,
                                 maximize = True,
                                 max_val = max_val)
    
    #For each combination of max attempt, max iteration, and random restart
    for max_attempt in max_attempts:
        for max_iter in max_iters:
            for pop_size in pop_sizes:
                for keep_pct in keep_pcts:
                
                    #Ensuring reproducibility
                    random_state = iter
                
                    #Start a timer for each iteration
                    start = time.time()

                    #Print message
                    print("Working on iter:", iter,
                          "Length:", length,
                          "Population size:", pop_size,
                          "Keep pct:", keep_pct,
                          "Max attempt:", max_attempt,
                          "Max iter:", max_iter)

                    #Mimic
                    #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
                    #Start the timer for MIMIC
                    mim_start = time.time()

                    #Optimization
                    (mim_best_state,
                     mim_best_fitness,
                     mim_fitness_curve) = mlrose.mimic(problem = problem,
                                                       pop_size = pop_size,
                                                       keep_pct = keep_pct,
                                                       max_attempts = max_attempt,
                                                       max_iters = max_iter,
                                                       curve = curve,
                                                       random_state = random_state,
                                                       fast_mimic = True)
                    #End the timer
                    mim_end = time.time()
                    #Get the total time
                    mim_time = mim_end - mim_start

                    #Message
                    print("    MIMIC best fitness:", mim_best_fitness)

                    #Add to results list
                    knapsack_results = knapsack_results.append({"algorithm": "mimic",
                                                                "pop_size": pop_size,
                                                                "keep_pct": keep_pct,
                                                                "length": length,
                                                                "max_attempt": max_attempt,
                                                                "max_iter": max_iter,
                                                                "best_fitness": mim_best_fitness,
                                                                "time": mim_time,
                                                                "function_evaluations": np.argmax(mim_fitness_curve) + 1},
                                                                ignore_index = True)


                    #End the timer for all four algorithms
                    end = time.time()
                    #Total time for all four algorithms
                    iter_time = end - start

                    #Message
                    print("Iter time:", iter_time)

                    print("\n")
                    iter = iter + 1

#Output results                
knapsack_results.to_csv(output_knapsack + "knapsack_mim.csv", index = False)
pd.DataFrame(mim_fitness_curve).to_csv(output_knapsack + "knapsack_mim_curve.csv", index = False)

#Done
print("Done.")
# Out:
# Working on iter: 1 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 100
#     MIMIC best fitness: 2172.0
# Iter time: 1071.3554599285126
#
#
# Working on iter: 2 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 100
#     MIMIC best fitness: 2244.0
# Iter time: 50.23491406440735
#
#
# Working on iter: 3 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 100
#     MIMIC best fitness: 2320.0
# Iter time: 2109.0619151592255
#
#
# Working on iter: 4 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 200
#     MIMIC best fitness: 2191.0
# Iter time: 188.56577396392822
#
#
# Working on iter: 5 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 200
#     MIMIC best fitness: 2298.0
# Iter time: 56.0721001625061
#
#
# Working on iter: 6 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 200
#     MIMIC best fitness: 2299.0
# Iter time: 606.5003809928894
#
#
# Working on iter: 7 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 300
#     MIMIC best fitness: 2119.0
# Iter time: 393.9843771457672
#
#
# Working on iter: 8 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 300
#     MIMIC best fitness: 2279.0
# Iter time: 57.15293526649475
#
#
# Working on iter: 9 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 300
#     MIMIC best fitness: 2319.0
# Iter time: 1983.6982581615448
#
#
# Working on iter: 10 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 400
#     MIMIC best fitness: 2200.0
# Iter time: 1048.5700931549072
#
#
# Working on iter: 11 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 400
#     MIMIC best fitness: 2228.0
# Iter time: 66.10730791091919
#
#
# Working on iter: 12 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 400
#     MIMIC best fitness: 2266.0
# Iter time: 1123.5415279865265
#
#
# Working on iter: 13 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 500
#     MIMIC best fitness: 2169.0
# Iter time: 1092.5058677196503
#
#
# Working on iter: 14 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 500
#     MIMIC best fitness: 2183.0
# Iter time: 1419.20778298378
#
#
# Working on iter: 15 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 500
#     MIMIC best fitness: 2320.0
# Iter time: 2732.029335975647
#
#
# Working on iter: 16 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 600
#     MIMIC best fitness: 2163.0
# Iter time: 162.14950394630432
#
#
# Working on iter: 17 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 600
#     MIMIC best fitness: 2175.0
# Iter time: 48.332871198654175
#
#
# Working on iter: 18 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 600
#     MIMIC best fitness: 2306.0
# Iter time: 1780.3079538345337
#
#
# Working on iter: 19 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 700
#     MIMIC best fitness: 2167.0
# Iter time: 1069.3687131404877
#
#
# Working on iter: 20 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 700
#     MIMIC best fitness: 2276.0
# Iter time: 989.6643619537354
#
#
# Working on iter: 21 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 700
#     MIMIC best fitness: 2210.0
# Iter time: 72.100821018219
#
#
# Working on iter: 22 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 800
#     MIMIC best fitness: 2119.0
# Iter time: 1723.8551099300385
#
#
# Working on iter: 23 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 800
#     MIMIC best fitness: 2159.0
# Iter time: 2240.700553894043
#
#
# Working on iter: 24 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 800
#     MIMIC best fitness: 2205.0
# Iter time: 1006.3222680091858
#
#
# Working on iter: 25 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 900
#     MIMIC best fitness: 2151.0
# Iter time: 1042.602292060852
#
#
# Working on iter: 26 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 900
#     MIMIC best fitness: 2167.0
# Iter time: 1799.6612169742584
#
#
# Working on iter: 27 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 900
#     MIMIC best fitness: 2243.0
# Iter time: 2914.3410589694977
#
#
# Working on iter: 28 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1000
#     MIMIC best fitness: 2173.0
# Iter time: 957.561115026474
#
#
# Working on iter: 29 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1000
#     MIMIC best fitness: 2223.0
# Iter time: 1827.5456466674805
#
#
# Working on iter: 30 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1000
#     MIMIC best fitness: 2171.0
# Iter time: 3529.8936808109283
#
#
# Working on iter: 31 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1100
#     MIMIC best fitness: 2188.0
# Iter time: 1115.4462649822235
#
#
# Working on iter: 32 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1100
#     MIMIC best fitness: 2194.0
# Iter time: 1812.9765911102295
#
#
# Working on iter: 33 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1100
#     MIMIC best fitness: 2294.0
# Iter time: 2214.181760072708
#
#
# Working on iter: 34 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1200
#     MIMIC best fitness: 2159.0
# Iter time: 42.261335134506226
#
#
# Working on iter: 35 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1200
#     MIMIC best fitness: 2275.0
# Iter time: 2936.3498690128326
#
#
# Working on iter: 36 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1200
#     MIMIC best fitness: 2325.0
# Iter time: 2987.1690561771393
#
#
# Working on iter: 37 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1300
#     MIMIC best fitness: 2120.0
# Iter time: 41.642404079437256
#
#
# Working on iter: 38 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1300
#     MIMIC best fitness: 2168.0
# Iter time: 3275.422823190689
#
#
# Working on iter: 39 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1300
#     MIMIC best fitness: 2281.0
# Iter time: 1096.906077861786
#
#
# Working on iter: 40 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1400
#     MIMIC best fitness: 2075.0
# Iter time: 1938.1630010604858
#
#
# Working on iter: 41 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1400
#     MIMIC best fitness: 2264.0
# Iter time: 3696.282473087311
#
#
# Working on iter: 42 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1400
#     MIMIC best fitness: 2278.0
# Iter time: 699.3764679431915
#
#
# Working on iter: 43 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1500
#     MIMIC best fitness: 2061.0
# Iter time: 36.78124284744263
#
#
# Working on iter: 44 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1500
#     MIMIC best fitness: 2263.0
# Iter time: 60.15662598609924
#
#
# Working on iter: 45 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1500
#     MIMIC best fitness: 2221.0
# Iter time: 75.30416107177734
#
#
# Working on iter: 46 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1600
#     MIMIC best fitness: 2108.0
# Iter time: 42.58538222312927
#
#
# Working on iter: 47 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1600
#     MIMIC best fitness: 2262.0
# Iter time: 56.053648710250854
#
#
# Working on iter: 48 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1600
#     MIMIC best fitness: 2278.0
# Iter time: 80.0958080291748
#
#
# Working on iter: 49 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1700
#     MIMIC best fitness: 2172.0
# Iter time: 42.291424036026
#
#
# Working on iter: 50 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1700
#     MIMIC best fitness: 2264.0
# Iter time: 55.78877902030945
#
#
# Working on iter: 51 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1700
#     MIMIC best fitness: 2309.0
# Iter time: 77.08750629425049
#
#
# Working on iter: 52 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1800
#     MIMIC best fitness: 2182.0
# Iter time: 39.15996503829956
#
#
# Working on iter: 53 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1800
#     MIMIC best fitness: 2266.0
# Iter time: 54.074607133865356
#
#
# Working on iter: 54 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1800
#     MIMIC best fitness: 2222.0
# Iter time: 2171.998708963394
#
#
# Working on iter: 55 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1900
#     MIMIC best fitness: 2173.0
# Iter time: 1009.389148235321
#
#
# Working on iter: 56 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1900
#     MIMIC best fitness: 2194.0
# Iter time: 1873.3507268428802
#
#
# Working on iter: 57 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1900
#     MIMIC best fitness: 2335.0
# Iter time: 85.5052969455719
#
#
# Working on iter: 58 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 2000
#     MIMIC best fitness: 2172.0
# Iter time: 1865.74192404747
#
#
# Working on iter: 59 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 2000
#     MIMIC best fitness: 2288.0
# Iter time: 3806.6223709583282
#
#
# Working on iter: 60 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 2000
#     MIMIC best fitness: 2285.0
# Iter time: 1972.4514119625092
#
#
# Done.

# %% [markdown]
# ## FlipFlop

# %%
#Inputs for FlipFlop problem
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
fitness_fn = mlrose.FlipFlop()

#Initialize an empty data frame for recording results
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
flip_flop_results = pd.DataFrame(columns = ["algorithm",
                                            "pop_size",
                                            "keep_pct",
                                            "length",
                                            "max_attempt",
                                            "max_iter",
                                            "best_fitness",
                                            "time",
                                            "function_evaluations"])

#Loop
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Start an iteration counter
iter = 1
#For each unique number of objects
for length in lengths:
    
    #Set the optimization problem object
    problem = mlrose.DiscreteOpt(length = length,
                                 fitness_fn = fitness_fn,
                                 maximize = True,
                                 max_val = max_val)
    
    #For each combination of max attempt, max iteration, and random restart
    for max_attempt in max_attempts:
        for max_iter in max_iters:
            for pop_size in pop_sizes:
                for keep_pct in keep_pcts:
                
                    #Ensuring reproducibility
                    random_state = iter
                
                    #Start a timer for each iteration
                    start = time.time()

                    #Print message
                    print("Working on iter:", iter,
                          "Length:", length,
                          "Population size:", pop_size,
                          "Keep pct:", keep_pct,
                          "Max attempt:", max_attempt,
                          "Max iter:", max_iter)

                    #Mimic
                    #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
                    #Start the timer for MIMIC
                    mim_start = time.time()

                    #Optimization
                    (mim_best_state,
                     mim_best_fitness,
                     mim_fitness_curve) = mlrose.mimic(problem = problem,
                                                       pop_size = pop_size,
                                                       keep_pct = keep_pct,
                                                       max_attempts = max_attempt,
                                                       max_iters = max_iter,
                                                       curve = curve,
                                                       random_state = random_state,
                                                       fast_mimic = True)
                    #End the timer
                    mim_end = time.time()
                    #Get the total time
                    mim_time = mim_end - mim_start

                    #Message
                    print("    MIMIC best fitness:", mim_best_fitness)

                    #Add to results list
                    flip_flop_results = flip_flop_results.append({"algorithm": "mimic",
                                                                  "pop_size": pop_size,
                                                                  "keep_pct": keep_pct,
                                                                  "length": length,
                                                                  "max_attempt": max_attempt,
                                                                  "max_iter": max_iter,
                                                                  "best_fitness": mim_best_fitness,
                                                                  "time": mim_time,
                                                                  "function_evaluations": np.argmax(mim_fitness_curve) + 1},
                                                                   ignore_index = True)


                    end = time.time()
                    iter_time = end - start
                    print("Iter time:", iter_time)

                    print("\n")
                    iter = iter + 1

#Output results
flip_flop_results.to_csv(output_flip_flop + "flip_flop_mim.csv", index = False)
pd.DataFrame(mim_fitness_curve).to_csv(output_flip_flop + "flip_flop_mim_curve.csv", index = False)

#Done
print("Done.")
# Out:
# Working on iter: 1 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 100
#     MIMIC best fitness: 724.0
# Iter time: 1079.970930814743
#
#
# Working on iter: 2 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 100
#     MIMIC best fitness: 738.0
# Iter time: 1017.6417798995972
#
#
# Working on iter: 3 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 100
#     MIMIC best fitness: 776.0
# Iter time: 2869.9012398719788
#
#
# Working on iter: 4 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 200
#     MIMIC best fitness: 744.0
# Iter time: 472.1281921863556
#
#
# Working on iter: 5 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 200
#     MIMIC best fitness: 785.0
# Iter time: 52.386768102645874
#
#
# Working on iter: 6 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 200
#     MIMIC best fitness: 767.0
# Iter time: 63.63113021850586
#
#
# Working on iter: 7 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 300
#     MIMIC best fitness: 751.0
# Iter time: 44.69995713233948
#
#
# Working on iter: 8 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 300
#     MIMIC best fitness: 804.0
# Iter time: 56.85861086845398
#
#
# Working on iter: 9 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 300
#     MIMIC best fitness: 756.0
# Iter time: 63.94388508796692
#
#
# Working on iter: 10 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 400
#     MIMIC best fitness: 729.0
# Iter time: 43.623852014541626
#
#
# Working on iter: 11 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 400
#     MIMIC best fitness: 719.0
# Iter time: 51.28992199897766
#
#
# Working on iter: 12 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 400
#     MIMIC best fitness: 737.0
# Iter time: 62.745572090148926
#
#
# Working on iter: 13 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 500
#     MIMIC best fitness: 716.0
# Iter time: 42.17223596572876
#
#
# Working on iter: 14 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 500
#     MIMIC best fitness: 768.0
# Iter time: 53.29371500015259
#
#
# Working on iter: 15 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 500
#     MIMIC best fitness: 771.0
# Iter time: 66.20137619972229
#
#
# Working on iter: 16 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 600
#     MIMIC best fitness: 711.0
# Iter time: 42.204143047332764
#
#
# Working on iter: 17 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 600
#     MIMIC best fitness: 750.0
# Iter time: 3392.092042684555
#
#
# Working on iter: 18 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 600
#     MIMIC best fitness: 811.0
# Iter time: 1880.0513010025024
#
#
# Working on iter: 19 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 700
#     MIMIC best fitness: 728.0
# Iter time: 42.810630798339844
#
#
# Working on iter: 20 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 700
#     MIMIC best fitness: 785.0
# Iter time: 55.77410101890564
#
#
# Working on iter: 21 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 700
#     MIMIC best fitness: 777.0
# Iter time: 61.94947600364685
#
#
# Working on iter: 22 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 800
#     MIMIC best fitness: 742.0
# Iter time: 42.891014099121094
#
#
# Working on iter: 23 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 800
#     MIMIC best fitness: 764.0
# Iter time: 52.10285496711731
#
#
# Working on iter: 24 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 800
#     MIMIC best fitness: 812.0
# Iter time: 66.8714988231659
#
#
# Working on iter: 25 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 900
#     MIMIC best fitness: 695.0
# Iter time: 38.83560490608215
#
#
# Working on iter: 26 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 900
#     MIMIC best fitness: 748.0
# Iter time: 49.6200749874115
#
#
# Working on iter: 27 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 900
#     MIMIC best fitness: 730.0
# Iter time: 58.192229986190796
#
#
# Working on iter: 28 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1000
#     MIMIC best fitness: 732.0
# Iter time: 45.39626908302307
#
#
# Working on iter: 29 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1000
#     MIMIC best fitness: 720.0
# Iter time: 47.55331087112427
#
#
# Working on iter: 30 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1000
#     MIMIC best fitness: 778.0
# Iter time: 1254.4690260887146
#
#
# Working on iter: 31 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1100
#     MIMIC best fitness: 742.0
# Iter time: 1068.2824261188507
#
#
# Working on iter: 32 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1100
#     MIMIC best fitness: 777.0
# Iter time: 1040.8199000358582
#
#
# Working on iter: 33 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1100
#     MIMIC best fitness: 774.0
# Iter time: 1091.175206899643
#
#
# Working on iter: 34 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1200
#     MIMIC best fitness: 688.0
# Iter time: 41.62128472328186
#
#
# Working on iter: 35 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1200
#     MIMIC best fitness: 811.0
# Iter time: 52.33490991592407
#
#
# Working on iter: 36 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1200
#     MIMIC best fitness: 813.0
# Iter time: 61.41118407249451
#
#
# Working on iter: 37 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1300
#     MIMIC best fitness: 750.0
# Iter time: 41.46304702758789
#
#
# Working on iter: 38 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1300
#     MIMIC best fitness: 795.0
# Iter time: 55.73069500923157
#
#
# Working on iter: 39 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1300
#     MIMIC best fitness: 811.0
# Iter time: 60.794432163238525
#
#
# Working on iter: 40 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1400
#     MIMIC best fitness: 738.0
# Iter time: 40.61520791053772
#
#
# Working on iter: 41 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1400
#     MIMIC best fitness: 787.0
# Iter time: 54.645323038101196
#
#
# Working on iter: 42 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1400
#     MIMIC best fitness: 813.0
# Iter time: 66.09525728225708
#
#
# Working on iter: 43 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1500
#     MIMIC best fitness: 746.0
# Iter time: 46.49390387535095
#
#
# Working on iter: 44 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1500
#     MIMIC best fitness: 820.0
# Iter time: 50.620174169540405
#
#
# Working on iter: 45 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1500
#     MIMIC best fitness: 792.0
# Iter time: 64.93000912666321
#
#
# Working on iter: 46 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1600
#     MIMIC best fitness: 742.0
# Iter time: 40.61746597290039
#
#
# Working on iter: 47 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1600
#     MIMIC best fitness: 770.0
# Iter time: 47.484899044036865
#
#
# Working on iter: 48 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1600
#     MIMIC best fitness: 787.0
# Iter time: 61.84063172340393
#
#
# Working on iter: 49 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1700
#     MIMIC best fitness: 773.0
# Iter time: 40.4649019241333
#
#
# Working on iter: 50 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1700
#     MIMIC best fitness: 761.0
# Iter time: 1218.4736020565033
#
#
# Working on iter: 51 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1700
#     MIMIC best fitness: 804.0
# Iter time: 366.9350690841675
#
#
# Working on iter: 52 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1800
#     MIMIC best fitness: 739.0
# Iter time: 42.2144570350647
#
#
# Working on iter: 53 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1800
#     MIMIC best fitness: 795.0
# Iter time: 54.89089298248291
#
#
# Working on iter: 54 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1800
#     MIMIC best fitness: 778.0
# Iter time: 65.04394197463989
#
#
# Working on iter: 55 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1900
#     MIMIC best fitness: 759.0
# Iter time: 42.12629199028015
#
#
# Working on iter: 56 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1900
#     MIMIC best fitness: 727.0
# Iter time: 48.568000078201294
#
#
# Working on iter: 57 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1900
#     MIMIC best fitness: 781.0
# Iter time: 61.49293494224548
#
#
# Working on iter: 58 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 2000
#     MIMIC best fitness: 675.0
# Iter time: 39.34746479988098
#
#
# Working on iter: 59 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 2000
#     MIMIC best fitness: 752.0
# Iter time: 50.29706788063049
#
#
# Working on iter: 60 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 2000
#     MIMIC best fitness: 773.0
# Iter time: 61.44169497489929
#
#
# Done.

# %% [markdown]
# ### OneMax

# %%
#Inputs for FlipFlop problem
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
fitness_fn = mlrose.OneMax()

#Initialize an empty data frame for recording results
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
one_max_results = pd.DataFrame(columns = ["algorithm",
                                          "pop_size",
                                          "keep_pct",
                                          "length",
                                          "max_attempt",
                                          "max_iter",
                                          "best_fitness",
                                          "time",
                                          "function_evaluations"])

#Loop
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#Start an iteration counter
iter = 1
#For each unique number of objects
for length in lengths:
    
    #Set the optimization problem object
    problem = mlrose.DiscreteOpt(length = length,
                                 fitness_fn = fitness_fn,
                                 maximize = True,
                                 max_val = max_val)
    
    #For each combination of max attempt, max iteration, and random restart
    for max_attempt in max_attempts:
        for max_iter in max_iters:
            for pop_size in pop_sizes:
                for keep_pct in keep_pcts:
                
                    #Ensuring reproducibility
                    random_state = iter
                
                    #Start a timer for each iteration
                    start = time.time()

                    #Print message
                    print("Working on iter:", iter,
                          "Length:", length,
                          "Population size:", pop_size,
                          "Keep pct:", keep_pct,
                          "Max attempt:", max_attempt,
                          "Max iter:", max_iter)

                    #Mimic
                    #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
                    #Start the timer for MIMIC
                    mim_start = time.time()

                    #Optimization
                    (mim_best_state,
                     mim_best_fitness,
                     mim_fitness_curve) = mlrose.mimic(problem = problem,
                                                       pop_size = pop_size,
                                                       keep_pct = keep_pct,
                                                       max_attempts = max_attempt,
                                                       max_iters = max_iter,
                                                       curve = curve,
                                                       random_state = random_state,
                                                       fast_mimic = True)
                    #End the timer
                    mim_end = time.time()
                    #Get the total time
                    mim_time = mim_end - mim_start

                    #Message
                    print("    MIMIC best fitness:", mim_best_fitness)

                    #Add to results list
                    one_max_results = one_max_results.append({"algorithm": "mimic",
                                                              "pop_size": pop_size,
                                                              "keep_pct": keep_pct,
                                                              "length": length,
                                                              "max_attempt": max_attempt,
                                                              "max_iter": max_iter,
                                                              "best_fitness": mim_best_fitness,
                                                              "time": mim_time,
                                                              "function_evaluations": np.argmax(mim_fitness_curve) + 1},
                                                              ignore_index = True)


                    end = time.time()
                    iter_time = end - start
                    print("Iter time:", iter_time)

                    print("\n")
                    iter = iter + 1

#Output results
one_max_results.to_csv(output_one_max + "one_max_mim.csv", index = False)
pd.DataFrame(mim_fitness_curve).to_csv(output_one_max + "one_max_mim_curve.csv", index = False)

#Done
print("Done.")
# Out:
# Working on iter: 1 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 100
#     MIMIC best fitness: 802.0
# Iter time: 40.05660796165466
#
#
# Working on iter: 2 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 100
#     MIMIC best fitness: 901.0
# Iter time: 49.80327391624451
#
#
# Working on iter: 3 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 100
#     MIMIC best fitness: 899.0
# Iter time: 760.2000367641449
#
#
# Working on iter: 4 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 200
#     MIMIC best fitness: 833.0
# Iter time: 986.4941298961639
#
#
# Working on iter: 5 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 200
#     MIMIC best fitness: 927.0
# Iter time: 1113.6703600883484
#
#
# Working on iter: 6 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 200
#     MIMIC best fitness: 919.0
# Iter time: 64.208083152771
#
#
# Working on iter: 7 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 300
#     MIMIC best fitness: 824.0
# Iter time: 1044.0824539661407
#
#
# Working on iter: 8 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 300
#     MIMIC best fitness: 916.0
# Iter time: 1029.5819067955017
#
#
# Working on iter: 9 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 300
#     MIMIC best fitness: 953.0
# Iter time: 1100.3921482563019
#
#
# Working on iter: 10 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 400
#     MIMIC best fitness: 776.0
# Iter time: 1828.1855380535126
#
#
# Working on iter: 11 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 400
#     MIMIC best fitness: 905.0
# Iter time: 221.5053482055664
#
#
# Working on iter: 12 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 400
#     MIMIC best fitness: 951.0
# Iter time: 67.59361982345581
#
#
# Working on iter: 13 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 500
#     MIMIC best fitness: 843.0
# Iter time: 41.92671990394592
#
#
# Working on iter: 14 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 500
#     MIMIC best fitness: 847.0
# Iter time: 48.6514208316803
#
#
# Working on iter: 15 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 500
#     MIMIC best fitness: 907.0
# Iter time: 63.7302520275116
#
#
# Working on iter: 16 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 600
#     MIMIC best fitness: 811.0
# Iter time: 40.62163305282593
#
#
# Working on iter: 17 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 600
#     MIMIC best fitness: 888.0
# Iter time: 50.82081484794617
#
#
# Working on iter: 18 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 600
#     MIMIC best fitness: 903.0
# Iter time: 62.768808126449585
#
#
# Working on iter: 19 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 700
#     MIMIC best fitness: 848.0
# Iter time: 40.20132398605347
#
#
# Working on iter: 20 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 700
#     MIMIC best fitness: 880.0
# Iter time: 50.03792381286621
#
#
# Working on iter: 21 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 700
#     MIMIC best fitness: 912.0
# Iter time: 66.20113205909729
#
#
# Working on iter: 22 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 800
#     MIMIC best fitness: 829.0
# Iter time: 42.103158712387085
#
#
# Working on iter: 23 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 800
#     MIMIC best fitness: 870.0
# Iter time: 1056.4622399806976
#
#
# Working on iter: 24 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 800
#     MIMIC best fitness: 936.0
# Iter time: 995.1474361419678
#
#
# Working on iter: 25 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 900
#     MIMIC best fitness: 799.0
# Iter time: 42.88592004776001
#
#
# Working on iter: 26 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 900
#     MIMIC best fitness: 874.0
# Iter time: 1045.7800121307373
#
#
# Working on iter: 27 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 900
#     MIMIC best fitness: 878.0
# Iter time: 2094.977583169937
#
#
# Working on iter: 28 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1000
#     MIMIC best fitness: 810.0
# Iter time: 42.237313985824585
#
#
# Working on iter: 29 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1000
#     MIMIC best fitness: 818.0
# Iter time: 50.37192702293396
#
#
# Working on iter: 30 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1000
#     MIMIC best fitness: 936.0
# Iter time: 1806.6528000831604
#
#
# Working on iter: 31 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1100
#     MIMIC best fitness: 823.0
# Iter time: 1938.1710340976715
#
#
# Working on iter: 32 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1100
#     MIMIC best fitness: 913.0
# Iter time: 1841.539517879486
#
#
# Working on iter: 33 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1100
#     MIMIC best fitness: 921.0
# Iter time: 1926.3834989070892
#
#
# Working on iter: 34 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1200
#     MIMIC best fitness: 842.0
# Iter time: 1830.3653090000153
#
#
# Working on iter: 35 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1200
#     MIMIC best fitness: 885.0
# Iter time: 1250.923014163971
#
#
# Working on iter: 36 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1200
#     MIMIC best fitness: 923.0
# Iter time: 2942.6852049827576
#
#
# Working on iter: 37 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1300
#     MIMIC best fitness: 843.0
# Iter time: 1930.8963420391083
#
#
# Working on iter: 38 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1300
#     MIMIC best fitness: 870.0
# Iter time: 1869.4551327228546
#
#
# Working on iter: 39 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1300
#     MIMIC best fitness: 908.0
# Iter time: 1072.8953909873962
#
#
# Working on iter: 40 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1400
#     MIMIC best fitness: 769.0
# Iter time: 41.22159790992737
#
#
# Working on iter: 41 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1400
#     MIMIC best fitness: 904.0
# Iter time: 52.77362108230591
#
#
# Working on iter: 42 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1400
#     MIMIC best fitness: 906.0
# Iter time: 62.58128213882446
#
#
# Working on iter: 43 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1500
#     MIMIC best fitness: 817.0
# Iter time: 39.77689003944397
#
#
# Working on iter: 44 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1500
#     MIMIC best fitness: 845.0
# Iter time: 47.78548717498779
#
#
# Working on iter: 45 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1500
#     MIMIC best fitness: 938.0
# Iter time: 61.3583550453186
#
#
# Working on iter: 46 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1600
#     MIMIC best fitness: 800.0
# Iter time: 43.12321090698242
#
#
# Working on iter: 47 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1600
#     MIMIC best fitness: 913.0
# Iter time: 50.9801070690155
#
#
# Working on iter: 48 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1600
#     MIMIC best fitness: 931.0
# Iter time: 63.93924593925476
#
#
# Working on iter: 49 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1700
#     MIMIC best fitness: 840.0
# Iter time: 39.59316611289978
#
#
# Working on iter: 50 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1700
#     MIMIC best fitness: 876.0
# Iter time: 35.04728174209595
#
#
# Working on iter: 51 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1700
#     MIMIC best fitness: 923.0
# Iter time: 59.41723418235779
#
#
# Working on iter: 52 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1800
#     MIMIC best fitness: 822.0
# Iter time: 40.95312309265137
#
#
# Working on iter: 53 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1800
#     MIMIC best fitness: 868.0
# Iter time: 49.86283612251282
#
#
# Working on iter: 54 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1800
#     MIMIC best fitness: 947.0
# Iter time: 63.70048785209656
#
#
# Working on iter: 55 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 1900
#     MIMIC best fitness: 769.0
# Iter time: 41.12821102142334
#
#
# Working on iter: 56 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 1900
#     MIMIC best fitness: 907.0
# Iter time: 49.65781092643738
#
#
# Working on iter: 57 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 1900
#     MIMIC best fitness: 938.0
# Iter time: 1124.4248750209808
#
#
# Working on iter: 58 Length: 1000 Population size: 100 Keep pct: 0.1 Max attempt: 20 Max iter: 2000
#     MIMIC best fitness: 824.0
# Iter time: 962.7060060501099
#
#
# Working on iter: 59 Length: 1000 Population size: 100 Keep pct: 0.2 Max attempt: 20 Max iter: 2000
#     MIMIC best fitness: 880.0
# Iter time: 1877.9181180000305
#
#
# Working on iter: 60 Length: 1000 Population size: 100 Keep pct: 0.3 Max attempt: 20 Max iter: 2000
#     MIMIC best fitness: 914.0
# Iter time: 2938.367959022522
#
#
# Done.
